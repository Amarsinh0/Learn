# %% [markdown]
# <a href="https://colab.research.google.com/github/Amarsinh0/MY-NOTES/blob/main/ML_code_collection_888_Geeks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Create Test DataSets using Sklearn

# %%
# importing libraries
from sklearn.datasets import make_blobs

# matplotlib for plotting
from matplotlib import pyplot as plt
from matplotlib import style

# Creating Test DataSets using sklearn.datasets.make_blobs
from sklearn.datasets import make_blobs
from matplotlib import pyplot as plt
from matplotlib import style

style.use("fivethirtyeight")

X, y = make_blobs(n_samples = 100, centers = 3,
			cluster_std = 1, n_features = 2)

plt.scatter(X[:, 0], X[:, 1], s = 40, color = 'g')
plt.xlabel("X")
plt.ylabel("Y")

plt.show()
plt.clf()

# %% [markdown]
# Sure! Let's go through the provided code step by step:
#
# Step 1: Importing Libraries
# ```python
# # importing libraries
# from sklearn.datasets import make_blobs
# from matplotlib import pyplot as plt
# from matplotlib import style
# ```
# Explanation: In this step, we import necessary libraries that we will be using later in the code. The code imports three libraries:
# - `sklearn.datasets.make_blobs`: This library is used to create synthetic datasets with clusters of data points.
# - `matplotlib.pyplot`: This library is used for data visualization and plotting.
# - `matplotlib.style`: This module provides style settings for the plots.
#
# Step 2: Setting Plot Style
# ```python
# style.use("fivethirtyeight")
# ```
# Explanation: Here, we set the style for the plot using the `style.use()` function. In this case, we're using the "fivethirtyeight" style, which is one of the pre-defined styles available in Matplotlib.
#
# Step 3: Creating Test Datasets
# ```python
# X, y = make_blobs(n_samples=100, centers=3, cluster_std=1, n_features=2)
# ```
# Explanation: This step creates synthetic datasets using the `make_blobs` function from the `sklearn.datasets` module. The function generates random samples from a multi-dimensional Gaussian distribution and creates clusters of points. The parameters used in the function are:
# - `n_samples`: The total number of data points to generate (in this case, 100).
# - `centers`: The number of clusters to generate (in this case, 3).
# - `cluster_std`: The standard deviation of the clusters (in this case, 1).
# - `n_features`: The number of features for each data point (in this case, 2).
#
# Step 4: Plotting the Data Points
# ```python
# plt.scatter(X[:, 0], X[:, 1], s=40, color='g')
# plt.xlabel("X")
# plt.ylabel("Y")
# ```
# Explanation: In this step, we plot the data points on a 2D graph. The `scatter` function from Matplotlib is used for this purpose. The first argument (`X[:, 0]`) corresponds to the x-coordinates of the data points, and the second argument (`X[:, 1]`) corresponds to the y-coordinates of the data points. The parameters used in the `scatter` function are:
# - `s`: The size of the markers (in this case, 40).
# - `color`: The color of the markers (in this case, green - 'g').
# - `xlabel`: Sets the label for the x-axis as "X".
# - `ylabel`: Sets the label for the y-axis as "Y".
#
# Step 5: Displaying the Plot
# ```python
# plt.show()
# ```
# Explanation: This line displays the plot on the screen. Without this line, the plot would not be visible.
#
# Step 6: Clearing the Plot
# ```python
# plt.clf()
# ```
# Explanation: This line clears the current plot, allowing you to create a new plot or avoid any overlap with subsequent plots if you are plotting multiple figures.
#
# Concepts covered in this code:
# 1. Importing libraries: Python allows us to import external libraries to extend its functionality. In this code, we import the `make_blobs` function from `sklearn.datasets` and various modules from Matplotlib for data visualization.
# 2. Generating synthetic datasets: The `make_blobs` function is used to generate synthetic datasets with clusters of data points, which is useful for testing and visualization purposes.
# 3. Data visualization: The code uses Matplotlib to visualize the data points on a 2D graph.
#
# If you have any further questions or need more explanations, feel free to ask!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **sklearn.datasets.make_moon**

# %%
# Creating Test DataSets using sklearn.datasets.make_moon
from sklearn.datasets import make_moons
from matplotlib import pyplot as plt
from matplotlib import style

X, y = make_moons(n_samples = 1000, noise = 0.1)
plt.scatter(X[:, 0], X[:, 1], s = 40, color ='g')
plt.xlabel("X")
plt.ylabel("Y")

plt.show()
plt.clf()

# %% [markdown]
# Certainly! Let's break down the provided code step by step:
#
# Step 1: Importing Libraries
# ```python
# from sklearn.datasets import make_moons
# from matplotlib import pyplot as plt
# from matplotlib import style
# ```
# Explanation: In this step, we import the necessary libraries that we will be using later in the code. The code imports three libraries:
# - `sklearn.datasets.make_moons`: This library is used to create synthetic moon-shaped datasets with two classes.
# - `matplotlib.pyplot`: This library is used for data visualization and plotting.
# - `matplotlib.style`: This module provides style settings for the plots.
#
# Step 2: Creating Test Datasets
# ```python
# X, y = make_moons(n_samples=1000, noise=0.1)
# ```
# Explanation: This step creates synthetic datasets using the `make_moons` function from the `sklearn.datasets` module. The function generates random samples that form two interleaving half circles (resembling a moon shape). The parameters used in the function are:
# - `n_samples`: The total number of data points to generate (in this case, 1000).
# - `noise`: The standard deviation of Gaussian noise added to the data points (in this case, 0.1).
#
# Step 3: Plotting the Data Points
# ```python
# plt.scatter(X[:, 0], X[:, 1], s=40, color='g')
# plt.xlabel("X")
# plt.ylabel("Y")
# ```
# Explanation: In this step, we plot the data points on a 2D graph. The `scatter` function from Matplotlib is used for this purpose. The first argument (`X[:, 0]`) corresponds to the x-coordinates of the data points, and the second argument (`X[:, 1]`) corresponds to the y-coordinates of the data points. The parameters used in the `scatter` function are:
# - `s`: The size of the markers (in this case, 40).
# - `color`: The color of the markers (in this case, green - 'g').
# - `xlabel`: Sets the label for the x-axis as "X".
# - `ylabel`: Sets the label for the y-axis as "Y".
#
# Step 4: Displaying the Plot
# ```python
# plt.show()
# ```
# Explanation: This line displays the plot on the screen. Without this line, the plot would not be visible.
#
# Step 5: Clearing the Plot
# ```python
# plt.clf()
# ```
# Explanation: This line clears the current plot, allowing you to create a new plot or avoid any overlap with subsequent plots if you are plotting multiple figures.
#
# Concepts covered in this code:
# 1. Importing libraries: Python allows us to import external libraries to extend its functionality. In this code, we import the `make_moons` function from `sklearn.datasets` and various modules from Matplotlib for data visualization.
# 2. Generating synthetic datasets: The `make_moons` function is used to create synthetic datasets that form two interleaving half circles, representing two classes.
# 3. Data visualization: The code uses Matplotlib to visualize the data points on a 2D graph.
#
# If you have any further questions or need more explanations, feel free to ask!

# %%
# generate 2d classification dataset
X, y = make_classification(n_samples = 100,
                           n_features=2,
                           n_redundant=0,
                           n_informative=2,
                           n_repeated=0,
                           n_classes =3,
                           n_clusters_per_class=1)

# Plot the generated datasets
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

# %% [markdown]
# Absolutely! Let's break down the provided code step by step:
#
# Step 1: Importing Libraries
# ```python
# from sklearn.datasets import make_classification
# from matplotlib import pyplot as plt
# ```
# Explanation: In this step, we import the necessary libraries that we will be using later in the code. The code imports two libraries:
# - `sklearn.datasets.make_classification`: This library is used to create synthetic classification datasets.
# - `matplotlib.pyplot`: This library is used for data visualization and plotting.
#
# Step 2: Creating the Test Dataset
# ```python
# X, y = make_classification(n_samples=100,
#                            n_features=2,
#                            n_redundant=0,
#                            n_informative=2,
#                            n_repeated=0,
#                            n_classes=3,
#                            n_clusters_per_class=1)
# ```
# Explanation: This step creates a synthetic classification dataset using the `make_classification` function from the `sklearn.datasets` module. The function generates random samples with specific characteristics. The parameters used in the function are:
# - `n_samples`: The total number of data points to generate (in this case, 100).
# - `n_features`: The number of features for each data point (in this case, 2).
# - `n_redundant`: The number of redundant features (features that are linear combinations of other features) to add (in this case, 0).
# - `n_informative`: The number of informative features (features that are relevant for the classification) to add (in this case, 2).
# - `n_repeated`: The number of duplicated features (features that are duplicates of other features) to add (in this case, 0).
# - `n_classes`: The number of classes (in this case, 3).
# - `n_clusters_per_class`: The number of clusters per class (in this case, 1).
#
# Step 3: Plotting the Data Points
# ```python
# plt.scatter(X[:, 0], X[:, 1], c=y)
# plt.show()
# ```
# Explanation: In this step, we plot the data points on a 2D graph. The `scatter` function from Matplotlib is used for this purpose. The first argument (`X[:, 0]`) corresponds to the x-coordinates of the data points, and the second argument (`X[:, 1]`) corresponds to the y-coordinates of the data points. The parameter `c=y` specifies the color of the markers based on the `y` array, which contains the class labels for each data point.
#
# Concepts covered in this code:
# 1. Importing libraries: Python allows us to import external libraries to extend its functionality. In this code, we import the `make_classification` function from `sklearn.datasets` and the `matplotlib.pyplot` module for data visualization.
# 2. Generating synthetic classification datasets: The `make_classification` function is used to create synthetic datasets for classification tasks. It allows you to control various characteristics of the generated data, such as the number of features, informative and redundant features, number of classes, etc.
# 3. Data visualization: The code uses Matplotlib to visualize the data points on a 2D graph. The color of each data point represents its class label, allowing us to see the separation between different classes.
#
# If you have any further questions or need more explanations, feel free to ask!

# %% [markdown]
# # **make_multilabel_classification() **

# %%
# Import necessary libraries
from sklearn.datasets import make_multilabel_classification
import pandas as pd
import matplotlib.pyplot as plt

# Generate 2d classification dataset
X, y = make_multilabel_classification(n_samples=500, n_features=2,
									n_classes=2, n_labels=2,
									allow_unlabeled=True,
									random_state=23)
# create pandas dataframe from generated dataset
df = pd.concat([pd.DataFrame(X, columns=['X1', 'X2']),
				pd.DataFrame(y, columns=['Label1', 'Label2'])],
			axis=1)
display(df.head())

# Plot the generated datasets
plt.scatter(df['X1'], df['X2'], c=df['Label1'])
plt.show()

result:-

    X1    X2    Label1    Label2
0    14.0    34.0    0    1
1    30.0    22.0    1    1
2    29.0    19.0    1    1
3    21.0    19.0    1    1
4    16.0    32.0    0    1

# %% [markdown]
# Sure! Let's break down the provided code step by step:
#
# Step 1: Importing Libraries
# ```python
# from sklearn.datasets import make_multilabel_classification
# import pandas as pd
# import matplotlib.pyplot as plt
# ```
# Explanation: In this step, we import the necessary libraries that we will be using later in the code. The code imports three libraries:
# - `sklearn.datasets.make_multilabel_classification`: This library is used to create a synthetic multilabel classification dataset.
# - `pandas`: This library is used for data manipulation and analysis, especially for creating and working with data frames (tables).
# - `matplotlib.pyplot`: This library is used for data visualization and plotting.
#
# Step 2: Generating the Multilabel Classification Dataset
# ```python
# X, y = make_multilabel_classification(n_samples=500, n_features=2,
#                                       n_classes=2, n_labels=2,
#                                       allow_unlabeled=True,
#                                       random_state=23)
# ```
# Explanation: This step creates a synthetic multilabel classification dataset using the `make_multilabel_classification` function from the `sklearn.datasets` module. The function generates random samples with specific characteristics. The parameters used in the function are:
# - `n_samples`: The total number of data points to generate (in this case, 500).
# - `n_features`: The number of features for each data point (in this case, 2).
# - `n_classes`: The number of classes (in this case, 2).
# - `n_labels`: The average number of labels for each instance (in this case, 2).
# - `allow_unlabeled`: Whether to allow instances to have no labels (in this case, True).
# - `random_state`: The random seed for reproducibility (in this case, 23).
#
# Step 3: Creating a Pandas DataFrame from the Generated Dataset
# ```python
# df = pd.concat([pd.DataFrame(X, columns=['X1', 'X2']),
#                pd.DataFrame(y, columns=['Label1', 'Label2'])],
#               axis=1)
# ```
# Explanation: In this step, we create a Pandas DataFrame from the generated dataset. The `pd.DataFrame` function is used to create data frames, and `pd.concat` is used to concatenate the X (features) and y (labels) arrays into a single DataFrame. We give meaningful column names ('X1', 'X2', 'Label1', 'Label2') to the DataFrame for better understanding.
#
# Step 4: Displaying the First Few Rows of the DataFrame
# ```python
# display(df.head())
# ```
# Explanation: This line displays the first few rows of the DataFrame created in the previous step. The DataFrame contains the X (features) and y (labels) values for the synthetic dataset.
#
# Step 5: Plotting the Data Points
# ```python
# plt.scatter(df['X1'], df['X2'], c=df['Label1'])
# plt.show()
# ```
# Explanation: In this step, we plot the data points on a 2D graph. The `scatter` function from Matplotlib is used for this purpose. The x-coordinates are taken from the 'X1' column of the DataFrame, the y-coordinates are taken from the 'X2' column, and the color of the markers is determined by the 'Label1' column, representing one of the multilabels.
#
# Concepts covered in this code:
# 1. Importing libraries: Python allows us to import external libraries to extend its functionality. In this code, we import the `make_multilabel_classification` function from `sklearn.datasets`, the `pandas` library for data manipulation, and the `matplotlib.pyplot` module for data visualization.
# 2. Generating synthetic multilabel classification datasets: The `make_multilabel_classification` function is used to create synthetic datasets for multilabel classification tasks. It allows you to control various characteristics of the generated data, such as the number of features, classes, and labels per instance.
# 3. Data manipulation with Pandas DataFrame: The code uses Pandas to create a DataFrame from the generated data, which is a powerful data structure for data analysis, especially when working with tabular data.
# 4. Data visualization: The code uses Matplotlib to visualize the data points on a 2D graph, where different colors represent different labels for the data instances.
#
# If you have any further questions or need more explanations, feel free to ask!

# %% [markdown]
# # Multilabel feature using **make_sparse_uncorrelated()**

# %%
# Import necessary libraries
from sklearn.datasets import make_sparse_uncorrelated    # same code for Multilabel feature using make_friedman2()
import matplotlib.pyplot as plt
# Generate 1d Regression dataset
X, y = make_sparse_uncorrelated(n_samples = 100, n_features=4, random_state=23)
# Plot the generated datasets
plt.figure(figsize=(12,10))
for i in range(4):
	plt.subplot(2,2, i+1)
	plt.scatter(X[:,i], y)
	plt.xlabel('X'+str(i+1))
	plt.ylabel('Y')
plt.show()

# %% [markdown]
# Sure! Let's go through the provided code step by step:
#
# Step 1: Importing Libraries
# ```python
# from sklearn.datasets import make_sparse_uncorrelated
# import matplotlib.pyplot as plt
# ```
# Explanation: In this step, we import the necessary libraries that we will be using later in the code. The code imports two libraries:
# - `sklearn.datasets.make_sparse_uncorrelated`: This library is used to create a synthetic regression dataset with sparse and uncorrelated features.
# - `matplotlib.pyplot`: This library is used for data visualization and plotting.
#
# Step 2: Generating the Sparse Uncorrelated Regression Dataset
# ```python
# X, y = make_sparse_uncorrelated(n_samples=100, n_features=4, random_state=23)
# ```
# Explanation: This step creates a synthetic regression dataset using the `make_sparse_uncorrelated` function from the `sklearn.datasets` module. The function generates random samples with specific characteristics. The parameters used in the function are:
# - `n_samples`: The total number of data points to generate (in this case, 100).
# - `n_features`: The number of features for each data point (in this case, 4).
# - `random_state`: The random seed for reproducibility (in this case, 23).
#
# Step 3: Plotting the Data Points
# ```python
# plt.figure(figsize=(12, 10))
# for i in range(4):
#     plt.subplot(2, 2, i+1)
#     plt.scatter(X[:, i], y)
#     plt.xlabel('X'+str(i+1))
#     plt.ylabel('Y')
# plt.show()
# ```
# Explanation: In this step, we plot the data points on separate subplots. The `figure` function from Matplotlib is used to create a larger plot area with a size of 12x10 inches. The `for` loop iterates over each feature in the dataset, and for each feature, it creates a subplot using `subplot`. The `scatter` function is used to plot the data points, where the x-coordinates are taken from the i-th feature of the `X` array, and the y-coordinates are taken from the `y` array (the target values). The `xlabel` and `ylabel` functions are used to set the labels for the x-axis and y-axis, respectively, for each subplot.
#
# Concepts covered in this code:
# 1. Importing libraries: Python allows us to import external libraries to extend its functionality. In this code, we import the `make_sparse_uncorrelated` function from `sklearn.datasets` and the `matplotlib.pyplot` module for data visualization.
# 2. Generating synthetic regression datasets: The `make_sparse_uncorrelated` function is used to create synthetic datasets for regression tasks. It allows you to control various characteristics of the generated data, such as the number of features and the level of sparsity and correlation.
# 3. Data visualization: The code uses Matplotlib to visualize the data points on separate subplots. Each subplot shows the relationship between one of the features (X1, X2, X3, X4) and the target variable (Y). Subplots are useful when you want to visualize multiple plots in a single figure.
#
# If you have any further questions or need more explanations, feel free to ask!

# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
#  **Check the outliers:**

# %%
# Box Plots
fig, axs = plt.subplots(9,1,dpi=95, figsize=(7,17))
i = 0
for col in df.columns:
	axs[i].boxplot(df[col], vert=False)
	axs[i].set_ylabel(col)
	i+=1
plt.show()

# %% [markdown]
# Certainly! Let's break down the provided code step by step:
#
# Step 1: Importing Libraries
# ```python
# import matplotlib.pyplot as plt
# ```
# Explanation: In this step, we import the necessary library that we will be using later in the code.
# - `matplotlib.pyplot`: This library is used for data visualization and plotting.
#
# Step 2: Creating Subplots
# ```python
# fig, axs = plt.subplots(9, 1, dpi=95, figsize=(7, 17))
# ```
# Explanation: This step creates a grid of subplots arranged in a column format. The `subplots` function from Matplotlib is used to create the subplots. The parameters used in the function are:
# - `9`: The number of rows in the subplot grid (in this case, 9).
# - `1`: The number of columns in the subplot grid (in this case, 1).
# - `dpi`: Dots per inch, setting the resolution of the figure (in this case, 95).
# - `figsize`: The size of the figure (in this case, 7 inches wide and 17 inches tall).
#
# Step 3: Iterating Through DataFrame Columns and Plotting Box Plots
# ```python
# i = 0
# for col in df.columns:
#     axs[i].boxplot(df[col], vert=False)
#     axs[i].set_ylabel(col)
#     i += 1
# ```
# Explanation: In this step, we iterate through each column of the DataFrame (`df`) and create a box plot for each column on the corresponding subplot. The `boxplot` function is used to create the box plot. The parameters used in the function are:
# - `df[col]`: The data for which the box plot is created, where `col` represents each column in the DataFrame.
# - `vert=False`: This parameter specifies that the box plot should be horizontal (not vertical).
#
# The `set_ylabel` function is used to set the y-axis label for each subplot, and the label is set to the name of the corresponding column in the DataFrame.
#
# Step 4: Displaying the Plot
# ```python
# plt.show()
# ```
# Explanation: This line displays the entire subplot grid with the box plots for each column of the DataFrame. Without this line, the plot would not be visible.
#
# Concepts covered in this code:
# 1. Data visualization with Box Plots: Box plots are a graphical representation of the distribution of data based on a five-number summary (minimum, first quartile, median, third quartile, and maximum). They are useful for visualizing the spread and skewness of the data and identifying potential outliers. In this code, a box plot is created for each column in the DataFrame, allowing us to visualize the distribution of each variable.
#
# 2. Subplots: Subplots are a way to display multiple plots in a single figure, allowing you to compare different visualizations side by side. In this code, we create a grid of subplots, with each subplot displaying a box plot for one of the DataFrame columns.
#
# If you have any further questions or need more explanations, feel free to ask!

# %% [markdown]
# **Drop the outliers**

# %%
# Identify the quartiles
q1, q3 = np.percentile(df['Insulin'], [25, 75])
# Calculate the interquartile range
iqr = q3 - q1
# Calculate the lower and upper bounds
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop the outliers
clean_data = df[(df['Insulin'] >= lower_bound)
				& (df['Insulin'] <= upper_bound)]


# Identify the quartiles
q1, q3 = np.percentile(clean_data['Pregnancies'], [25, 75])
# Calculate the interquartile range
iqr = q3 - q1
# Calculate the lower and upper bounds
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop the outliers
clean_data = clean_data[(clean_data['Pregnancies'] >= lower_bound)
						& (clean_data['Pregnancies'] <= upper_bound)]


# Identify the quartiles
q1, q3 = np.percentile(clean_data['Age'], [25, 75])
# Calculate the interquartile range
iqr = q3 - q1
# Calculate the lower and upper bounds
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop the outliers
clean_data = clean_data[(clean_data['Age'] >= lower_bound)
						& (clean_data['Age'] <= upper_bound)]


# Identify the quartiles
q1, q3 = np.percentile(clean_data['Glucose'], [25, 75])
# Calculate the interquartile range
iqr = q3 - q1
# Calculate the lower and upper bounds
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop the outliers
clean_data = clean_data[(clean_data['Glucose'] >= lower_bound)
						& (clean_data['Glucose'] <= upper_bound)]


# Identify the quartiles
q1, q3 = np.percentile(clean_data['BloodPressure'], [25, 75])
# Calculate the interquartile range
iqr = q3 - q1
# Calculate the lower and upper bounds
lower_bound = q1 - (0.75 * iqr)
upper_bound = q3 + (0.75 * iqr)
# Drop the outliers
clean_data = clean_data[(clean_data['BloodPressure'] >= lower_bound)
						& (clean_data['BloodPressure'] <= upper_bound)]


# Identify the quartiles
q1, q3 = np.percentile(clean_data['BMI'], [25, 75])
# Calculate the interquartile range
iqr = q3 - q1
# Calculate the lower and upper bounds
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop the outliers
clean_data = clean_data[(clean_data['BMI'] >= lower_bound)
						& (clean_data['BMI'] <= upper_bound)]


# Identify the quartiles
q1, q3 = np.percentile(clean_data['DiabetesPedigreeFunction'], [25, 75])
# Calculate the interquartile range
iqr = q3 - q1
# Calculate the lower and upper bounds
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)

# Drop the outliers
clean_data = clean_data[(clean_data['DiabetesPedigreeFunction'] >= lower_bound)
						& (clean_data['DiabetesPedigreeFunction'] <= upper_bound)]

# %% [markdown]
# The code you provided performs outlier removal based on the interquartile range (IQR) method. It identifies the quartiles, calculates the IQR, and determines the lower and upper bounds. Data points outside of these bounds are considered outliers and are subsequently dropped from the dataset.
#
# Let's break down the code and discuss its purpose, when and where to use it, and summarize the expected result:
#
# ```python
# # Identify the quartiles
# q1, q3 = np.percentile(df['Insulin'], [25, 75])
# # Calculate the interquartile range
# iqr = q3 - q1
# # Calculate the lower and upper bounds
# lower_bound = q1 - (1.5 * iqr)
# upper_bound = q3 + (1.5 * iqr)
# # Drop the outliers
# clean_data = df[(df['Insulin'] >= lower_bound) & (df['Insulin'] <= upper_bound)]
# ```
#
# The code begins by identifying the quartiles (`q1` and `q3`) of the 'Insulin' column in the dataframe (`df`) using the `percentile` function from `numpy` (`np.percentile`). The `25` and `75` indicate the desired percentiles.
#
# The interquartile range (IQR) is calculated as the difference between `q3` and `q1`.
#
# The lower bound is computed by subtracting `1.5` times the IQR from `q1`, while the upper bound is calculated by adding `1.5` times the IQR to `q3`.
#
# Outliers are then dropped by selecting the rows in the dataframe where the 'Insulin' values are within the lower and upper bounds. The resulting data is stored in the `clean_data` variable.
#
# The same process is repeated for other columns in the dataframe ('Pregnancies', 'Age', 'Glucose', 'BloodPressure', 'BMI', and 'DiabetesPedigreeFunction') with their respective quartiles and bounds.
#
# The purpose of this code is to identify and remove outliers from specific columns in a dataframe using the interquartile range (IQR) method. Outliers are defined as data points that fall below the lower bound or above the upper bound.
#
# When and Where to Use:
# - Use this code when you want to remove outliers from specific columns in a dataframe based on the IQR method.
# - The IQR method is commonly used in data cleaning and preprocessing to identify and handle outliers.
# - This code can be applied in various data analysis tasks, such as outlier detection, data quality improvement, and enhancing the performance of machine learning algorithms.
#
# Result Summary:
# Executing this code will create new dataframes (`clean_data`) by removing outliers from specific columns in the original dataframe. The outliers are determined based on the IQR method, where data points falling below the lower bound or above the upper bound are excluded from the clean dataset. Each new dataframe will have outliers removed for the respective columns.

# %% [markdown]
# **Correlation**

# %%
#correlation
corr = df.corr()

plt.figure(dpi=130)
sns.heatmap(df.corr(), annot=True, fmt= '.2f')
plt.show()
corr['Outcome'].sort_values(ascending = False)

Result:-

Outcome                     1.000000
Glucose                     0.466581

# %% [markdown]
# Of course! Let's go through the provided code step by step:
#
# Step 1: Importing Libraries
# ```python
# import seaborn as sns
# import matplotlib.pyplot as plt
# ```
# Explanation: In this step, we import the necessary libraries that we will be using later in the code.
# - `seaborn`: This library is used for statistical data visualization, including creating heatmaps.
# - `matplotlib.pyplot`: This library is used for data visualization and plotting.
#
# Step 2: Calculating the Correlation Matrix
# ```python
# corr = df.corr()
# ```
# Explanation: This step calculates the correlation matrix of the DataFrame `df`. The `corr` function computes the pairwise correlation of columns in the DataFrame. The resulting `corr` variable is a DataFrame itself, where each entry represents the correlation between two variables. The diagonal entries are always 1 because they represent the correlation of a variable with itself (which is perfect correlation).
#
# Step 3: Creating and Displaying the Correlation Heatmap
# ```python
# plt.figure(dpi=130)
# sns.heatmap(df.corr(), annot=True, fmt='.2f')
# plt.show()
# ```
# Explanation: In this step, we create a heatmap to visualize the correlation matrix. The `heatmap` function from Seaborn is used for this purpose. The parameters used in the function are:
# - `df.corr()`: The correlation matrix that we calculated in the previous step.
# - `annot=True`: This parameter enables the display of the correlation values on the heatmap.
# - `fmt='.2f'`: This parameter specifies the format of the displayed correlation values (up to two decimal places).
#
# The `plt.figure(dpi=130)` sets the figure size of the heatmap, making it easier to view. The `show()` function displays the heatmap.
#
# Step 4: Displaying the Correlation with the 'Outcome' Variable
# ```python
# corr['Outcome'].sort_values(ascending=False)
# ```
# Explanation: In this step, we extract the correlation values of the 'Outcome' variable (the target variable) with all other variables from the `corr` DataFrame. The code uses indexing and sorting to display the correlation values in descending order. This line gives us the correlation of each variable with the 'Outcome' variable, sorted from the highest correlation to the lowest.
#
# Concepts covered in this code:
# 1. Correlation: Correlation measures the strength and direction of the linear relationship between two variables. It is commonly used to understand the association between variables and can range from -1 (perfect negative correlation) to 1 (perfect positive correlation). A correlation of 0 indicates no linear relationship.
#
# 2. Heatmap: A heatmap is a graphical representation of data where individual values in a matrix are represented as colors. In this code, we use a heatmap to visualize the correlation matrix, where the color intensity represents the strength of correlation between different variables. Heatmaps are particularly useful when working with correlation matrices to quickly identify patterns and relationships in the data.
#
# 3. Seaborn: Seaborn is a data visualization library based on Matplotlib. It provides a high-level interface for creating informative and attractive statistical graphics. In this code, we use Seaborn's `heatmap` function to create the correlation heatmap.
#
# If you have any further questions or need more explanations, feel free to ask!

# %% [markdown]
# ## **Check Outcomes Proportionality**

# %%
plt.pie(df.Outcome.value_counts(),
		labels= ['Diabetes', 'Not Diabetes'],
		autopct='%.f', shadow=True)
plt.title('Outcome Proportionality')
plt.show()

# %% [markdown]
# Sure! Let's break down the provided code step by step:
#
# Step 1: Importing Libraries (Not shown in the provided code)
# ```python
# import matplotlib.pyplot as plt
# ```
# Explanation: In this step, we import the necessary library that we will be using later in the code.
# - `matplotlib.pyplot`: This library is used for data visualization and plotting.
#
# Step 2: Creating a Pie Chart
# ```python
# plt.pie(df.Outcome.value_counts(), labels=['Diabetes', 'Not Diabetes'], autopct='%.f', shadow=True)
# ```
# Explanation: In this step, we create a pie chart to visualize the proportion of different outcomes ('Diabetes' and 'Not Diabetes') in the DataFrame `df`. The `pie` function from Matplotlib is used for this purpose. The parameters used in the function are:
# - `df.Outcome.value_counts()`: This line counts the occurrences of each unique value in the 'Outcome' column of the DataFrame `df`. It creates a Series with the count of 'Diabetes' and 'Not Diabetes' occurrences.
# - `labels=['Diabetes', 'Not Diabetes']`: This parameter provides the labels for the slices of the pie chart, corresponding to the two unique values in the 'Outcome' column.
# - `autopct='%.f'`: This parameter specifies the format for displaying the percentages on each slice of the pie chart. `%.f` means the percentages will be displayed as integers (no decimal places).
# - `shadow=True`: This parameter adds a shadow effect to the pie chart, making it visually appealing.
#
# Step 3: Adding a Title to the Pie Chart
# ```python
# plt.title('Outcome Proportionality')
# ```
# Explanation: In this step, we add a title to the pie chart using the `title` function from Matplotlib. The title of the pie chart is set to 'Outcome Proportionality'.
#
# Step 4: Displaying the Pie Chart
# ```python
# plt.show()
# ```
# Explanation: This line displays the pie chart on the screen. Without this line, the pie chart would not be visible.
#
# Concepts covered in this code:
# 1. Pie Chart: A pie chart is a circular statistical graphic divided into slices to illustrate numerical proportions. Each slice represents a portion of the whole, and the size of each slice is proportional to the quantity it represents. Pie charts are commonly used to show the distribution of categorical data.
#
# 2. Data Visualization: Data visualization is the graphical representation of information and data. It helps to understand patterns, trends, and insights in the data more intuitively. In this code, we use a pie chart to visualize the proportion of 'Diabetes' and 'Not Diabetes' outcomes in the DataFrame.
#
# If you have any further questions or need more explanations, feel free to ask!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  **Normalization **

# %%
# initialising the MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

# learning the statistical parameters for each of the data and transforming
rescaledX = scaler.fit_transform(X)
rescaledX[:5]

# %% [markdown]
# Certainly! Let's go through the provided code step by step:
#
# Step 1: Importing the Necessary Library (Not shown in the provided code)
# ```python
# from sklearn.preprocessing import MinMaxScaler
# ```
# Explanation: In this step, we import the `MinMaxScaler` class from the `sklearn.preprocessing` module. The `MinMaxScaler` is used for scaling data to a specified range, typically between 0 and 1.
#
# Step 2: Initializing the MinMaxScaler
# ```python
# scaler = MinMaxScaler(feature_range=(0, 1))
# ```
# Explanation: In this step, we create an instance of the `MinMaxScaler` class and store it in the variable `scaler`. We also set the `feature_range` parameter to (0, 1), which specifies the desired range for the scaled features. In this case, we want the scaled features to be between 0 and 1.
#
# Step 3: Learning the Statistical Parameters and Transforming the Data
# ```python
# rescaledX = scaler.fit_transform(X)
# ```
# Explanation: In this step, we use the `fit_transform` method of the `MinMaxScaler` object to both learn the statistical parameters of the data and transform the original data (`X`) to its scaled version (`rescaledX`). The `fit_transform` method computes the minimum and maximum values of the data for each feature and scales the data accordingly to the specified range (0 to 1 in this case).
#
# Step 4: Displaying the Scaled Data
# ```python
# rescaledX[:5]
# ```
# Explanation: This line displays the first five rows of the scaled data (`rescaledX`). The `rescaledX` variable now contains the scaled version of the original data (`X`).
#
# Concepts covered in this code:
# 1. Feature Scaling: Feature scaling is a preprocessing technique used to standardize the range of independent features (variables) in the dataset. It is essential when features have different scales, as some machine learning algorithms can be sensitive to the scale of the input features. MinMax scaling is one type of feature scaling that scales the data to a specific range, often (0, 1) in this case.
#
# 2. Min-Max Scaling: Min-Max scaling is a linear transformation technique that scales the data to a specific range. It involves normalizing the data by shifting and scaling each feature such that it lies within the specified range. The formula for Min-Max scaling is:
#
#    `X_scaled = (X - X_min) / (X_max - X_min)`
#
#    Where:
#    - `X` is the original data.
#    - `X_scaled` is the scaled data.
#    - `X_min` is the minimum value of the original data.
#    - `X_max` is the maximum value of the original data.
#
# In the given code, the `MinMaxScaler` scales the data (`X`) to the range (0, 1), ensuring that each feature is transformed to lie within this specified range.
#
# If you have any further questions or need more explanations, feel free to ask!

# %% [markdown]
# **standerdisation**

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler().fit(X)
rescaledX = scaler.transform(X)
rescaledX[:5]

# %% [markdown]
# Of course! Let's break down the provided code step by step:
#
# Step 1: Importing the Necessary Library (Not shown in the provided code)
# ```python
# from sklearn.preprocessing import StandardScaler
# ```
# Explanation: In this step, we import the `StandardScaler` class from the `sklearn.preprocessing` module. The `StandardScaler` is used for standardizing features by removing the mean and scaling to unit variance.
#
# Step 2: Initializing the StandardScaler and Fitting to the Data
# ```python
# scaler = StandardScaler().fit(X)
# ```
# Explanation: In this step, we create an instance of the `StandardScaler` class and store it in the variable `scaler`. Then, we use the `fit` method of the `StandardScaler` object to compute the mean and standard deviation of the data (`X`). The `fit` method learns the statistical parameters necessary for scaling the data.
#
# Step 3: Transforming the Data
# ```python
# rescaledX = scaler.transform(X)
# ```
# Explanation: In this step, we use the `transform` method of the `StandardScaler` object to transform the original data (`X`) into its standardized version (`rescaledX`). The `transform` method applies the standardization to the data using the previously computed mean and standard deviation.
#
# Step 4: Displaying the Standardized Data
# ```python
# rescaledX[:5]
# ```
# Explanation: This line displays the first five rows of the standardized data (`rescaledX`). The `rescaledX` variable now contains the standardized version of the original data (`X`).
#
# Concepts covered in this code:
# 1. Feature Scaling: Feature scaling is a preprocessing technique used to standardize the range of independent features (variables) in the dataset. It is essential when features have different scales, as some machine learning algorithms can be sensitive to the scale of the input features. Standardization is one type of feature scaling that transforms the data to have zero mean and unit variance.
#
# 2. Standardization: Standardization is the process of transforming the data in such a way that it has a mean of 0 and a standard deviation of 1. It is done by subtracting the mean of the data from each data point and then dividing by the standard deviation. The formula for standardization is:
#
#    `X_standardized = (X - mean(X)) / std(X)`
#
#    Where:
#    - `X` is the original data.
#    - `X_standardized` is the standardized data.
#    - `mean(X)` is the mean of the original data.
#    - `std(X)` is the standard deviation of the original data.
#
# In the given code, the `StandardScaler` standardizes the data (`X`) by centering it around 0 and scaling it to have a standard deviation of 1.
#
# If you have any further questions or need more explanations, feel free to ask!

# %% [markdown]
# # **Check the categorical and numerical columns**

# %%
# Categorical columns
cat_col = [col for col in df.columns if df[col].dtype == 'object']
print('Categorical columns :',cat_col)
# Numerical columns
num_col = [col for col in df.columns if df[col].dtype != 'object']
print('Numerical columns :',num_col)


result:-

Categorical columns : ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']
Numerical columns : ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %% [markdown]
# **Handling missing data:**

# %%
round((df1.isnull().sum()/df1.shape[0])*100,2)

# %% [markdown]
# Certainly! Let's go through the provided code step by step:
#
# Step 1: Identifying Categorical Columns
# ```python
# cat_col = [col for col in df.columns if df[col].dtype == 'object']
# print('Categorical columns :', cat_col)
# ```
# Explanation: In this step, we create a list called `cat_col`, which will store the names of all categorical columns in the DataFrame `df`. The code iterates through each column in `df` using a list comprehension. For each column, it checks if the `dtype` (data type) is 'object'. If the data type is 'object', it means the column contains categorical data (e.g., strings). The column names that satisfy this condition are added to the `cat_col` list. Finally, we print the list of categorical columns.
#
# Step 2: Identifying Numerical Columns
# ```python
# num_col = [col for col in df.columns if df[col].dtype != 'object']
# print('Numerical columns :', num_col)
# ```
# Explanation: In this step, we create a list called `num_col`, which will store the names of all numerical columns in the DataFrame `df`. The code iterates through each column in `df` using a list comprehension. For each column, it checks if the `dtype` (data type) is not 'object'. If the data type is not 'object', it means the column contains numerical data (e.g., integers or floats). The column names that satisfy this condition are added to the `num_col` list. Finally, we print the list of numerical columns.
#
# Step 3: Calculating Missing Value Percentages
# ```python
# round((df1.isnull().sum() / df1.shape[0]) * 100, 2)
# ```
# Explanation: In this step, we calculate the percentage of missing values for each column in the DataFrame `df1`. The code uses the `isnull` function to create a boolean DataFrame where `True` represents missing values. The `sum` function then calculates the total number of missing values for each column. The result is divided by the total number of rows in the DataFrame (`df1.shape[0]`) to get the proportion of missing values for each column. Finally, the percentages are rounded to two decimal places using the `round` function.
#
# Concepts covered in this code:
# 1. Data Types: In Python and pandas, data types refer to the type of data stored in a variable or column. Common data types include integers, floats, strings, and objects. In this code, we use the data type information to distinguish between categorical columns (dtype='object') and numerical columns (dtype != 'object').
#
# 2. Categorical and Numerical Data: Categorical data represents qualitative information and is often represented by strings or discrete values. Numerical data, on the other hand, represents quantitative information and is usually represented by integers or real numbers. It is important to distinguish between these data types, as different analysis techniques are applied to each.
#
# 3. Missing Values: Missing values refer to the absence of data in a particular column or variable. Dealing with missing values is an essential step in data preprocessing, as many machine learning algorithms cannot handle missing data directly. In the provided code, we use the `isnull` function to identify missing values and calculate the percentage of missing values for each column.
#
# If you have any further questions or need more explanations, feel free to ask!

# %%
df2 = df1.drop(columns='Cabin')
df2.dropna(subset=['Embarked'], axis=0, inplace=True)
df2.shape

# %% [markdown]
# This code snippet performs the following operations on a DataFrame:
#
# 1. `df2 = df1.drop(columns='Cabin')`: This line creates a new DataFrame `df2` by dropping the column labeled 'Cabin' from the original DataFrame `df1`. The `drop()` function is used to remove specific columns or rows from a DataFrame. In this case, the `columns` parameter is set to 'Cabin' to indicate that the 'Cabin' column should be dropped. The resulting DataFrame is assigned to the variable `df2`.
#
# 2. `df2.dropna(subset=['Embarked'], axis=0, inplace=True)`: This line removes any rows from `df2` that contain missing values (NaN) in the 'Embarked' column. The `dropna()` function is used to drop rows with missing values. The `subset` parameter is set to ['Embarked'] to specify that only the 'Embarked' column should be considered for missing values. The `axis` parameter is set to 0 to indicate that rows should be dropped. The `inplace` parameter is set to True, which means the changes are made directly to `df2` without creating a new DataFrame.
#
# 3. `df2.shape`: This line returns the shape of the DataFrame `df2` as a tuple `(rows, columns)`. The shape attribute provides information about the dimensions of the DataFrame, where the first element represents the number of rows and the second element represents the number of columns. This line is likely used to check the resulting shape of `df2` after dropping the 'Cabin' column and removing rows with missing values in the 'Embarked' column.

# %%
# Mean imputation
df3 = df2.fillna(df2.Age.mean())
# Let's check the null values again
df3.isnull().sum()

# %% [markdown]
# Of course! Let's go through the provided code step by step:
#
# Step 1: Mean Imputation
# ```python
# df3 = df2.fillna(df2.Age.mean())
# ```
# Explanation: In this step, we perform mean imputation on the DataFrame `df2`. Mean imputation is a method of handling missing data by replacing the missing values with the mean of the available values in the same column. Here, we are specifically imputing missing values in the 'Age' column. The `fillna` function is used to fill the missing values with the mean of the 'Age' column. The `mean()` method calculates the mean of the 'Age' column, and then the missing values in that column are replaced with this mean value.
#
# Step 2: Checking for Null Values
# ```python
# df3.isnull().sum()
# ```
# Explanation: In this step, we use the `isnull()` function to create a boolean DataFrame where `True` represents missing values in `df3`. Then, we use the `sum()` method on this DataFrame to count the number of missing values for each column. This line of code helps us check whether there are any remaining missing values after the mean imputation.
#
# Concepts covered in this code:
# 1. Mean Imputation: Mean imputation is a simple method of handling missing data by replacing the missing values with the mean of the available (non-missing) values in the same column. It is a straightforward approach that can work well when the missing data is missing completely at random (MCAR) or missing at random (MAR). However, mean imputation may introduce bias and underestimate the variability in the data if the missing data is not MCAR or MAR.
#
# 2. Handling Missing Values: Missing values are gaps in the data where the information is not available. Handling missing values is an essential step in data preprocessing. Various methods can be used to deal with missing values, such as mean imputation, median imputation, mode imputation, and more advanced techniques like multiple imputation and using machine learning models for imputation.
#
# In the provided code, mean imputation is used to fill the missing values in the 'Age' column with the mean of the available ages. The resulting DataFrame, `df3`, now contains the imputed values, and we use `isnull().sum()` to verify if there are any remaining missing values.
#
# If you have any further questions or need more explanations, feel free to ask!

# %% [markdown]
# **Handling outliers:**

# %%
# calculate summary statistics
mean = df3['Age'].mean()
std = df3['Age'].std()

# Calculate the lower and upper bounds
lower_bound = mean - std*2
upper_bound = mean + std*2

print('Lower Bound :',lower_bound)
print('Upper Bound :',upper_bound)

# Drop the outliers
df4 = df3[(df3['Age'] >= lower_bound)
				& (df3['Age'] <= upper_bound)]

# %% [markdown]
# Of course! Let's go through the provided code step by step:
#
# Step 1: Calculating Summary Statistics - Mean and Standard Deviation
# ```python
# mean = df3['Age'].mean()
# std = df3['Age'].std()
# ```
# Explanation: In this step, we calculate the mean and standard deviation of the 'Age' column in the DataFrame `df3`. The `mean()` method calculates the average (mean) of the values in the 'Age' column, and the `std()` method calculates the standard deviation of the values in the same column. The mean and standard deviation are statistical measures that provide information about the central tendency and dispersion of the data.
#
# Step 2: Calculating Lower and Upper Bounds
# ```python
# lower_bound = mean - std * 2
# upper_bound = mean + std * 2
# ```
# Explanation: In this step, we calculate the lower and upper bounds for detecting outliers. Outliers are data points that lie significantly far away from the mean of the data. In this code, we define outliers as data points that are more than two standard deviations away from the mean. The lower bound is calculated by subtracting two standard deviations from the mean, and the upper bound is calculated by adding two standard deviations to the mean.
#
# Step 3: Printing the Lower and Upper Bounds
# ```python
# print('Lower Bound :', lower_bound)
# print('Upper Bound :', upper_bound)
# ```
# Explanation: These lines print the calculated lower and upper bounds on the screen.
#
# Step 4: Dropping the Outliers
# ```python
# df4 = df3[(df3['Age'] >= lower_bound) & (df3['Age'] <= upper_bound)]
# ```
# Explanation: In this step, we create a new DataFrame called `df4`, which contains only the rows from `df3` where the 'Age' column values are within the calculated lower and upper bounds. This effectively drops the outliers from the original DataFrame `df3`.
#
# Concepts covered in this code:
# 1. Summary Statistics: Summary statistics are numerical measures that provide information about the central tendency and dispersion of a dataset. The mean and standard deviation are two common summary statistics. The mean represents the average value of the data, while the standard deviation measures the spread or dispersion of the data points around the mean.
#
# 2. Outliers: Outliers are data points that deviate significantly from the majority of the data points in a dataset. Outliers can occur due to various reasons, such as errors in data collection or genuine extreme values in the data. Detecting and handling outliers is crucial in data analysis, as they can influence statistical analyses and machine learning models.
#
# In the given code, we calculate the mean and standard deviation of the 'Age' column to detect outliers. Outliers are then dropped from the DataFrame `df3`, and the resulting DataFrame is stored in `df4`.
#
# If you have any further questions or need more explanations, feel free to ask!

# %%
from sklearn.preprocessing import MinMaxScaler

# initialising the MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

# Numerical columns
num_col_ = [col for col in X.columns if X[col].dtype != 'object']
x1 = X
# learning the statistical parameters for each of the data and transforming
x1[num_col_] = scaler.fit_transform(x1[num_col_])
x1.head()

# %% [markdown]
# Certainly! Let's go through the provided code step by step:
#
# Step 1: Importing the Necessary Library (Not shown in the provided code)
# ```python
# from sklearn.preprocessing import MinMaxScaler
# ```
# Explanation: In this step, we import the `MinMaxScaler` class from the `sklearn.preprocessing` module. The `MinMaxScaler` is used for scaling data to a specified range, typically between 0 and 1.
#
# Step 2: Initializing the MinMaxScaler
# ```python
# scaler = MinMaxScaler(feature_range=(0, 1))
# ```
# Explanation: In this step, we create an instance of the `MinMaxScaler` class and store it in the variable `scaler`. We also set the `feature_range` parameter to (0, 1), which specifies the desired range for the scaled features. In this case, we want the scaled features to be between 0 and 1.
#
# Step 3: Identifying Numerical Columns
# ```python
# num_col_ = [col for col in X.columns if X[col].dtype != 'object']
# ```
# Explanation: In this step, we create a list called `num_col_`, which will store the names of all numerical columns in the DataFrame `X`. The code iterates through each column in `X` using a list comprehension. For each column, it checks if the `dtype` (data type) is not 'object'. If the data type is not 'object', it means the column contains numerical data (e.g., integers or floats). The column names that satisfy this condition are added to the `num_col_` list.
#
# Step 4: Creating a Copy of the DataFrame
# ```python
# x1 = X.copy()
# ```
# Explanation: In this step, we create a copy of the DataFrame `X` and store it in a new variable called `x1`. Making a copy of the DataFrame is important because it allows us to preserve the original data in `X` while performing the scaling on `x1`.
#
# Step 5: Learning the Statistical Parameters and Transforming the Data
# ```python
# x1[num_col_] = scaler.fit_transform(x1[num_col_])
# ```
# Explanation: In this step, we use the `fit_transform` method of the `MinMaxScaler` object to both learn the statistical parameters of the data (i.e., minimum and maximum values) and transform the original data (`x1[num_col_]`) to its scaled version. The `fit_transform` method computes the minimum and maximum values of the data for each feature and scales the data accordingly to the specified range (0 to 1 in this case). We apply this scaling only to the numerical columns identified in `num_col_`.
#
# Step 6: Displaying the Scaled Data
# ```python
# x1.head()
# ```
# Explanation: This line displays the first few rows of the scaled DataFrame `x1`. The `x1` DataFrame now contains the scaled version of the original numerical data.
#
# Concepts covered in this code:
# 1. Feature Scaling: Feature scaling is a preprocessing technique used to standardize the range of independent features (variables) in the dataset. It is essential when features have different scales, as some machine learning algorithms can be sensitive to the scale of the input features. MinMax scaling is one type of feature scaling that scales the data to a specific range, often (0, 1) in this case.
#
# 2. Numerical Columns: Numerical columns in a dataset contain numerical data, such as integers or floats. Identifying numerical columns is important when performing feature scaling, as we only want to scale the numerical features and not the categorical features.
#
# In the given code, the `MinMaxScaler` scales the numerical columns in the DataFrame `X` to the range (0, 1). The resulting DataFrame `x1` now contains the scaled version of the original numerical data, while the categorical columns remain unchanged.
#
# If you have any further questions or need more explanations, feel free to ask!

# %%
# For this first, we are supposed to evaluate the absolute(.abs) maximum values of the columns.

import numpy as np
max_vals = np.max(np.abs(df))
max_vals

# %% [markdown]
# Of course! Let's go through the provided code step by step:
#
# Step 1: Importing the Necessary Libraries (Not shown in the provided code)
# ```python
# import numpy as np
# ```
# Explanation: In this step, we import the NumPy library with the alias `np`. NumPy is a powerful library for numerical computing in Python and is commonly used for array operations and mathematical computations.
#
# Step 2: Evaluating the Absolute Maximum Values of Columns
# ```python
# max_vals = np.max(np.abs(df))
# ```
# Explanation: In this step, we calculate the absolute maximum values for each column in the DataFrame `df`. The `np.abs` function is used to calculate the absolute values of all elements in the DataFrame `df`. Then, the `np.max` function is applied to these absolute values to find the maximum value in each column. The resulting values are stored in the `max_vals` variable.
#
# Step 3: Displaying the Absolute Maximum Values
# ```python
# max_vals
# ```
# Explanation: This line of code displays the absolute maximum values for each column in the DataFrame `df`.
#
# Concepts covered in this code:
# 1. NumPy: NumPy (Numerical Python) is a powerful library for numerical computing in Python. It provides support for large, multi-dimensional arrays and matrices, along with a collection of mathematical functions to operate on these arrays efficiently. In this code, we use NumPy to perform element-wise absolute value calculations and find the maximum value for each column in the DataFrame.
#
# 2. Absolute Value: The absolute value of a number is the magnitude of the number without considering its sign. For example, the absolute value of -5 and +5 is both 5. The `np.abs` function in NumPy is used to compute the absolute values of elements in an array or DataFrame.
#
# 3. Maximum Value: The maximum value in a set of numbers is the largest value among them. The `np.max` function in NumPy is used to find the maximum value in an array or DataFrame.
#
# In the given code, the absolute maximum values of each column in the DataFrame `df` are calculated using NumPy functions, and the results are stored in the `max_vals` variable. These values represent the largest magnitude observed in each column, regardless of the sign.
#
# If you have any further questions or need more explanations, feel free to ask!

# %% [markdown]
# **Robust Scaling**
#
# In this method of scaling, we use two main statistical measures of the data.
# ---------------
# Median
# ----------
# # Inter-Quartile Range

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()
scaled_data = scaler.fit_transform(df)
scaled_df = pd.DataFrame(scaled_data,
						columns=df.columns)
print(scaled_df.head())

# %% [markdown]
# Of course! Let's go through the provided code step by step:
#
# Step 1: Importing the Necessary Libraries (Not shown in the provided code)
# ```python
# from sklearn.preprocessing import RobustScaler
# import pandas as pd
# ```
# Explanation: In this step, we import the `RobustScaler` class from the `sklearn.preprocessing` module. The `RobustScaler` is used for scaling data using robust statistics, which are less sensitive to outliers. We also import the `pandas` library with the alias `pd` to work with DataFrames.
#
# Step 2: Initializing the RobustScaler
# ```python
# scaler = RobustScaler()
# ```
# Explanation: In this step, we create an instance of the `RobustScaler` class and store it in the variable `scaler`. The `RobustScaler` scales the data using the interquartile range (IQR), making it robust to the presence of outliers. Robust scaling is particularly useful when the data contains extreme values or outliers that can significantly affect the scaling process.
#
# Step 3: Scaling the Data
# ```python
# scaled_data = scaler.fit_transform(df)
# ```
# Explanation: In this step, we use the `fit_transform` method of the `RobustScaler` object to scale the DataFrame `df`. The `fit_transform` method both learns the statistical parameters (median and IQR) from the data and then transforms the original data using these parameters. The resulting `scaled_data` is an array with the scaled values.
#
# Step 4: Creating a New DataFrame with Scaled Data
# ```python
# scaled_df = pd.DataFrame(scaled_data, columns=df.columns)
# ```
# Explanation: In this step, we create a new DataFrame called `scaled_df` using the `pd.DataFrame()` constructor. The `scaled_data` array is used as the data for the new DataFrame, and the original column names from `df` are assigned to the columns of the new DataFrame.
#
# Step 5: Displaying the Scaled DataFrame
# ```python
# print(scaled_df.head())
# ```
# Explanation: This line of code displays the first few rows of the `scaled_df` DataFrame. The `scaled_df` DataFrame now contains the scaled version of the original data `df`.
#
# Concepts covered in this code:
# 1. Robust Scaling: Robust scaling is a method of feature scaling that uses robust statistics to make the scaling process less sensitive to outliers in the data. Robust scaling is based on the interquartile range (IQR), which is the range between the first quartile (25th percentile) and the third quartile (75th percentile) of the data. By using the IQR, the scaling process is less influenced by extreme values (outliers) and can be more suitable for datasets with non-normal or skewed distributions.
#
# 2. Interquartile Range (IQR): The interquartile range is a measure of statistical dispersion that is based on quartiles. The first quartile (Q1) is the value below which 25% of the data falls, and the third quartile (Q3) is the value below which 75% of the data falls. The IQR is calculated as IQR = Q3 - Q1. In robust scaling, the IQR is used to determine the scale of the data.
#
# In the given code, the `RobustScaler` scales the data in `df` using robust statistics, and the scaled data is stored in the `scaled_df` DataFrame. The resulting `scaled_df` contains the scaled version of the original data, which is now less sensitive to the presence of outliers.
#
# If you have any further questions or need more explanations, feel free to ask!

# %% [markdown]
# # **One Hot Encoding**

# %%
# one Hot Encodingin python

one_hot_encoded_data = pd.get_dummies(data, columns = ['Remarks', 'Gender'])
print(one_hot_encoded_data)

# %% [markdown]
# Of course! Let's go through the provided code step by step:
#
# Step 1: Importing the Necessary Library (Not shown in the provided code)
# ```python
# import pandas as pd
# ```
# Explanation: In this step, we import the `pandas` library with the alias `pd`. `pandas` is a popular library for data manipulation and analysis in Python. It provides powerful data structures, such as DataFrames, which allow for efficient handling of structured data.
#
# Step 2: Performing One-Hot Encoding
# ```python
# one_hot_encoded_data = pd.get_dummies(data, columns=['Remarks', 'Gender'])
# ```
# Explanation: In this step, we perform one-hot encoding on the DataFrame `data` for the columns 'Remarks' and 'Gender'. One-hot encoding is a technique used to convert categorical variables (variables with discrete values) into binary vectors to represent the presence or absence of a particular category.
#
# The `pd.get_dummies()` function is used for one-hot encoding. It takes the DataFrame `data` as the first argument and a list of column names to be one-hot encoded as the `columns` parameter. The function then creates binary vectors for each unique category in the specified columns. For each category, a new column is created, and the value is set to 1 if the category is present for that row and 0 otherwise.
#
# Step 3: Displaying the One-Hot Encoded Data
# ```python
# print(one_hot_encoded_data)
# ```
# Explanation: This line of code displays the DataFrame `one_hot_encoded_data`, which now contains the one-hot encoded representation of the original data `data`.
#
# Concepts covered in this code:
# 1. One-Hot Encoding: One-hot encoding is a technique used to convert categorical variables (also called nominal variables) into binary vectors. Categorical variables have discrete values representing different categories or labels. One-hot encoding is commonly used in machine learning algorithms that cannot directly handle categorical data. By converting categorical variables into binary vectors, we can represent each category as a separate feature (column) with binary values (0 or 1).
#
# 2. pd.get_dummies(): `pd.get_dummies()` is a function provided by the `pandas` library for one-hot encoding. It takes a DataFrame as input and returns a new DataFrame with binary vectors representing the one-hot encoded categorical columns. The `columns` parameter is used to specify which columns in the DataFrame should be one-hot encoded.
#
# In the given code, `pd.get_dummies()` is used to perform one-hot encoding on the DataFrame `data` for the columns 'Remarks' and 'Gender'. The resulting `one_hot_encoded_data` DataFrame contains the binary vectors representing the one-hot encoded categorical columns.
#
# If you have any further questions or need more explanations, feel free to ask!

# %%
# one hot encoding using sklearn
# importing libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder

# Retrieving data
data = pd.read_csv('Employee_data.csv')

# Converting type of columns to category
data['Gender'] = data['Gender'].astype('category')
data['Remarks'] = data['Remarks'].astype('category')


# Assigning numerical values and storing it in another columns
data['Gen_new'] = data['Gender'].cat.codes
data['Rem_new'] = data['Remarks'].cat.codes


# Create an instance of One-hot-encoder
enc = OneHotEncoder()

# Passing encoded columns

enc_data = pd.DataFrame(enc.fit_transform(
	data[['Gen_new', 'Rem_new']]).toarray())

# Merge with main
New_df = data.join(enc_data)

print(New_df)

# %% [markdown]
# Of course! Let's go through the provided code step by step:
#
# Step 1: Importing the Necessary Libraries
# ```python
# import pandas as pd
# import numpy as np
# from sklearn.preprocessing import OneHotEncoder
# ```
# Explanation: In this step, we import the required libraries for performing one-hot encoding using scikit-learn (`sklearn`). `pandas` is used for data manipulation and handling DataFrames, `numpy` is used for numerical computations, and `OneHotEncoder` is used for one-hot encoding.
#
# Step 2: Retrieving Data
# ```python
# data = pd.read_csv('Employee_data.csv')
# ```
# Explanation: In this step, we read the data from a CSV file named 'Employee_data.csv' into a DataFrame called `data`. The data in the CSV file should contain the columns 'Gender' and 'Remarks' that we want to one-hot encode.
#
# Step 3: Converting Columns to Categorical Data Type
# ```python
# data['Gender'] = data['Gender'].astype('category')
# data['Remarks'] = data['Remarks'].astype('category')
# ```
# Explanation: In this step, we convert the columns 'Gender' and 'Remarks' in the DataFrame `data` to the categorical data type using the `astype()` method. Categorical data types are used to represent variables with a limited and fixed set of unique values (categories).
#
# Step 4: Assigning Numerical Values to Categorical Categories
# ```python
# data['Gen_new'] = data['Gender'].cat.codes
# data['Rem_new'] = data['Remarks'].cat.codes
# ```
# Explanation: In this step, we create two new columns 'Gen_new' and 'Rem_new' in the DataFrame `data`. The `cat.codes` property is used to assign numerical values to the categories in the 'Gender' and 'Remarks' columns. The numerical codes assigned represent each unique category in the respective columns.
#
# Step 5: Creating an Instance of OneHotEncoder
# ```python
# enc = OneHotEncoder()
# ```
# Explanation: In this step, we create an instance of the `OneHotEncoder` class. The `OneHotEncoder` is part of scikit-learn's preprocessing module and is used for one-hot encoding categorical features.
#
# Step 6: Performing One-Hot Encoding
# ```python
# enc_data = pd.DataFrame(enc.fit_transform(data[['Gen_new', 'Rem_new']]).toarray())
# ```
# Explanation: In this step, we perform one-hot encoding on the 'Gen_new' and 'Rem_new' columns using the `fit_transform()` method of the `OneHotEncoder` instance `enc`. The `fit_transform()` method takes a 2D array-like input, so we pass a subset of the `data` DataFrame containing only the 'Gen_new' and 'Rem_new' columns using `data[['Gen_new', 'Rem_new']]`.
#
# The output of `fit_transform()` is converted to a NumPy array using `toarray()` and then converted to a DataFrame named `enc_data`. This DataFrame now contains the binary vectors representing the one-hot encoded columns.
#
# Step 7: Merging One-Hot Encoded Data with the Original Data
# ```python
# New_df = data.join(enc_data)
# ```
# Explanation: In this step, we merge the DataFrame `enc_data`, containing the one-hot encoded data, with the original DataFrame `data` using the `join()` method. The `join()` method combines the two DataFrames based on their index, so the one-hot encoded columns are appended to the original DataFrame.
#
# Step 8: Printing the Final DataFrame
# ```python
# print(New_df)
# ```
# Explanation: This line of code prints the DataFrame `New_df`, which now contains the original data with the one-hot encoded columns appended.
#
# Concepts covered in this code:
# 1. One-Hot Encoding: One-hot encoding is a technique used to convert categorical variables (also called nominal variables) into binary vectors. Categorical variables have discrete values representing different categories or labels. One-hot encoding is commonly used in machine learning algorithms that cannot directly handle categorical data. By converting categorical variables into binary vectors, we can represent each category as a separate feature (column) with binary values (0 or 1).
#
# 2. Categorical Data Type: The categorical data type is used in pandas to represent variables with a limited and fixed set of unique values. By using the categorical data type, we can efficiently work with categorical variables and perform operations like assigning numerical codes to the categories.
#
# 3. OneHotEncoder: `OneHotEncoder` is a class from scikit-learn's preprocessing module that is used for one-hot encoding. It can handle multiple columns simultaneously and is a powerful tool for encoding categorical features into binary vectors.
#
# In the given code, the data in the 'Gender' and 'Remarks' columns is one-hot encoded using scikit-learn's `OneHotEncoder`. The resulting DataFrame `New_df` contains the original data along with the one-hot encoded columns.
#
# If you have any further questions or need more explanations, feel free to ask!

# %% [markdown]
# # **SMOTE (Synthetic Minority Oversampling Technique)**
#
# ------------------------------------------------
# SMOTE (synthetic minority oversampling technique) is one of the most commonly used oversampling methods to solve the imbalance problem.
# It aims to balance class distribution by randomly increasing minority class examples by replicating them.
# SMOTE synthesises new minority instances between existing minority instances. It generates the virtual training records by linear interpolation for the minority class. These synthetic training records are generated by randomly selecting one or more of the k-nearest neighbors for each example in the minority class. After the oversampling process, the data is reconstructed and several classification models can be applied for the processed data.

# %%
print("Before OverSampling, counts of label '1': {}".format(sum(y_train == 1)))
print("Before OverSampling, counts of label '0': {} \n".format(sum(y_train == 0)))

# import SMOTE module from imblearn library
# pip install imblearn (if you don't have imblearn in your system)
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 2)
X_train_res, y_train_res = sm.fit_sample(X_train, y_train.ravel())

print('After OverSampling, the shape of train_X: {}'.format(X_train_res.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(y_train_res.shape))

print("After OverSampling, counts of label '1': {}".format(sum(y_train_res == 1)))
print("After OverSampling, counts of label '0': {}".format(sum(y_train_res == 0)))




Result:--

Before OverSampling, counts of label '1': [345]
Before OverSampling, counts of label '0': [199019]

After OverSampling, the shape of train_X: (398038, 29)
After OverSampling, the shape of train_y: (398038, )

After OverSampling, counts of label '1': 199019
After OverSampling, counts of label '0': 199019

# %% [markdown]
# Of course! Let's go through the provided code step by step:
#
# Step 1: Printing the Count of Labels Before OverSampling
# ```python
# print("Before OverSampling, counts of label '1': {}".format(sum(y_train == 1)))
# print("Before OverSampling, counts of label '0': {} \n".format(sum(y_train == 0)))
# ```
# Explanation: In this step, we print the counts of class labels '1' and '0' in the `y_train` array before applying the Oversampling technique. The class labels represent the target variable, where '1' indicates the positive class (e.g., an event happening) and '0' indicates the negative class (e.g., an event not happening).
#
# `sum(y_train == 1)` counts the number of occurrences of label '1' (positive class) in the `y_train` array, and `sum(y_train == 0)` counts the number of occurrences of label '0' (negative class) in the `y_train` array.
#
# Step 2: Importing the SMOTE Module from imblearn Library
# ```python
# from imblearn.over_sampling import SMOTE
# ```
# Explanation: In this step, we import the `SMOTE` (Synthetic Minority Over-sampling Technique) module from the `imblearn` library. SMOTE is a popular method used to perform oversampling for handling imbalanced datasets. It creates synthetic samples of the minority class to balance the class distribution.
#
# Step 3: Applying SMOTE for Oversampling
# ```python
# sm = SMOTE(random_state=2)
# X_train_res, y_train_res = sm.fit_sample(X_train, y_train.ravel())
# ```
# Explanation: In this step, we create an instance of the `SMOTE` class with the parameter `random_state` set to 2. The `random_state` is used to ensure reproducibility of the results.
#
# The `fit_sample()` method of the `SMOTE` object is then applied to the training data (`X_train` and `y_train`). It generates synthetic samples for the minority class (class '1') such that the number of samples in the minority class becomes equal to the number of samples in the majority class (class '0'). The resulting `X_train_res` and `y_train_res` are the oversampled versions of the original training data.
#
# Step 4: Printing the Count of Labels After OverSampling
# ```python
# print('After OverSampling, the shape of train_X: {}'.format(X_train_res.shape))
# print('After OverSampling, the shape of train_y: {} \n'.format(y_train_res.shape))
#
# print("After OverSampling, counts of label '1': {}".format(sum(y_train_res == 1)))
# print("After OverSampling, counts of label '0': {}".format(sum(y_train_res == 0)))
# ```
# Explanation: In this step, we print the shape of the oversampled `X_train_res` and `y_train_res` arrays to check the size of the data after applying the SMOTE technique. The shape should reflect the balanced dataset after oversampling.
#
# We also print the counts of class labels '1' and '0' in the `y_train_res` array after oversampling. Ideally, the counts should be equal after applying SMOTE, indicating that the dataset is now balanced.
#
# Concepts covered in this code:
# 1. Imbalanced Dataset: An imbalanced dataset is a dataset where the class distribution is not equal among the different classes. In binary classification, imbalanced datasets have a significantly larger number of instances in one class (majority class) compared to the other class (minority class).
#
# 2. SMOTE (Synthetic Minority Over-sampling Technique): SMOTE is a technique used to handle imbalanced datasets by oversampling the minority class. It generates synthetic samples for the minority class to balance the class distribution, thereby mitigating the impact of class imbalance on the model's performance.
#
# 3. Random State: The `random_state` parameter is used to set a seed value for generating random numbers. By setting a specific `random_state` value, we ensure reproducibility of the results in cases where randomization is involved.
#
# In the given code, SMOTE is used to oversample the minority class (class '1') in the training data to balance the class distribution. The resulting `X_train_res` and `y_train_res` are the oversampled versions of the original training data. The printed output demonstrates the effect of SMOTE in balancing the dataset.
#
# If you have any further questions or need more explanations, feel free to ask!

# %%
lr1 = LogisticRegression()
lr1.fit(X_train_res, y_train_res.ravel())
predictions = lr1.predict(X_test)

# print classification report
print(classification_report(y_test, predictions))


Result :-

 precision   recall   f1-score  support

           0       1.00      0.98      0.99     85296
           1       0.06      0.92      0.11       147

    accuracy                           0.98     85443
   macro avg       0.53      0.95      0.55     85443
weighted avg       1.00      0.98      0.99     85443

# %% [markdown]
# Of course! Let's go through the provided code step by step:
#
# Step 1: Importing the Necessary Libraries (Not shown in the provided code)
# ```python
# from sklearn.linear_model import LogisticRegression
# from sklearn.metrics import classification_report
# ```
# Explanation: In this step, we import the required libraries. `LogisticRegression` is a class from scikit-learn used for logistic regression, which is a popular algorithm for binary classification. `classification_report` is a function used to generate a classification report that provides various evaluation metrics for a classification model's performance.
#
# Step 2: Creating and Fitting the Logistic Regression Model
# ```python
# lr1 = LogisticRegression()
# lr1.fit(X_train_res, y_train_res.ravel())
# ```
# Explanation: In this step, we create an instance of the `LogisticRegression` class and store it in the variable `lr1`. The `fit()` method is then used to train the logistic regression model on the oversampled training data `X_train_res` and `y_train_res`. The `ravel()` function is used to flatten the `y_train_res` array into a 1-dimensional array if it is not already in that format.
#
# Step 3: Making Predictions
# ```python
# predictions = lr1.predict(X_test)
# ```
# Explanation: In this step, we use the trained logistic regression model (`lr1`) to make predictions on the test data `X_test`. The `predict()` method of the `LogisticRegression` class is used to obtain the predicted class labels for the test data.
#
# Step 4: Printing the Classification Report
# ```python
# print(classification_report(y_test, predictions))
# ```
# Explanation: In this step, we print the classification report, which provides a comprehensive evaluation of the model's performance on the test data. The `classification_report()` function takes the true labels `y_test` and the predicted labels `predictions` as input. It then calculates various metrics, such as precision, recall, F1-score, and support, for each class in the binary classification task.
#
# Concepts covered in this code:
# 1. Logistic Regression: Logistic regression is a type of regression analysis used for predicting binary outcomes (e.g., 0 or 1). It models the relationship between the dependent variable and one or more independent variables using the logistic function, which maps continuous values into probabilities between 0 and 1.
#
# 2. Classification Metrics: The classification report provides various evaluation metrics to assess the performance of a classification model. Some of the key metrics include:
#    - Precision: The proportion of true positive predictions out of all positive predictions made by the model. It measures the accuracy of positive predictions.
#    - Recall (also called Sensitivity or True Positive Rate): The proportion of true positive predictions out of all actual positive instances in the data. It measures the ability of the model to correctly identify positive instances.
#    - F1-score: The harmonic mean of precision and recall. It provides a balance between precision and recall and is useful when there is an imbalanced class distribution.
#    - Support: The number of occurrences of each class in the test data.
#
# In the given code, a logistic regression model is trained on the oversampled training data using `LogisticRegression`, and predictions are made on the test data. The classification report provides a detailed overview of the model's performance, including precision, recall, F1-score, and support for each class in the binary classification task.
#
# If you have any further questions or need more explanations, feel free to ask!

# %% [markdown]
# # **NearMiss Algorithm:**

# %%
print("Before Undersampling, counts of label '1': {}".format(sum(y_train == 1)))
print("Before Undersampling, counts of label '0': {} \n".format(sum(y_train == 0)))

# apply near miss
from imblearn.under_sampling import NearMiss
nr = NearMiss()

X_train_miss, y_train_miss = nr.fit_sample(X_train, y_train.ravel())

print('After Undersampling, the shape of train_X: {}'.format(X_train_miss.shape))
print('After Undersampling, the shape of train_y: {} \n'.format(y_train_miss.shape))

print("After Undersampling, counts of label '1': {}".format(sum(y_train_miss == 1)))
print("After Undersampling, counts of label '0': {}".format(sum(y_train_miss == 0)))

# %% [markdown]
# Of course! Let's go through the provided code step by step:
#
# Step 1: Printing the Count of Labels Before Undersampling
# ```python
# print("Before Undersampling, counts of label '1': {}".format(sum(y_train == 1)))
# print("Before Undersampling, counts of label '0': {} \n".format(sum(y_train == 0)))
# ```
# Explanation: In this step, we print the counts of class labels '1' and '0' in the `y_train` array before applying the undersampling technique. The class labels represent the target variable, where '1' indicates the positive class (e.g., an event happening) and '0' indicates the negative class (e.g., an event not happening).
#
# `sum(y_train == 1)` counts the number of occurrences of label '1' (positive class) in the `y_train` array, and `sum(y_train == 0)` counts the number of occurrences of label '0' (negative class) in the `y_train` array.
#
# Step 2: Importing the NearMiss Module from imblearn Library
# ```python
# from imblearn.under_sampling import NearMiss
# ```
# Explanation: In this step, we import the `NearMiss` module from the `imblearn` library. NearMiss is an undersampling technique used to address imbalanced datasets. It reduces the size of the majority class by selecting samples that are closer to the minority class instances.
#
# Step 3: Applying NearMiss for Undersampling
# ```python
# nr = NearMiss()
# X_train_miss, y_train_miss = nr.fit_sample(X_train, y_train.ravel())
# ```
# Explanation: In this step, we create an instance of the `NearMiss` class and store it in the variable `nr`.
#
# The `fit_sample()` method of the `NearMiss` object is then applied to the training data `X_train` and `y_train`. It reduces the size of the majority class (class '0') by selecting samples that are closest to the minority class (class '1') instances. The resulting `X_train_miss` and `y_train_miss` are the undersampled versions of the original training data.
#
# Step 4: Printing the Count of Labels After Undersampling
# ```python
# print('After Undersampling, the shape of train_X: {}'.format(X_train_miss.shape))
# print('After Undersampling, the shape of train_y: {} \n'.format(y_train_miss.shape))
#
# print("After Undersampling, counts of label '1': {}".format(sum(y_train_miss == 1)))
# print("After Undersampling, counts of label '0': {}".format(sum(y_train_miss == 0)))
# ```
# Explanation: In this step, we print the shape of the undersampled `X_train_miss` and `y_train_miss` arrays to check the size of the data after applying the NearMiss technique. The shape should reflect the reduced size of the majority class after undersampling.
#
# We also print the counts of class labels '1' and '0' in the `y_train_miss` array after undersampling. Ideally, the counts should be balanced after applying NearMiss, indicating that the dataset is now balanced.
#
# Concepts covered in this code:
# 1. Imbalanced Dataset: An imbalanced dataset is a dataset where the class distribution is not equal among the different classes. In binary classification, imbalanced datasets have a significantly larger number of instances in one class (majority class) compared to the other class (minority class).
#
# 2. NearMiss: NearMiss is an undersampling technique used to address imbalanced datasets. It reduces the size of the majority class by selecting samples that are closer to the minority class instances. This technique helps to balance the class distribution and mitigate the impact of class imbalance on the model's performance.
#
# In the given code, NearMiss is used to undersample the majority class (class '0') in the training data to balance the class distribution. The resulting `X_train_miss` and `y_train_miss` are the undersampled versions of the original training data. The printed output demonstrates the effect of NearMiss in balancing the dataset.
#
# If you have any further questions or need more explanations, feel free to ask!
