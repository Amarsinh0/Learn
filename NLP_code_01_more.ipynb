# %% [markdown]
# <a href="https://colab.research.google.com/github/Amarsinh0/MY-NOTES/blob/main/NLP_code_01_more.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Step1 Data Cleaning in NLP**

# %%
import pandas as pd
text = ['This is the NLP TASKS ARTICLE written by ABhishek Jaiswal** ','IN this article ''ll be explaining various DATA-CLEANING techniques',
 'So stay tuned for FURther More &&','Nah I don"t think he goes to usf, he lives around']
df = pd.DataFrame({'text':text})

# %% [markdown]
# Sure! Let's break down the code step by step:
#
# Step 1: Import the pandas library
# ```python
# import pandas as pd
# ```
#
# In this line, we are importing the pandas library and giving it an alias "pd". This library is widely used for data manipulation and analysis in Python.
#
# Step 2: Create a list of text
# ```python
# text = ['This is the NLP TASKS ARTICLE written by ABhishek Jaiswal** ',
#         'IN this article ll be explaining various DATA-CLEANING techniques',
#         'So stay tuned for FURther More &&',
#         'Nah I don"t think he goes to usf, he lives around']
# ```
#
# Here, we have created a list called "text" that contains four elements, each representing a text string. These strings seem to be sentences or phrases.
#
# Step 3: Create a DataFrame using pandas
# ```python
# df = pd.DataFrame({'text': text})
# ```
#
# In this line, we use the pandas DataFrame constructor to create a DataFrame object. We pass a dictionary as an argument, where the key is 'text' and the value is the previously defined list of text strings. This creates a DataFrame with a single column named 'text', and each element of the 'text' column corresponds to one of the strings from the 'text' list.
#
# Now, the DataFrame 'df' looks like this:
#
# ```
#                                                 text
# 0  This is the NLP TASKS ARTICLE written by ABhi...
# 1  IN this article ll be explaining various DAT...
# 2            So stay tuned for FURther More &&
# 3  Nah I don"t think he goes to usf, he lives around
# ```
#
# Each string from the 'text' list is placed in its own row in the DataFrame.
#
# That's it! You have successfully created a pandas DataFrame named 'df' with the provided text data. This DataFrame can be further used for data analysis, text processing, or any other tasks you might need.

# %% [markdown]
# # **Lowercasing**
# The method lower()converts all uppercase characters into lowercase and returns.
#
# Applying lower() method using lambda function

# %%
df['lower'] = df['text'].apply(lambda x: " ".join(x.lower()  for x in x.split()))
df

# %% [markdown]
# Certainly! Let's break down the code step by step:
#
# Step 1: Accessing the 'text' column in the DataFrame
# ```python
# df['text']
# ```
#
# In this line, we are accessing the 'text' column of the DataFrame 'df'. The 'text' column contains the text strings we discussed earlier.
#
# Step 2: Using the `split()` method to break each text string into words
# ```python
# x.split()
# ```
#
# Here, we are using the `split()` method on each text string 'x' to break it into individual words. This will produce a list of words for each text string.
#
# Step 3: Converting words to lowercase
# ```python
# x.lower()
# ```
#
# We apply the `lower()` method to each word in the list generated in Step 2. This converts all the words to lowercase. The reason for doing this could be to standardize the text and make it case-insensitive for further processing.
#
# Step 4: Joining the lowercase words back into a sentence
# ```python
# " ".join(x.lower() for x in x.split())
# ```
#
# In this part, we use a list comprehension to convert the list of lowercase words back into a single string (sentence). The `join()` method is used to concatenate these words using a space as a separator, effectively forming the sentence again but with all lowercase letters.
#
# Step 5: Creating a new column 'lower' in the DataFrame
# ```python
# df['lower'] = df['text'].apply(lambda x: " ".join(x.lower() for x in x.split()))
# ```
#
# In this line, we use the `apply()` method on the 'text' column of the DataFrame. The `apply()` method is used to apply a function to each element of the column. Here, the function is defined using a lambda function that takes each text string 'x', converts it to lowercase, splits it into words, and then joins them back to form a new sentence with all lowercase letters.
#
# Finally, we assign this new sentence to a new column called 'lower' in the DataFrame 'df'.
#
# That's it! After running this code, the DataFrame 'df' will have an additional column named 'lower', which contains the original text strings, but with all lowercase letters. This can be useful for various purposes, such as making text processing tasks easier or ensuring consistency in the text data.

# %% [markdown]
# Certainly! Let's explore the concepts related to the provided code:
#
# 1. DataFrame Manipulation: The code is working with a Pandas DataFrame ('df') to add a new column named 'lower'. DataFrame manipulation involves various operations to modify, extract, or add data to a DataFrame.
#
# 2. Lambda Function: The code uses a lambda function to apply a specific operation to each element of the 'text' column. Lambda functions are anonymous functions in Python that can be used for simple, one-line operations.
#
# 3. apply() method: The 'apply()' method in Pandas is used to apply a function along a specific axis of the DataFrame. In this case, it applies the lambda function to each element of the 'text' column.
#
# 4. String Manipulation: The lambda function inside 'apply()' performs string manipulation on each sentence in the 'text' column. Specifically, it converts the text to lowercase using the 'lower()' method.
#
# 5. List Comprehension: The lambda function utilizes list comprehension to split each sentence into individual words and then rejoin them back into a single string. List comprehensions provide a concise way to create lists in Python.
#
# 6. Tokenization: The process of splitting each sentence into words is called tokenization. Tokenization is an essential step in natural language processing (NLP) to convert text into manageable units (tokens).
#
# 7. Lowercasing: Lowercasing involves converting all characters in a string to lowercase. It is a common preprocessing step in NLP to ensure uniformity and remove case-related variations.
#
# 8. Joining Strings: The 'join()' method is used to join the list of words back into a single string. Here, the individual words of each sentence are joined with spaces to form a sentence in lowercase.
#
# 9. Text Preprocessing: The code is performing a basic text preprocessing step by converting the text to lowercase. Text preprocessing involves various tasks to clean, normalize, and transform text data before using it in NLP tasks.
#
# 10. Creating a New DataFrame Column: The code creates a new column named 'lower' and populates it with the processed text. Adding a new column to a DataFrame allows you to store and work with additional information.
#
# 11. DataFrame Column Access: The code uses DataFrame column access ('df['text']') to retrieve the 'text' column data and then assigns the processed data to the new 'lower' column.
#
# 12. In-Place Modification: The code modifies the DataFrame 'df' in-place by adding the 'lower' column to it. The original 'df' DataFrame is updated with the new column.
#
# Overall, the code demonstrates how to perform text preprocessing (lowercasing) on the 'text' column of a Pandas DataFrame using lambda functions, list comprehension, and the 'apply()' method. This step can be part of a larger data preprocessing pipeline when working with text data in NLP tasks.

# %% [markdown]
# # **Punctuation Removal**
# Removing punctuation(*,&,%#@#()) is a crucial step since punctuation doesn’t add any extra information or value to our data. Hence, removing punctuation reduces the data size; therefore, it improves computational efficiency.

# %% [markdown]
# Sure! Let's break down the code step by step:
#
# Step 1: Importing the 'string' module
# ```python
# import string
# ```
#
# In this line, we are importing the 'string' module, which provides various constants and functions for working with strings. In this code, we are interested in the 'string.punctuation' constant, which contains all punctuation characters.
#
# Step 2: Understanding the 'string.punctuation' constant
# ```python
# string.punctuation
# ```
#
# This line displays the contents of the 'string.punctuation' constant, which contains a string with all punctuation characters commonly used in English. For reference, the characters in 'string.punctuation' are: `!"#$%&'()*+,-./:;<=>?@[\\]^_`{|}~`.
#
# Step 3: Applying lambda function to remove punctuation from text
# ```python
# df.text.apply(lambda x: "".join(i for i in x if i not in string.punctuation))
# ```
#
# Here, we are using the 'apply()' method on the 'text' column of the DataFrame 'df'. The 'apply()' method is used to apply a function to each element of the column.
#
# In this case, the function is defined using a lambda function. For each text string 'x', the lambda function iterates over each character 'i' in the string 'x'. It uses a list comprehension to create a new string by joining only those characters that are not present in the 'string.punctuation' constant. This effectively removes all punctuation characters from each text string.
#
# Step 4: Displaying the result after removing punctuation
# ```
# 0    This is the NLP TASKS ARTICLE written by ABhis...
# 1    IN this article ll be explaining various DATAC...
# 2                      So stay tuned for FURther More
# 3      Nah I dont think he goes to usf he lives around
# Name: text, dtype: object
# ```
#
# After executing the code, you get the DataFrame 'df' with the 'text' column updated. The 'text' column now contains the same text strings as before, but with all punctuation characters removed.
#
# Step 5: Alternative way using regular expression (re)
# ```python
# import re
# df.text.apply(lambda x: ''.join(re.findall(r'[a-zA-Z+" "]', x)))
# ```
#
# This part demonstrates an alternative method to remove punctuation from text using the 're' module (regular expression). We use the 'findall()' function from the 're' module to extract only alphanumeric characters and spaces (including the double quotes "+", to preserve quoted text) from each text string. The lambda function and 'apply()' method are used as before to apply this operation to each element of the 'text' column.
#
# The result is the same as the previous method, with all punctuation characters removed from each text string in the 'text' column of the DataFrame 'df'.
#
# That's it! You have learned two ways to remove punctuation from text data in pandas DataFrame using either the 'string' module or the 're' module.

# %% [markdown]
# Certainly! Let's delve into the technical concepts related to the provided code:
#
# 1. String Module: The code starts by importing the `string` module, which is a standard Python module that provides various functions and constants related to string manipulation. In this code, it uses the constant `string.punctuation`.
#
# 2. string.punctuation: `string.punctuation` is a constant defined in the `string` module that contains all the ASCII punctuation characters. These characters are typically used to represent punctuation symbols like periods, commas, exclamation marks, question marks, etc.
#
# 3. Pandas DataFrame: The code assumes the presence of a Pandas DataFrame named `df`. A DataFrame is a two-dimensional tabular data structure provided by the Pandas library, widely used for data manipulation, analysis, and cleaning tasks.
#
# 4. DataFrame.apply(): The `.apply()` method in Pandas is used to apply a function along a specific axis of the DataFrame. In this case, it is being used to apply a function to each element of the 'text' column of the DataFrame.
#
# 5. Lambda Function: The code uses a lambda function, an anonymous function, to process each element of the 'text' column. The lambda function is a concise way of defining a small function without explicitly giving it a name.
#
# 6. List Comprehension: In both versions of the code, the lambda function uses list comprehension to iterate over the characters (or tokens) of each element in the 'text' column and perform some operations on them.
#
# 7. Removing Punctuation: The primary purpose of the code is to remove punctuation characters from the text data. Both versions of the code achieve this by eliminating the punctuation characters found in the `string.punctuation` constant from each element of the 'text' column.
#
# 8. Regular Expressions (re): In the second version of the code, the `re` module is imported. `re` stands for regular expressions, which are powerful tools used for pattern matching and text manipulation. It is utilized to extract specific patterns from the text.
#
# 9. re.findall(): The `re.findall()` function is used to find all non-overlapping occurrences of the pattern specified by the regular expression in a given text. In this code, the regular expression `[a-zA-Z+" "]` matches all alphabetical characters (both lowercase and uppercase) and the double quotes, along with spaces.
#
# 10. Cleaning Text Data: The code demonstrates a common preprocessing task in text analysis, where unwanted characters, such as punctuation marks, are removed or replaced to prepare the text data for further analysis or modeling.
#
# 11. Text Processing: Both versions of the code involve text processing, which is a critical step in natural language processing (NLP) tasks. Text processing includes tokenization, cleaning, stemming, lemmatization, and more.
#
# 12. Data Cleaning and Transformation: The code showcases data cleaning and transformation techniques on textual data, which is essential to improve data quality and facilitate meaningful analysis.
#
# Overall, the code snippet demonstrates how to remove punctuation characters from text data in a Pandas DataFrame using simple iteration, list comprehension, and regular expressions. Understanding and applying these concepts are valuable skills for working with text data in data science and NLP projects.

# %% [markdown]
# # **Stop Words Removal**

# %% [markdown]
# Sure! Let's break down the code step by step:
#
# Step 1: Install the NLTK library
# ```python
# !pip install nltk
# ```
#
# In this line, the code is using the 'pip' package manager to install the Natural Language Toolkit (NLTK) library. NLTK is a powerful library for working with human language data and is widely used for tasks like text processing, tokenization, stemming, and more.
#
# Step 2: Import the necessary modules from NLTK
# ```python
# import nltk
# nltk.download('stopwords')
# ```
#
# Here, we import the 'nltk' module and download the 'stopwords' dataset. Stopwords are common words that do not carry significant meaning and are often removed from text during text processing tasks. NLTK provides a collection of stopwords for various languages, and we are downloading the English stopwords in this code.
#
# Step 3: Access the English stopwords
# ```python
# from nltk.corpus import stopwords
# allstopwords = stopwords.words('english')
# ```
#
# In this part, we are importing the English stopwords from NLTK and storing them in a list called 'allstopwords'. This list contains words like 'the', 'is', 'and', 'to', etc., which are considered stopwords and will be removed from our text data.
#
# Step 4: Applying a lambda function to filter out stopwords
# ```python
# df.lower.apply(lambda x: " ".join(i for i in x.split() if i not in allstopwords))
# ```
#
# Here, we are using the 'apply()' method on the 'lower' column of the DataFrame 'df'. The 'apply()' method is used to apply a function to each element of the column.
#
# In this case, the function is defined using a lambda function. For each text string 'x' in the 'lower' column, the lambda function first splits the text into individual words using 'split()'. Then, it iterates over each word 'i' in the text and checks if it is not present in the 'allstopwords' list (i.e., it is not a stopword). If the word is not a stopword, it is included in the result.
#
# Step 5: Result after removing stopwords
# ```
# 0         nlp tasks article written abhishek jaiswal**
# 1    article explaining various data-cleaning techn...
# 2                                        stay tuned &&
# 3               nah don"t think goes usf, lives around
# Name: lower, dtype: object
# ```
#
# After executing the code, you get the DataFrame 'df' with the 'lower' column updated. The 'lower' column now contains the same text strings as before, but with stopwords removed. As you can see, common words like 'This', 'is', 'the', 'by', 'in', 'be', 'for', 'So', 'I', 'll', 'be', 'various', 'for', 'More', 'I', 'don't', 'he', 'to', 'he' have been removed, as they are stopwords.
#
# That's it! You have learned how to use the NLTK library to filter out stopwords from your text data, which can be useful for text analysis and natural language processing tasks.

# %% [markdown]
# Certainly! Let's explore the technical and theoretical concepts related to the provided code:
#
# Technical Concepts:
#
# 1. NLTK (Natural Language Toolkit): NLTK is a popular Python library for natural language processing (NLP). It provides various tools, resources, and corpora for working with human language data. In this code, NLTK is used to access and download the stopwords corpus.
#
# 2. Installation with pip: The code begins with a commented line (`# !pip install nltk`). This line suggests installing the NLTK library using the pip package manager. Pip is a package manager used to install Python packages from the Python Package Index (PyPI).
#
# 3. Downloading Data with NLTK: The `nltk.download()` function is used to download specific resources or corpora from NLTK. In this code, it downloads the 'stopwords' corpus, which contains commonly occurring words (e.g., "and," "the," "is") that are often removed during text preprocessing.
#
# 4. Stopwords: Stopwords are words that are frequently used in a language but generally do not contribute much to the meaning of a sentence. They are commonly removed from text data during text preprocessing to reduce noise and improve the efficiency of NLP tasks.
#
# 5. stopword.words(): The `stopwords.words('english')` function call retrieves a list of stopwords from the NLTK's 'stopwords' corpus for the English language. These stopwords will be used to filter out unnecessary words from the text data.
#
# 6. DataFrame Column Access: The code uses DataFrame column access (`df.lower`) to retrieve the 'lower' column data from the DataFrame 'df'.
#
# 7. Lambda Function: The code applies a lambda function to each element of the 'lower' column using the `.apply()` method. The lambda function is an anonymous function that processes each text (sentence) individually.
#
# 8. List Comprehension: Inside the lambda function, list comprehension is used to split each sentence into words and then filter out the stopwords. The resulting words are joined back together into a single string using the `join()` method.
#
# Theoretical Concepts:
#
# 1. Text Preprocessing: The primary objective of the code is text preprocessing. Text preprocessing is a crucial step in NLP that involves cleaning, normalizing, and transforming raw text data into a suitable format for analysis or modeling. Removing stopwords is one such preprocessing step.
#
# 2. Stopword Removal: The process of removing stopwords from text data is called stopword removal. These stopwords, which are common and less meaningful words, are excluded to focus on the significant words that convey the actual content of the text.
#
# 3. Tokenization: The code implicitly performs tokenization, which is the process of splitting text into smaller units called tokens. In this case, tokens are words. Tokenization is a fundamental step before applying any text analysis techniques.
#
# 4. Text Cleaning: Removing stopwords is a text cleaning operation that aims to eliminate noise and reduce the dimensionality of the text data. It helps to focus on the important words and improve the efficiency of NLP algorithms.
#
# 5. Text Normalization: The code performs a form of text normalization by converting all words to lowercase (using the 'lower' column). Text normalization aims to bring text data to a common format, reducing variations due to case differences.
#
# By understanding these concepts, you can better appreciate the role of NLTK, stopwords, text preprocessing, and the data cleaning process in NLP tasks. The code demonstrates a typical pipeline for preparing text data for analysis or machine learning applications.

# %% [markdown]
# # **Spelling Correction**

# %%
#Install textblob library
# !pip install textblob
from textblob import TextBlob

# %% [markdown]
# Most of the text data extracted in customer reviews, blogs, or tweets have some chances of spelling mistakes.
#
# Correcting spelling mistakes improves model accuracy.
#
# There are various libraries to fix spelling mistakes, but the most convenient method is to use a text blob.
#
# The method correct() works on text blob objects and corrects the spelling mistakes.

# %% [markdown]
# Sure! Let's break down the code step by step:
#
# Step 1: Install the textblob library
# ```python
# !pip install textblob
# ```
#
# In this line, the code is using the 'pip' package manager to install the TextBlob library. TextBlob is a powerful library for processing textual data and provides various functions for tasks like sentiment analysis, part-of-speech tagging, noun phrase extraction, and more.
#
# Step 2: Import the necessary modules from textblob
# ```python
# from textblob import TextBlob
# ```
#
# Here, we are importing the TextBlob class from the textblob module. The TextBlob class is the main entry point for using TextBlob functionalities.
#
# Step 3: Applying TextBlob's spelling correction
# ```python
# df['lower'].apply(lambda x: str(TextBlob(x).correct()))
# ```
#
# In this part, we are using the 'apply()' method on the 'lower' column of the DataFrame 'df'. The 'apply()' method is used to apply a function to each element of the column.
#
# In this case, the function is defined using a lambda function. For each text string 'x' in the 'lower' column, the lambda function creates a TextBlob object from the text using `TextBlob(x)`. The TextBlob object allows us to perform various text processing operations.
#
# One of the operations is spelling correction, and we are using `.correct()` to apply spelling correction to the text. This will try to fix common spelling mistakes and return the corrected version of the text.
#
# Step 4: Result after applying spelling correction
# ```
# 0    this is the nap tasks article written by abhis...
# 1    in this article ll be explaining various data-...
# 2                    so stay tuned for further more &&
# 3      ah i don"t think he goes to us, he lives around
# Name: lower, dtype: object
# ```
#
# After executing the code, you get the DataFrame 'df' with the 'lower' column updated. The 'lower' column now contains the same text strings as before, but with spelling corrections applied. For example, 'nap' was corrected to 'nap tasks', 'abhishek' was corrected to 'abhis', and 'data-cleaning' was corrected to 'data-cleaning techniques'.
#
# Note: The accuracy of spelling correction may vary based on the input text and the context. TextBlob's spelling correction might not always produce perfect results.
#
# In summary, you have learned how to use the TextBlob library to apply spelling correction to text data. This can be helpful in cleaning and improving the quality of text before performing various natural language processing tasks.

# %% [markdown]
# Certainly! Let's explore the technical and theoretical concepts related to the provided code:
#
# Technical Concepts:
#
# 1. TextBlob Library: TextBlob is a Python library built on top of NLTK and Pattern libraries. It provides a simple API for common natural language processing (NLP) tasks, such as part-of-speech tagging, noun phrase extraction, sentiment analysis, and more.
#
# 2. Installation with pip: The first line in the code (`#Install textblob library !pip install textblob`) is a comment that suggests installing the TextBlob library using the pip package manager. Pip is a package manager used to install Python packages from the Python Package Index (PyPI).
#
# 3. Importing TextBlob: After installing the TextBlob library, the code imports the `TextBlob` class from the `textblob` module. The `TextBlob` class is the main entry point for using the TextBlob library.
#
# 4. DataFrame Column Access: The code uses DataFrame column access (`df['lower']`) to retrieve the data from the 'lower' column of the DataFrame 'df'. This column contains the text in lowercase, which will be processed by TextBlob.
#
# 5. Lambda Function: The code applies a lambda function to each element of the 'lower' column using the `.apply()` method. The lambda function processes each text (sentence) individually using the TextBlob library.
#
# 6. TextBlob Correct(): Inside the lambda function, the `TextBlob(x).correct()` method is used to perform spelling correction on the text. The `correct()` method attempts to correct misspelled words in the text.
#
# Theoretical Concepts:
#
# 1. Spelling Correction: The main objective of the code is to perform spelling correction on the text data. Spelling correction is the process of automatically identifying and fixing misspelled words in a given text.
#
# 2. TextBlob Correct(): TextBlob utilizes probabilistic algorithms to identify potential corrections for misspelled words. It suggests the most probable correct word based on the context of the surrounding words in the text.
#
# 3. NLP Libraries: TextBlob is an example of an NLP library that provides high-level abstractions and tools to perform various NLP tasks without the need for intricate implementations. These libraries save time and effort for NLP practitioners and researchers.
#
# 4. Preprocessing and Data Cleaning: The code assumes that the text data has already been preprocessed (lowercased) before using TextBlob for spelling correction. Preprocessing is essential to ensure consistent results and to avoid interference from case variations.
#
# 5. Language Model: TextBlob uses its internal language model and spelling correction algorithms to determine the correct words based on the context of the text. The language model is trained on a large corpus of text data to generalize spelling patterns.
#
# 6. Context-based Correction: Spelling correction in TextBlob is context-based, meaning it takes into account the words surrounding a misspelled word to propose a likely correction. This contextual approach improves the accuracy of the correction.
#
# By understanding these concepts, you can appreciate how TextBlob leverages its language model to provide spelling correction functionality and how it can be a useful tool for various NLP tasks, including text cleaning and preprocessing. However, it is essential to note that no automated spelling correction method is perfect, and manual verification may still be required for critical applications.

# %% [markdown]
# # **Tokenization**
# Tokenization means splitting text into meaningful unit words. There are sentence tokenizers as well as word tokenizers.
#
# Sentence tokenizer splits a paragraph into meaningful sentences, while word tokenizer splits a sentence into unit meaningful words. Many libraries can perform tokenization like SpaCy, NLTK, and TextBlob.
#
# Splitting a sentence on space to get individual unit words can be understood as tokenization.

# %%
import nltk
nltk.download('punkt')
mystring = "My favorite animal is cat"
nltk.word_tokenize(mystring)
mystring.split(" ")

# %% [markdown]
# Sure, let's break down the given code step by step and explain each line of code:
#
# 1. Import the nltk library:
#
# ```python
# import nltk
# ```
#
# 2. Download the nltk tokenizer data:
#
# ```python
# nltk.download('punkt')
# ```
#
# - `nltk.download('punkt')`: This line downloads the necessary data for the nltk tokenizer, which is used for splitting text into words and sentences.
#
# 3. Define a string:
#
# ```python
# mystring = "My favorite animal is cat"
# ```
#
# 4. Tokenize the string using nltk:
#
# ```python
# nltk.word_tokenize(mystring)
# ```
#
# - `nltk.word_tokenize`: This function takes a string as input and tokenizes it into individual words. Tokenization is the process of breaking down a text into smaller units, such as words or sentences.
#
# 5. Split the string using the space character:
#
# ```python
# mystring.split(" ")
# ```
#
# - `mystring.split(" ")`: This method splits the string `mystring` into a list of words based on the space character ' '. It is an alternative way to tokenize the string, but it may not handle punctuation or other forms of whitespace as effectively as the `nltk.word_tokenize` function.
#
# Concepts covered:
# 1. Tokenization: The code demonstrates tokenization using the nltk library. Tokenization is an important preprocessing step in natural language processing (NLP) that breaks down text into smaller units (tokens) such as words or sentences. It allows for easier analysis and processing of text data.
# 2. nltk.word_tokenize: The `nltk.word_tokenize` function is a part of the Natural Language Toolkit (nltk) library in Python. It is commonly used for word tokenization in NLP tasks. It handles more complex cases, such as punctuation and contractions, better than simple string splitting.
# 3. String splitting: The code also shows an alternative way to split a string into words using the `split` method. In this case, the space character ' ' is used as the delimiter to split the string into words. However, this method may not be as robust as `nltk.word_tokenize` in handling different forms of whitespace or punctuation.

# %% [markdown]
# # **Stemming**
# Stemming is converting words into their root word using some set of rules irrespective of meaning. I.e.,
#
#
#
# “fish,” “fishes,” and “fishing” are stemmed into “fish”.
# “playing”, “played”,” plays” are stemmed into “play”.
# Stemming helps to reduce the vocabulary hence improving the accuracy.
# The simplest way to perform stemming is to use NLTK or a TextBlob library.
#
#
#
# NLTK provides various stemming techniques, i.e. Snowball, PorterStemmer; different technique follows different sets of rules to convert words into their root word.

# %%
import nltk
# “article” is stemmed into “articl“, “lives“ — -> “live“.
from nltk.stem import PorterStemmer
st = PorterStemmer()
df['text'].apply(lambda x:" ".join([st.stem(word) for word in x.split()]))

# %% [markdown]
# Sure, let's break down the given code step by step and explain each line of code:
#
# 1. Import the nltk library:
#
# ```python
# import nltk
# ```
#
# 2. Import the PorterStemmer from nltk.stem:
#
# ```python
# from nltk.stem import PorterStemmer
# ```
#
# 3. Create a PorterStemmer object:
#
# ```python
# st = PorterStemmer()
# ```
#
# - `PorterStemmer`: This class from nltk.stem represents the Porter Stemmer, which is a widely used stemming algorithm in natural language processing. Stemming is the process of reducing words to their root or base form, by removing suffixes and prefixes, and keeping only the core meaning of the word. For example, "running" and "runs" would both be stemmed to "run".
#
# 4. Apply stemming to the 'text' column of a DataFrame:
#
# ```python
# df['text'].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
# ```
#
# - `df['text']`: This selects the 'text' column of a DataFrame named 'df', which contains the text data to be stemmed.
# - `.apply()`: This method applies a function to each element of the selected column.
# - `lambda x: ...`: This is an anonymous function that takes each element (text) in the 'text' column and applies the stemming operation on it.
# - `x.split()`: This splits the text into individual words, creating a list of words.
# - `[st.stem(word) for word in x.split()]`: This list comprehension applies the Porter Stemmer (`st.stem()`) to each word in the list created by splitting the text. It stems each word separately.
# - `" ".join(...)`: This joins the stemmed words back into a single string, separated by spaces. The resulting string is the stemmed version of the original text.
#
# Concepts covered:
# 1. Stemming: The code demonstrates stemming using the Porter Stemmer from the nltk library. Stemming is a preprocessing technique used in natural language processing to reduce words to their base or root form. It helps in reducing the dimensionality of text data and is useful for tasks like text classification, information retrieval, and topic modeling. However, stemming may result in words that are not actual dictionary words, as it only removes prefixes and suffixes without considering the context of the word.
# 2. nltk.stem.PorterStemmer: The `PorterStemmer` class is a part of the Natural Language Toolkit (nltk) library in Python. It implements the Porter stemming algorithm, which is one of the most widely used stemming algorithms.
# 3. Lambda function and apply: In this code, the `apply()` method is used to apply a lambda function to each element of the 'text' column in the DataFrame. The lambda function applies stemming to each word in the text, and then the stemmed words are joined back together to form the stemmed version of the text. Lambda functions are short, anonymous functions that can be used for simple operations like this, especially when used in combination with pandas' `apply()` method.

# %% [markdown]
# # **Lemmatization**
# Lemmatization is converting words into their root word using vocabulary mapping. Lemmatization is done with the help of part of speech and its meaning; hence it doesn’t generate meaningless root words. But lemmatization is slower than stemming.
#
# “good,” “better,” or “best” is lemmatized into “good“.
# Lemmatization will convert all synonyms into a single root word. i.e. * “automobile“, “car“,” truck“,” vehicles” are lemmatized into “automobile”.
# Lemmatization usually gets better results.
# Ie. leafs Stemmed to. leaves stemmed to leav while leafs , leaves lemmatized to leaf
#
# Lemmatization can be done using NLTK, TextBlob library.
#
# # **Wordnet Lemmatizer with NLTK**
# Wordnet is an large, freely and publicly available lexical database for the English language aiming to establish structured semantic relationships between words.
#
# It offers lemmatization capabilities as well and is one of the earliest and most commonly used lemmatizers.
#
# NLTK offers an interface to it, but you have to download it first in order to use it. Follow the below instructions to install nltk and download wordnet.

# %%
# In order to lemmatize, you need to create an instance of the WordNetLemmatizer() and call the lemmatize() function on a single word.

import nltk
from nltk.stem import WordNetLemmatizer

# Init the Wordnet Lemmatizer
lemmatizer = WordNetLemmatizer()

# Lemmatize Single Word
print(lemmatizer.lemmatize("bats"))

# %% [markdown]
# Sure, let's break down the given code step by step and explain each line of code:
#
# 1. Download WordNet through NLTK in the Python console:
#
# ```python
# import nltk
# nltk.download('wordnet')
# nltk.download('omw-1.4')
# ```
#
# - `nltk.download('wordnet')`: This line downloads the WordNet corpus from the Natural Language Toolkit (NLTK) library. WordNet is a lexical database used for natural language processing tasks, such as lemmatization and word sense disambiguation.
# - `nltk.download('omw-1.4')`: This line downloads the Open Multilingual Wordnet (OMW) version 1.4. WordNet is available in multiple languages, and this download specifically provides access to the multilingual WordNet.
#
# 2. Import necessary libraries and modules:
#
# ```python
# import nltk
# from nltk.stem import WordNetLemmatizer
# ```
#
# - `nltk.stem.WordNetLemmatizer`: This class from the NLTK library represents the WordNet Lemmatizer, which is used for lemmatization. Lemmatization is the process of converting words to their base or root form, known as the lemma.
#
# 3. Initialize the WordNet Lemmatizer:
#
# ```python
# lemmatizer = WordNetLemmatizer()
# ```
#
# - `WordNetLemmatizer()`: This creates an instance of the WordNet Lemmatizer and stores it in the variable `lemmatizer`. We will use this instance to perform lemmatization on words.
#
# 4. Lemmatize a single word:
#
# ```python
# print(lemmatizer.lemmatize("bats"))
# ```
#
# - `lemmatizer.lemmatize("bats")`: This line calls the `lemmatize()` function on the WordNet Lemmatizer instance (`lemmatizer`) to lemmatize the word "bats". Lemmatization will attempt to convert "bats" to its base form, which is "bat".
#
# Concepts covered:
# 1. WordNet: The code demonstrates downloading WordNet using NLTK, which is a lexical database that provides information about words and their relationships. WordNet is commonly used for lemmatization, word sense disambiguation, and other NLP tasks.
# 2. Lemmatization: Lemmatization is the process of reducing words to their base or root form (lemma). It is an important preprocessing step in natural language processing because it reduces words to their core meaning, which can help in improving the accuracy of various NLP tasks.
# 3. nltk.stem.WordNetLemmatizer: The `WordNetLemmatizer` class is a part of the Natural Language Toolkit (nltk) library in Python. It implements lemmatization using WordNet's database of lemmas and their corresponding word forms.
# 4. Lemmatize(): The `lemmatize()` function of the `WordNetLemmatizer` class is used to lemmatize a single word. It takes the word as input and returns its lemma as the output. In the given example, the word "bats" is lemmatized to "bat".

# %%
import textblob
from textblob import Word
df['lower'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))

# %% [markdown]
# Sure, let's break down the given code step by step and explain each line of code:
#
# 1. Import necessary libraries and modules:
#
# ```python
# import textblob
# from textblob import Word
# ```
#
# - `textblob`: This import statement brings in the textblob library, which is a powerful library for processing textual data, including tasks like sentiment analysis, part-of-speech tagging, and lemmatization.
# - `textblob.Word`: This import statement imports the Word class from the textblob library. The Word class is used for lemmatization.
#
# 2. Apply lemmatization to the 'lower' column of a DataFrame:
#
# ```python
# df['lower'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
# ```
#
# - `df['lower']`: This selects the 'lower' column of a DataFrame named 'df', which presumably contains text data in lowercase (since it's called 'lower').
# - `.apply()`: This method applies a function to each element of the selected column.
# - `lambda x: ...`: This is an anonymous function that takes each element (text) in the 'lower' column and applies lemmatization to it.
# - `x.split()`: This splits the text into individual words, creating a list of words.
# - `[Word(word).lemmatize() for word in x.split()]`: This list comprehension applies lemmatization using the `Word` class on each word in the list created by splitting the text. It lemmatizes each word separately using the `lemmatize()` method.
# - `" ".join(...)`: This joins the lemmatized words back into a single string, separated by spaces. The resulting string is the lemmatized version of the original text.
#
# Concepts covered:
# 1. TextBlob: The code demonstrates using the TextBlob library for lemmatization. TextBlob is a simple natural language processing library built on top of NLTK and Pattern. It provides an easy-to-use API for common NLP tasks.
# 2. Lemmatization: Lemmatization is the process of converting words to their base or root form, known as the lemma. It reduces inflected or derived words to their base or dictionary form, which helps in normalization and analysis of text data.
# 3. TextBlob.Word: The `Word` class from TextBlob is used for lemmatization. It provides the `lemmatize()` method to find the lemma of a word. The lemmatize function is based on WordNet's lemmatization rules.
# 4. lambda function and apply: In this code, the `apply()` method is used to apply a lambda function to each element of the 'lower' column in the DataFrame. The lambda function applies lemmatization to each word in the text, and then the lemmatized words are joined back together to form the lemmatized version of the text. Lambda functions are short, anonymous functions that can be used for simple operations like this, especially when used in combination with pandas' `apply()` method.

# %% [markdown]
# ### **Lemmatize the whole dataset.**

# %%
import textblob
from textblob import Word
df['lower'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))

# %% [markdown]
# Certainly! Let's break down the given code step by step and explain each line:
#
# 1. Import necessary libraries and modules:
#
# ```python
# import textblob
# from textblob import Word
# ```
#
# - `textblob`: This import statement brings in the textblob library, which is a powerful library for processing textual data, including tasks like sentiment analysis, part-of-speech tagging, and lemmatization.
# - `textblob.Word`: This import statement imports the Word class from the textblob library. The Word class is used for lemmatization.
#
# 2. Apply lemmatization to the 'lower' column of a DataFrame:
#
# ```python
# df['lower'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
# ```
#
# - `df['lower']`: This selects the 'lower' column of a DataFrame named 'df', which presumably contains text data in lowercase (since it's called 'lower').
# - `.apply()`: This method applies a function to each element of the selected column.
# - `lambda x: ...`: This is an anonymous function that takes each element (text) in the 'lower' column and applies lemmatization to it.
# - `x.split()`: This splits the text into individual words, creating a list of words.
# - `[Word(word).lemmatize() for word in x.split()]`: This list comprehension applies lemmatization using the `Word` class on each word in the list created by splitting the text. It lemmatizes each word separately using the `lemmatize()` method.
# - `" ".join(...)`: This joins the lemmatized words back into a single string, separated by spaces. The resulting string is the lemmatized version of the original text.
#
# Concepts covered:
# 1. TextBlob: The code demonstrates using the TextBlob library for lemmatization. TextBlob is a simple natural language processing library built on top of NLTK and Pattern. It provides an easy-to-use API for common NLP tasks.
# 2. Lemmatization: Lemmatization is the process of converting words to their base or root form, known as the lemma. It reduces inflected or derived words to their base or dictionary form, which helps in normalization and analysis of text data.
# 3. TextBlob.Word: The `Word` class from TextBlob is used for lemmatization. It provides the `lemmatize()` method to find the lemma of a word. The lemmatize function is based on WordNet's lemmatization rules.
# 4. lambda function and apply: In this code, the `apply()` method is used to apply a lambda function to each element of the 'lower' column in the DataFrame. The lambda function applies lemmatization to each word in the text, and then the lemmatized words are joined back together to form the lemmatized version of the text. Lambda functions are short, anonymous functions that can be used for simple operations like this, especially when used in combination with pandas' `apply()` method.

# %% [markdown]
# # **Step 2 Exploratory Data Analysis**
# So far, we have seen the various text preprocessing techniques that must be done after getting the raw data. After cleaning our data, we now can perform exploratory data analysis and explore and understand the text data.
#
# **Word Frequency in Data**
#
# Counting the unique words in our data gives an idea about our data’s most frequent, least frequent terms. Often we drop the least frequent comments to make our model training more generalized.
#
# nltk provides Freq_dist class to calculate word frequency, and it takes a bag of words as input.

# %%
all_words = []
for sentence in df['lower']:
    all_words.extend(sentence.split())

# %% [markdown]
# Of course! Let's break down the given code step by step and explain each line:
#
# 1. Create an empty list to store all the words:
#
# ```python
# all_words = []
# ```
#
# 2. Iterate through the 'lower' column of the DataFrame and split sentences into words:
#
# ```python
# for sentence in df['lower']:
#     all_words.extend(sentence.split())
# ```
#
# - `for sentence in df['lower']:`: This loop iterates over each element (sentence) in the 'lower' column of the DataFrame 'df'.
# - `sentence.split()`: This splits each sentence into words, creating a list of words from the sentence.
# - `all_words.extend(...)`: This line extends the 'all_words' list by adding the words from the split sentence. The 'extend' method is used to append all the elements from the list created by splitting the sentence to the 'all_words' list.
#
# After running this code, the list 'all_words' will contain all the words from the 'lower' column of the DataFrame, where each word is a separate element in the list.
#
# Concepts covered:
# 1. List: The 'all_words' list is a common data structure used to store a collection of items (in this case, words). Lists are versatile and can hold elements of different types. They are denoted by square brackets [ ] and allow for easy manipulation of data.
# 2. Loop: The 'for' loop is used to iterate over each element (sentence) in the 'lower' column of the DataFrame. In each iteration, the sentence is split into words, and those words are added to the 'all_words' list using the 'extend' method.
# 3. Splitting strings: The `split()` method is used to split a string into a list of words based on the default separator (space). It is a useful method for breaking down sentences or text into individual words, facilitating further text processing and analysis.

# %%
import nltk
from nltk import FreqDist
nltk.FreqDist(all_words)

# %% [markdown]
# Certainly! Let's break down the given code step by step and explain each line:
#
# 1. Import necessary libraries and modules:
#
# ```python
# import nltk
# ```
#
# 2. Import the FreqDist class from nltk:
#
# ```python
# from nltk import FreqDist
# ```
#
# - `nltk.FreqDist`: This class from the NLTK library represents a frequency distribution. It is used to count the occurrences of items in a collection (e.g., words in a text) and store the results as a dictionary-like object with items and their corresponding frequencies.
#
# 3. Create a frequency distribution of all the words:
#
# ```python
# nltk.FreqDist(all_words)
# ```
#
# - `nltk.FreqDist(...)`: This line creates a frequency distribution of all the words stored in the 'all_words' list.
#
# The frequency distribution will contain each unique word as a key and its corresponding frequency (the number of times it appears) as the value.
#
# Concepts covered:
# 1. Frequency Distribution: The code demonstrates using the FreqDist class from NLTK to create a frequency distribution. Frequency distributions are useful for counting the occurrences of items in a collection and understanding the distribution of those items. In this case, we are creating a frequency distribution of words in a text, which helps us analyze the word frequency in the given data.
# 2. NLTK: The Natural Language Toolkit (NLTK) is a powerful library for natural language processing tasks in Python. It provides a wide range of tools and resources for text analysis, including tokenization, lemmatization, stemming, and more.
# 3. FreqDist: The `FreqDist` class is a part of the NLTK library. It provides methods to create and manipulate frequency distributions. Once created, a frequency distribution can be used to get the count of individual items (words in this case) and calculate various statistics related to the distribution.
# 4. all_words list: The 'all_words' list is presumably a list containing all the words from the text data. The frequency distribution is created based on the occurrences of these words in the text. This list would have been created using the previous code snippet where words were split from the sentences in the 'lower' column of the DataFrame and added to the 'all_words' list.

# %% [markdown]
# # **Word Cloud**
# Wordcloud is the pictorial representation of the word frequency of the dataset.WordCloud is easier to understand and gives a better idea about our textual data.
#
# The library wordcloud Let us create a word cloud in a few lines of code.
#
# importing libraries :

# %%
from wordcloud import WordCloud
from wordcloud import STOPWORDS
import matplotlib.pyplot as plt


# We can draw a word cloud using text containing all the words of our data.

words = []
for message in df['lower']:
    words.extend([word for word in message.split() if word not in STOPWORDS])

wordcloud = WordCloud(width = 1000, height = 500).generate(" ".join(words))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# Certainly! Let's break down the given code step by step and explain each line:
#
# 1. Import necessary libraries and modules:
#
# ```python
# from wordcloud import WordCloud
# from wordcloud import STOPWORDS
# import matplotlib.pyplot as plt
# ```
#
# 2. Create an empty list to store words:
#
# ```python
# words = []
# ```
#
# 3. Iterate through the 'lower' column of the DataFrame and filter out stopwords:
#
# ```python
# for message in df['lower']:
#     words.extend([word for word in message.split() if word not in STOPWORDS])
# ```
#
# - `for message in df['lower']:`: This loop iterates over each element (message) in the 'lower' column of the DataFrame 'df'.
# - `message.split()`: This splits each message into words, creating a list of words from the message.
# - `if word not in STOPWORDS`: This condition is used to check if the word is not in the STOPWORDS set. STOPWORDS are common words (like "and," "the," "in," etc.) that are typically removed during text analysis to focus on more meaningful words.
# - `words.extend(...)`: This line extends the 'words' list by adding words that are not in the STOPWORDS set. The `extend` method is used to append all the elements from the list comprehension to the 'words' list.
#
# 4. Create a WordCloud:
#
# ```python
# wordcloud = WordCloud(width=1000, height=500).generate(" ".join(words))
# ```
#
# - `WordCloud`: This class from the wordcloud library represents a Word Cloud, which is a data visualization technique used to visualize the most frequent words in a text corpus. The Word Cloud will show the words that appear more frequently in larger font size.
# - `width=1000, height=500`: These parameters set the width and height of the Word Cloud visualization to be generated.
#
# 5. Display the Word Cloud:
#
# ```python
# plt.imshow(wordcloud, interpolation='bilinear')
# plt.axis("off")
# plt.show()
# ```
#
# - `plt.imshow(...)`: This function from the matplotlib.pyplot module is used to display the Word Cloud visualization.
# - `interpolation='bilinear'`: This parameter sets the interpolation method to 'bilinear', which ensures smooth rendering of the Word Cloud image.
# - `plt.axis("off")`: This line is used to turn off the axis of the plot, so the axes and ticks are not displayed.
# - `plt.show()`: This function displays the Word Cloud plot.
#
# Concepts covered:
# 1. Word Cloud: A Word Cloud is a popular visualization technique used to display the most frequent words in a text corpus. The size of each word in the Word Cloud is proportional to its frequency in the text.
# 2. STOPWORDS: The STOPWORDS set contains common words that are often removed during text analysis because they do not contribute significantly to the meaning or analysis of the text. By filtering out these words, we can focus on more relevant and meaningful words in the Word Cloud.
# 3. wordcloud.WordCloud: The `WordCloud` class from the wordcloud library is used to create the Word Cloud visualization. It takes various parameters to control the appearance and layout of the Word Cloud.
# 4. matplotlib.pyplot: The `matplotlib.pyplot` module is used for plotting and data visualization. In this code, it is used to display the Word Cloud image generated using the WordCloud class.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# background_color = 'white' using this parameter, we can change the background colour of the word cloud.
#
# collocations = False Keeping it as False will ignore the collocation words. Collocations are those words that are formed by those words which occur together. I.e. pay attention, home works, etc.
#
# We can adjust height and width using the parameters.
#
# Note : Before making the word cloud always remove the stopwords.

# %% [markdown]
# # **Table of Contents**
# Feature Extraction
# Bag of Word model
# Concept of n-grams
# Count Vectorizer method
# TF-IDF
# Word Embedding with python code
# ## **Why do we need feature extraction?**
# Feature Engineering is a very key part of Natural Language Processing. as we all know algorithms and machines can’t understand characters or words or sentences hence we need to encode these words into some specific form of numerical in order to interact with algorithms or machines. we can’t feed the text data containing words /sentences/characters to a machine learning model.
#
# There are various ways to perform feature extraction. some popular and mostly used are:-
#
# 1)  Bag of Words model
#
# 2)  TF-IDF
#
# # **1. Bag of Words(BOW) model**
#
# It’s the simplest model, Image a sentence as a bag of words here The idea is to take the whole text data and count their frequency of occurrence. and map the words with their frequency. This method doesn’t care about the order of the words, but it does care how many times a word occurs and the default bag of words model treats all words equally.
#
# ![image.png](data:image/png;base64,...)
#
# The feature vector will have the same word length. Words that come multiple times get higher weightage making this model biased, which has been fixed with TF-IDF discussed further.
#
# Implementation of BOW model using Python:
#
# sklearn provides all the necessary feature extraction techniques with easy implementation.

# %%
import sklearn
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()


# Importing CountVectorizer in order to implement the Bag of words model.
import pandas as pd
text = ["i love NLP",
        "NLP is future",
        "i will learn in 2 months"]
vectorizer = CountVectorizer()
count_matrix = vectorizer.fit_transform(text)
count_array = count_matrix.toarray()
df = pd.DataFrame(data=count_array,columns = vectorizer.get_feature_names())
print(df)



   future  in  is  learn  love  months  nlp  will
0       0   0   0      0     1       0    1     0
1       1   0   1      0     0       0    1     0
2       0   1   0      1     0       1    0     1

# %% [markdown]
# Sure, let's break down the given code step by step and explain each line:
#
# 1. Import necessary libraries and modules:
#
# ```python
# import sklearn
# from sklearn.feature_extraction.text import CountVectorizer
# ```
#
# 2. Create a list of text data:
#
# ```python
# text = ["i love NLP",
#         "NLP is future",
#         "i will learn in 2 months"]
# ```
#
# 3. Create an instance of CountVectorizer:
#
# ```python
# vectorizer = CountVectorizer()
# ```
#
# - `CountVectorizer`: This class from scikit-learn (sklearn) is used to convert a collection of text documents (in this case, the 'text' list) into a matrix of token counts. It is part of the feature extraction module in scikit-learn.
#
# 4. Fit and transform the text data using CountVectorizer:
#
# ```python
# count_matrix = vectorizer.fit_transform(text)
# ```
#
# - `vectorizer.fit_transform(text)`: This line fits the CountVectorizer on the 'text' data and then transforms the text data into a sparse matrix of token counts. Each row in the matrix represents a document (text data), and each column represents a unique word (token) in the corpus.
#
# 5. Convert the sparse matrix to a dense array and create a DataFrame:
#
# ```python
# count_array = count_matrix.toarray()
# df = pd.DataFrame(data=count_array, columns=vectorizer.get_feature_names())
# ```
#
# - `count_matrix.toarray()`: This line converts the sparse matrix 'count_matrix' into a dense array 'count_array'. The dense array representation is more readable and can be converted into a pandas DataFrame.
# - `pd.DataFrame(data=count_array, columns=vectorizer.get_feature_names())`: This line creates a DataFrame named 'df' using the 'count_array' data and assigns the corresponding feature names (unique words/tokens) as column names. Each row in the DataFrame represents a document, and each cell contains the count of the corresponding word in that document.
#
# 6. Print the DataFrame:
#
# ```python
# print(df)
# ```
#
# - This line simply prints the DataFrame 'df', which contains the counts of words (tokens) in each document (text data).
#
#
# The method fit_transform()first fits the data to countVectorizer and then converts it into features
# The method get_features_name() returns the vocabulary of unique words.
# Once countVectorizer has fitted it would not update the Bag of words.
# Stopwords we can pass a list of stopwords or specify language name ie {‘english’}to exclude stopwords from the vocabulary.
#
#
# Concepts covered:
# 1. Bag of Words Model: The code demonstrates the implementation of the Bag of Words model using CountVectorizer from scikit-learn. The Bag of Words model represents text data as a matrix of token counts, disregarding grammar and word order. Each row in the matrix represents a document, and each column represents a unique word (token) in the entire corpus.
# 2. CountVectorizer: The `CountVectorizer` class is part of scikit-learn's feature extraction module. It is used to convert text data into numerical representations, suitable for machine learning algorithms. In this case, it converts the list of text data into a sparse matrix of token counts, where each cell represents the frequency of a word (token) in the corresponding document.
# 3. Sparse Matrix: The output of `fit_transform()` using CountVectorizer is a sparse matrix, which is a memory-efficient representation of large matrices containing mostly zero values. In this case, the sparse matrix represents the token counts in the 'text' data, where each row corresponds to a document and each column corresponds to a word. The sparse matrix contains non-zero values representing the frequency of each word in the corresponding document.

# %%
# After fitting the countVectorizer we can transform any text into the fitted vocabulary.


text2 = ['I love NLP but can not learn in 2 months']
vectorizer.transform(text2).toarray()

array([[0, 1, 0, 1, 1, 1, 1, 0]])

# %% [markdown]
# Certainly! Let's break down the given code step by step and explain each line:
#
# 1. Define a new list containing a single text:
#
# ```python
# text2 = ['I love NLP but can not learn in 2 months']
# ```
#
# 2. Transform the new text using the fitted CountVectorizer:
#
# ```python
# vectorizer.transform(text2).toarray()
# ```
#
# - `vectorizer.transform(text2)`: This line transforms the new text 'text2' into a matrix of token counts using the already fitted CountVectorizer. The vocabulary of the CountVectorizer is based on the training data, so it already knows which words to include in the matrix and in what order.
# - `.toarray()`: This method converts the sparse matrix obtained from `transform()` into a dense array. The dense array representation is more readable and shows the token counts for the new text.
#
# 3. Display the result as a dense array:
#
# ```
# array([[0, 1, 0, 1, 1, 1, 1, 0]])
# ```
#
# - The result is a dense array that represents the token counts for the new text 'text2'. The array contains eight columns, where each column corresponds to a unique word (token) in the fitted vocabulary of the CountVectorizer. The values in the array represent the frequency of each word in the text 'text2'. In this example, the word 'love' and 'learn' appear once, while the other words do not appear in the text.
#
# Concepts covered:
# 1. Transforming New Text: Once the CountVectorizer is fitted on the training data, it learns the vocabulary of the words and their corresponding indices. After fitting, we can use `transform()` to convert any new text into the matrix of token counts, using the same vocabulary obtained during fitting.
# 2. Token Counts: The output of `transform()` is a matrix representing the token counts for the new text. Each row of the matrix corresponds to a document, and each column corresponds to a unique word (token) in the vocabulary. The values in the matrix represent the frequency of each word in the corresponding document.
# 3. Sparse vs. Dense Array: The initial output of `transform()` is a sparse matrix, which is a memory-efficient representation of large matrices containing mostly zero values. By using `.toarray()`, we convert the sparse matrix into a dense array that shows the actual token counts for the new text in a more readable format. The dense array contains integer values representing the frequency of each word in the text.

# %% [markdown]
# In the above example of the BOW model, each word is considered as one feature but there are some problems with this model.
#
# For example: assume that we have the word “not bad” and if we split this into “not” and “bad” then it will lose out its meaning. “not bad” is similar to “good” to some extent. we don’t want to split such words which lose their meaning after splitting. here the idea of n-grams comes into the picture.
#
# Unigrams are the single unique words in a sentence
# Bigrams are the combination of 2 words ie “not bad”,” turn off”.
# Trigrams are the combination of 3 words.
# While implementing the BOW model using CounVectorizer we can include n-grams in vocabulary using ngram_range parameter.
#
# Implementation of the BOW model with n-gram:
#
# ngram_range =(1, 1) means only unigrams,
#
# ngram_range = (1, 2) means unigrams with bigrams
#
# ngram_range=(2, 2) means only bigrams.

# %%
text = ["food was not bad"]
vectorizer = CountVectorizer(ngram_range = (1,2))
count_matrix = vectorizer.fit_transform(text)
count_array = count_matrix.toarray()
df = pd.DataFrame(data=count_array,columns = vectorizer.get_feature_names())
print(df)

   bad  food  food was  not  not bad  was  was not
0    1     1         1    1        1    1        1

# %% [markdown]
# Certainly! Let's break down the given code step by step and explain each line:
#
# 1. Define a list containing a single text:
#
# ```python
# text = ["food was not bad"]
# ```
#
# 2. Create an instance of CountVectorizer with n-gram range (1, 2):
#
# ```python
# vectorizer = CountVectorizer(ngram_range=(1, 2))
# ```
#
# - `CountVectorizer`: This class from scikit-learn (sklearn) is used to convert a collection of text documents (in this case, the 'text' list) into a matrix of token counts. It is part of the feature extraction module in scikit-learn.
# - `ngram_range=(1, 2)`: This parameter specifies the range of n-grams to consider during vectorization. An n-gram is a sequence of 'n' consecutive words. Here, n-gram range (1, 2) means that both single words (unigrams) and pairs of consecutive words (bigrams) will be considered.
#
# 3. Fit and transform the text data using CountVectorizer with n-gram range:
#
# ```python
# count_matrix = vectorizer.fit_transform(text)
# ```
#
# - `vectorizer.fit_transform(text)`: This line fits the CountVectorizer on the 'text' data and then transforms the text data into a sparse matrix of token counts, considering the specified n-gram range.
#
# 4. Convert the sparse matrix to a dense array and create a DataFrame:
#
# ```python
# count_array = count_matrix.toarray()
# df = pd.DataFrame(data=count_array, columns=vectorizer.get_feature_names())
# ```
#
# - `count_matrix.toarray()`: This line converts the sparse matrix 'count_matrix' into a dense array 'count_array'. The dense array representation is more readable and can be converted into a pandas DataFrame.
# - `pd.DataFrame(data=count_array, columns=vectorizer.get_feature_names())`: This line creates a DataFrame named 'df' using the 'count_array' data and assigns the corresponding feature names (unigrams and bigrams) as column names. Each row in the DataFrame represents a document, and each cell contains the count of the corresponding n-gram in that document.
#
# 5. Print the DataFrame:
#
# ```python
# print(df)
# ```
#
# - This line simply prints the DataFrame 'df', which contains the counts of unigrams and bigrams in the text.
#
# Concepts covered:
# 1. N-grams: N-grams are contiguous sequences of 'n' items from a given sample of text or speech. In this code, the n-gram range (1, 2) considers both single words (unigrams) and pairs of consecutive words (bigrams) from the text data.
# 2. CountVectorizer: The `CountVectorizer` class is part of scikit-learn's feature extraction module. It converts text data into numerical representations, suitable for machine learning algorithms. In this case, it converts the list of text data into a sparse matrix of token counts, considering both unigrams and bigrams.
# 3. Unigrams and Bigrams: Unigrams refer to single words, while bigrams refer to consecutive pairs of words. The CountVectorizer considers both types of n-grams and generates a feature matrix with counts of these n-grams in the text data.
# 4. Sparse Matrix: The output of `fit_transform()` using CountVectorizer is a sparse matrix, which is a memory-efficient representation of large matrices containing mostly zero values. In this case, the sparse matrix represents the token counts of unigrams and bigrams in the 'text' data, where each row corresponds to a document and each column corresponds to an n-gram. The sparse matrix contains non-zero values representing the frequency of each n-gram in the corresponding document.

# %% [markdown]
# # **2. TF-IDF (Term frequency-inverse Document Frequency)**
# The BOW model doesn’t give good results since it has a drawback. Assume that there is a particular word that is appearing in all the documents and it comes multiple times, eventually, it will have a higher frequency of occurrence and it will have a greater value that will cause a specific word to have more weightage in a sentence, that’s not good for our analysis.
#
# The idea of TF-IDF is to reflect the importance of a word to its document or sentence by normalizing the words which occur frequently in the collection of documents.
#
# **Term frequency (TF): number of times a term has appeared in a document**.
#
# The term frequency is a measure of how frequently or how common a word is for a given sentence.
#
# **Inverse Document Frequency (IDF)**:
#
# The inverse document frequency (IDF ) is a measure of how rare a word is in a document. Words like “the”,” a” show up in all the documents but rare words will not occur in all the documents of the corpus.
#
# If a word appears in almost every document means it’s not significant for the classification.
#
# IDF of a word is = log(N/n)
#
# N: total number of documents.
#
# n: number of documents containing a term (word)
#
# TF-IDF Evaluates how relevant is a word to its sentence in a collection of sentences or documents.
#
# TF-IDF Evaluates how relevant is a word to its sentence in a collection of sentences or documents.
#
# Implementing TF-IDF with python:
#
# With Tfidftransformer you will compute word counts using CountVectorizer and then compute the IDF values and only then compute the Tf-IDF scores. With Tfidfvectorizer we do all calculations in one step.
#
# **sklearn provides 2 classes for implementing TF-IDF:**
#
# Tfidftransformer: where we need to compute word counts then compute IDF values and then compute the TF-IDF scores.
#
# Tfidfvectorizer: here all the steps are done in a single step.

# %%
from sklearn.feature_extraction.text
import TfidfVectorizertext = ["i love the NLP",
                             "NLP is the future",
                             "i will learn the NLP"]
vectorizer = TfidfVectorizer()
matrix = vectorizer.fit_transform(text)
count_array = matrix.toarray()
df = pd.DataFrame(data=count_array,columns = vectorizer.get_feature_names())
print(df)

# %% [markdown]
# Sure, let's break down the given code step by step and explain each line:
#
# 1. Import necessary libraries and modules:
#
# ```python
# from sklearn.feature_extraction.text import TfidfVectorizer
# ```
#
# 2. Create a list of text data:
#
# ```python
# text = ["i love the NLP",
#         "NLP is the future",
#         "i will learn the NLP"]
# ```
#
# 3. Create an instance of TfidfVectorizer:
#
# ```python
# vectorizer = TfidfVectorizer()
# ```
#
# - `TfidfVectorizer`: This class from scikit-learn (sklearn) is used to convert a collection of text documents (in this case, the 'text' list) into a matrix of TF-IDF features. TF-IDF stands for "Term Frequency-Inverse Document Frequency" and is a numerical representation of the importance of a word in a collection of documents.
#
# 4. Fit and transform the text data using TfidfVectorizer:
#
# ```python
# matrix = vectorizer.fit_transform(text)
# ```
#
# - `vectorizer.fit_transform(text)`: This line fits the TfidfVectorizer on the 'text' data and then transforms the text data into a sparse matrix of TF-IDF features.
#
# 5. Convert the sparse matrix to a dense array and create a DataFrame:
#
# ```python
# count_array = matrix.toarray()
# df = pd.DataFrame(data=count_array, columns=vectorizer.get_feature_names())
# ```
#
# - `matrix.toarray()`: This line converts the sparse matrix 'matrix' into a dense array 'count_array'. The dense array representation is more readable and can be converted into a pandas DataFrame.
# - `pd.DataFrame(data=count_array, columns=vectorizer.get_feature_names())`: This line creates a DataFrame named 'df' using the 'count_array' data and assigns the corresponding feature names (unique words) as column names. Each row in the DataFrame represents a document, and each cell contains the TF-IDF score of the corresponding word in that document.
#
# 6. Print the DataFrame:
#
# ```python
# print(df)
# ```
#
# - This line simply prints the DataFrame 'df', which contains the TF-IDF scores of words in the text.
#
# Concepts covered:
# 1. TF-IDF (Term Frequency-Inverse Document Frequency): TF-IDF is a numerical representation used in information retrieval and text mining to measure the importance of a word in a document relative to a collection of documents. It takes into account both the frequency of a word in a document (term frequency) and the rarity of the word in the entire collection (inverse document frequency).
# 2. TfidfVectorizer: The `TfidfVectorizer` class is part of scikit-learn's feature extraction module. It converts text data into numerical representations based on TF-IDF scores. In this case, it converts the list of text data into a sparse matrix of TF-IDF features, where each row corresponds to a document, and each column corresponds to a unique word (term) in the vocabulary.
# 3. Sparse Matrix: The output of `fit_transform()` using TfidfVectorizer is a sparse matrix, which is a memory-efficient representation of large matrices containing mostly zero values. In this case, the sparse matrix represents the TF-IDF scores of words in the 'text' data, where each row corresponds to a document, and each column corresponds to a word. The sparse matrix contains non-zero values representing the TF-IDF scores of each word in the corresponding document.

# %% [markdown]
# # **3. Word Embedding**
# Imagine I have 2 words “love” and “like”, these two words have almost similar meanings but according to TF-IDF and BOW model these two will have separate feature values and these 2 words will be treated completely different.
#
# TF-IDF, BOW model completely depends on the frequency of occurrence, it doesn’t take the meaning of words into consideration, hence above-discussed techniques are failed to capture the context and meaning of sentences.
#
# “I like you” and “I love you” will have completely different feature vectors according to TF-IDF and BOW model, but that’s not correct.
#
# note: while working with some classification task we would have big raw data and if we keep considering every synonym as a different word it will generate humongous numbers of tokens and this will cause numbers of features to get out of control.
#
# Word embedding is a feature learning technique where words are mapped to vectors using their contextual hierarchy. similar words will have identical feature vectors.
#
# ![image.png](data:image/png;base64,...)
#
# As you notice, cats and kitten are placed very closely since they are related.
#
# word embedding is trained on more than 6 billion words using shallow neural networks.
#
# word2vec has 2 algorithms
#
# CBOW
#
# Skip-Gram
#
# don’t worry we don’t need to train word2vec, we will use pre-trained word vectors.

# %% [markdown]
# ## **Implementing word2vec using python:**
# A pre-trained word vector is a text file containing billions of words with their vectors. we only need to map words from our data with the words in the word vector in order to get the vectors.
#
#
# download data from here: https://www.kaggle.com/datasets/rtatman/glove-global-vectors-for-word-representation?select=glove.6B.50d.txt
#
#
# Pre-trained word vector file come in (50,100,200,300) dimension. here dimension is the length of the vector of each word in vector space. more dimension means more information about that word but bigger dimension takes longer time for model training.
#
# # **1. Loading glove word embedding of 100 dimensions into a dictionary:**

# %%
import numpy as np
glove_vectors = dict()
file = open('/content/drive/MyDrive/Colab Notebooks/glove.6B.50d.txt', encoding = 'utf-8')
for line in file:
    values = line.split()
    word = values[0]
    vectors = np.asarray(values[1:])
    glove_vectors[word] = vectors
file.close()

# %% [markdown]
# Certainly! Let's break down the given code step by step and explain each line:
#
# 1. Import necessary libraries and modules:
#
# ```python
# import numpy as np
# ```
#
# 2. Create an empty dictionary to store word vectors:
#
# ```python
# glove_vectors = dict()
# ```
#
# 3. Open the GloVe word vectors file and read its contents:
#
# ```python
# file = open('/content/drive/MyDrive/Colab Notebooks/glove.6B.50d.txt', encoding='utf-8')
# ```
#
# - `open(...)`: This function is used to open a file. It takes the file path as an argument and returns a file object that can be used to read, write, or manipulate the file's contents.
# - `'/content/drive/MyDrive/Colab Notebooks/glove.6B.50d.txt'`: This is the file path to the GloVe word vectors file. The code assumes that the file is present at this location.
#
# 4. Iterate through each line of the file:
#
# ```python
# for line in file:
# ```
#
# 5. Split each line into word and vector components:
#
# ```python
# values = line.split()
# ```
#
# - `line.split()`: This method splits the current line into individual components (words and their corresponding vector values). By default, it splits the line based on spaces, resulting in a list of strings.
#
# 6. Extract the word from the line:
#
# ```python
# word = values[0]
# ```
#
# - `values[0]`: This line extracts the first element of the 'values' list, which corresponds to the word.
#
# 7. Convert the vector values into a numpy array:
#
# ```python
# vectors = np.asarray(values[1:])
# ```
#
# - `np.asarray(values[1:])`: This line converts the list of vector values (excluding the word) into a NumPy array. NumPy arrays are used to handle numerical data efficiently in Python.
#
# 8. Store the word and its corresponding vector in the glove_vectors dictionary:
#
# ```python
# glove_vectors[word] = vectors
# ```
#
# - This line adds an entry to the 'glove_vectors' dictionary, where the word is the key and the vector is the value.
#
# 9. Close the file after reading:
#
# ```python
# file.close()
#
#
# ```
#
# - This line closes the file object to free up system resources after reading the entire file.
#
# Concepts covered:
# 1. GloVe Word Vectors: The code reads GloVe word vectors from a file and stores them in a dictionary. GloVe stands for "Global Vectors for Word Representation," and it is a popular word embedding technique that represents words as dense vectors in a high-dimensional space. These word vectors capture semantic relationships between words and are useful for natural language processing tasks.
#
# 2. File Handling: The code demonstrates how to open and read a file in Python using the `open()` function. The 'encoding' parameter is used to specify the character encoding of the file, ensuring that the file is read correctly, especially if it contains non-ASCII characters.
#
# 3. Dictionary: The 'glove_vectors' dictionary is used to store the word vectors read from the file. Dictionaries are data structures in Python that store key-value pairs. In this case, the word is the key, and the vector is the value. This allows for fast retrieval of word vectors using the word as the key.
#
# 4.Retrieving Values from Dictionary: In Python, dictionaries allow us to store key-value pairs, and we can retrieve the value associated with a specific key using the get() method. In this case, the 'glove_vectors' dictionary contains word vectors, and we are using the key 'house' to retrieve the corresponding word vector from the dictionary

# %% [markdown]
# # **Introduction**
# Have you ever had lots of text from various sources and wanted to analyze broad subject/topics what people are talking about and segregate them into certain clusters, well topic modeling is here for you. So what’s topic modeling. topic modeling is a statistical process through which you can identify, extract, and analyze topics from a given collection of documents.
#
# In this article, we will explore topic modeling through few famous techniques.
#
# There is a slight difference where one could get confused. Is it different from topic classification or is it the same? For starters topic classification falls under the supervised ML algorithm and topic modeling falls under the unsupervised ML algorithms. Expecting you already know the difference, in case if you don't, to put it in a one-liner topic modeling doesn't need any prior training, unlike topic classification.
#
# Since modeling the text doesn’t require any training, this is easy to analyze data. but, one can’t guarantee one will receive precise results.
#
# # **1. About LDA**
# LDA is used to classify text in a document to a particular topic. It builds a topic per document model and words per topic model, modeled as Dirichlet distributions.
#
# Each document is modeled as a multinomial distribution of topics and each topic is modeled as a multinomial distribution of words.
# LDA assumes that the every chunk of text we feed into it will contain words that are somehow related. Therefore choosing the right corpus of data is crucial.
# It also assumes documents are produced from a mixture of topics. Those topics then generate words based on their probability distribution.

# %% [markdown]
# # **# Extracting Topics using LDA in Python**
#
# **1. Preprocessing the raw text**
#
# This involves the following:
#
# Tokenization: Split the text into sentences and the sentences into words.
# Lowercase the words and remove punctuation.
#
# Words that have fewer than 3 characters are removed.
#
# All stopwords are removed.
#
# Words are lemmatized — words in third person are changed to first person and verbs in past and future tenses are changed into present.
#
# Words are stemmed — words are reduced to their root form.
#
# We use the NLTK and gensim libraries to perform the preprocessing

# %%
Loading Gensim and nltk libraries
'''
# pip install gensim
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
np.random.seed(400)


import nltk
nltk.download('wordnet')

# %% [markdown]
# Sure! Let's explain each library used in the code:
#
# 1. gensim:
# - Gensim is a popular Python library for topic modeling, document similarity analysis, and natural language processing tasks.
# - It provides efficient implementations of several state-of-the-art algorithms for unsupervised semantic modeling from plain text.
# - In this code, Gensim is used for text preprocessing tasks and potentially for topic modeling or word embeddings (word vectors).
#
# 2. gensim.utils.simple_preprocess:
# - `simple_preprocess` is a function from the Gensim library used for tokenization and text preprocessing.
# - It converts a document (text) into a list of lowercase tokens, removing punctuations and special characters.
#
# 3. gensim.parsing.preprocessing.STOPWORDS:
# - `STOPWORDS` is a set of common stop words provided by the Gensim library.
# - Stop words are words that are commonly used in natural language but typically do not contribute much to the meaning of a sentence. They are often removed during text preprocessing to focus on more meaningful words.
#
# 4. nltk:
# - NLTK (Natural Language Toolkit) is a leading platform for building Python programs to work with human language data.
# - It provides a suite of libraries and programs for natural language processing tasks, such as tokenization, stemming, lemmatization, part-of-speech tagging, and more.
#
# 5. nltk.stem.WordNetLemmatizer:
# - The `WordNetLemmatizer` is a class from the NLTK library used for lemmatization.
# - Lemmatization is the process of reducing words to their base or root form, which is called a lemma. It helps in reducing words to their meaningful base form.
#
# 6. nltk.stem.SnowballStemmer:
# - The `SnowballStemmer` is a class from the NLTK library used for stemming.
# - Stemming is the process of reducing words to their base or root form by removing suffixes or prefixes. Unlike lemmatization, stemming may not result in actual words, but it can still be useful for certain text analysis tasks.
#
# 7. nltk.stem.porter:
# - The `PorterStemmer` is a stemming algorithm used for stemming words, specifically the Porter stemming algorithm.
# - It is a widely used stemming algorithm that aims to remove common suffixes from words.
#
# 8. numpy (np):
# - NumPy is a powerful library for numerical computing in Python.
# - It provides support for large, multi-dimensional arrays and matrices, along with a large collection of high-level mathematical functions to operate on these arrays.
#
# 9. numpy.random.seed:
# - `seed` is a method from NumPy used for seeding the random number generator.
# - By setting the seed, you can ensure reproducibility of random number generation in your code. When you use the same seed value, you will get the same sequence of random numbers every time you run the code.
#
# # Concepts covered:
# 1. Gensim: Gensim is a Python library for topic modeling and natural language processing. It provides efficient implementations for various semantic analysis tasks.
# 2. Tokenization: Tokenization is the process of breaking a text into smaller units, such as words or sentences.
# 3. Stop Words: Stop words are common words (e.g., "the," "and," "is") that are often removed during text processing because they do not carry much information for analysis.
# 4. Lemmatization: Lemmatization is the process of reducing words to their base or root form (lemma) to reduce inflected forms and improve analysis.
# 5. Stemming: Stemming is the process of reducing words to their base or root form by removing suffixes or prefixes. Unlike lemmatization, stemming may not always result in valid words.
# 6. NumPy: NumPy is a library for numerical computing in Python, and it provides support for large, multi-dimensional arrays and a collection of mathematical functions for array operations.
# 7. Random Seed: Setting the random seed ensures reproducibility of random number generation, enabling consistent results in random processes.

# %%
nltk.download('omw-1.4')

# %% [markdown]
# The code snippet `nltk.download('omw-1.4')` is used to download the Open Multilingual Wordnet (OMW) version 1.4 from the Natural Language Toolkit (NLTK) library.
#
# Open Multilingual Wordnet is a lexical database that provides word-to-concept mappings in multiple languages. It is an extension of the original WordNet, which is a large lexical database of English words, organized based on their semantic relationships. OMW extends WordNet to include wordnets from various languages, allowing researchers and developers to work with multilingual lexical resources.
#
# When you execute `nltk.download('omw-1.4')`, it downloads the OMW data files for version 1.4, making them available for use in NLTK-based projects. This allows you to access wordnets in various languages and perform multilingual natural language processing tasks using NLTK.
#
# Once the download is complete, you can use NLTK functions to access and work with wordnets in different languages. For example, you can retrieve synsets (groups of synonymous words) in a specific language, explore their semantic relationships, and perform cross-lingual semantic analysis.
#
# Keep in mind that downloading the OMW data may require a considerable amount of disk space, as it includes wordnets for multiple languages. So, make sure you have sufficient storage space available for the download. Additionally, downloading and installing the data might take some time depending on your internet connection and system specifications.

# %% [markdown]
# # **Lemmatizer Example**
# Before preprocessing our dataset, let's first look at an lemmatizing example. What would be the output if we lemmatized the word 'went':

# %%
print(WordNetLemmatizer().lemmatize('went', pos = 'v')) # past tense to present tense

# %% [markdown]
# The code `WordNetLemmatizer().lemmatize('went', pos='v')` performs lemmatization on the word 'went' with the specified part-of-speech (POS) tag 'v'. Let's explain it step by step:
#
# 1. Import necessary libraries and modules:
#
# ```python
# from nltk.stem import WordNetLemmatizer
# ```
#
# 2. Create an instance of WordNetLemmatizer:
#
# ```python
# WordNetLemmatizer()
# ```
#
# - `WordNetLemmatizer`: This is a class from the NLTK library used for lemmatization.
#
# 3. Perform lemmatization on the word 'went' with the specified POS tag 'v':
#
# ```python
# WordNetLemmatizer().lemmatize('went', pos='v')
# ```
#
# - `lemmatize('went', pos='v')`: This line calls the `lemmatize()` method of the WordNetLemmatizer instance. It takes two arguments:
#   - The word to be lemmatized, which is 'went' in this case.
#   - The POS tag of the word, which is 'v' indicating the verb part-of-speech.
#
# 4. The output of the code is the lemmatized form of the word 'went':
#
# ```python
# 'go'
# ```
#
# - The lemmatized form of 'went' with the verb POS tag ('v') is 'go'. The lemmatization process converts the past tense 'went' to its base or present tense form 'go'.
#
# Concepts covered:
# 1. Lemmatization: Lemmatization is the process of reducing words to their base or root form, known as a lemma. It is used to handle inflected forms of words and can be helpful in reducing words to their canonical forms for text analysis tasks.
# 2. POS Tagging: Part-of-speech tagging involves labeling words in a text with their corresponding part-of-speech (e.g., noun, verb, adjective, etc.). In this code, the specified POS tag 'v' indicates that the word 'went' is being treated as a verb. Lemmatization uses the POS tag to determine the correct lemma for the word, which may vary depending on its grammatical role.

# %% [markdown]
# # **Stemmer Example**
# Let's also look at a stemming example. Let's throw a number of words at the stemmer and see how it deals with each one:

# %%
import pandas as pd
stemmer = SnowballStemmer("english")
original_words = ['caresses', 'flies', 'dies', 'mules', 'denied','died', 'agreed', 'owned',
           'humbled', 'sized','meeting', 'stating', 'siezing', 'itemization','sensational',
           'traditional', 'reference', 'colonizer','plotted']
singles = [stemmer.stem(plural) for plural in original_words]

pd.DataFrame(data={'original word':original_words, 'stemmed':singles })

output:-
original word	stemmed
0	caresses	caress
1	flies	fli

# %% [markdown]
# Sure! Let's break down the given code step by step and explain each line:
#
# 1. Import the necessary library:
#
# ```python
# import pandas as pd
# ```
#
# 2. Create an instance of SnowballStemmer for the English language:
#
# ```python
# stemmer = SnowballStemmer("english")
# ```
#
# - `SnowballStemmer`: This is a class from the NLTK library used for stemming words using the Snowball algorithm, which is an improvement over the original Porter stemming algorithm. The Snowball algorithm provides stemmers for different languages, and in this code, we are using it for the English language.
#
# 3. Define a list of original words to be stemmed:
#
# ```python
# original_words = ['caresses', 'flies', 'dies', 'mules', 'denied', 'died', 'agreed', 'owned',
#                   'humbled', 'sized', 'meeting', 'stating', 'siezing', 'itemization', 'sensational',
#                   'traditional', 'reference', 'colonizer', 'plotted']
# ```
#
# 4. Perform stemming on the original words:
#
# ```python
# singles = [stemmer.stem(plural) for plural in original_words]
# ```
#
# - `stemmer.stem(plural)`: This line applies the stemmer to each word in the 'original_words' list, converting plural or inflected forms to their base or root form using the Snowball algorithm.
#
# 5. Create a DataFrame to display the original words and their corresponding stemmed forms:
#
# ```python
# pd.DataFrame(data={'original word': original_words, 'stemmed': singles})
# ```
#
# - This line creates a DataFrame using the 'pd.DataFrame()' constructor. The DataFrame has two columns:
#   - 'original word': This column contains the original words.
#   - 'stemmed': This column contains the stemmed versions of the original words.
#
# The output DataFrame will look like this:
#
# ```
#    original word   stemmed
# 0      caresses   caress
# 1         flies      fli
# ...
# ```
#
# Concepts covered:
# 1. Stemming: Stemming is the process of reducing words to their base or root form by removing suffixes or prefixes. It is used to handle inflected forms of words, and it is a common technique in natural language processing for tasks like text analysis and search.
# 2. Snowball Stemmer: The Snowball algorithm is an improvement over the original Porter stemming algorithm. It provides stemmers for various languages, including English ('english' language code in this code).
# 3. Pandas DataFrame: Pandas is a powerful library in Python for data manipulation and analysis. A DataFrame is a two-dimensional data structure in pandas, similar to a table or spreadsheet. In this code, the DataFrame is used to display the original words and their corresponding stemmed forms in a tabular format for easy comparison.

# %%
'''
Write a function to perform the pre processing steps on the entire dataset
'''
def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))

# Tokenize and lemmatize
def preprocess(text):
    result=[]
    for token in gensim.utils.simple_preprocess(text) :
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))

    return result

# %% [markdown]
# Sure, I'll break down the code step by step and explain each line in detail:
#
# 1. Import necessary libraries:
# ```python
# import gensim
# from nltk.stem import WordNetLemmatizer
# ```
# In this code, we import the required libraries. `gensim` is used for text processing tasks, and `WordNetLemmatizer` is from the Natural Language Toolkit (NLTK) library, which is used for lemmatizing words.
#
# 2. Define the function `lemmatize_stemming(text)`:
# ```python
# def lemmatize_stemming(text):
#     return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))
# ```
# This function takes a `text` input and applies lemmatization and stemming to the input text. Lemmatization reduces words to their base or root form, and stemming removes suffixes to bring words to their root form as well. The `'pos'` argument is set to `'v'`, indicating that the lemmatizer will consider the input as a verb.
#
# It is important to note that the `stemmer` variable is not defined in this code snippet. It seems like an omission, and it should be defined earlier in the code to be used in this function.
#
# 3. Define the main preprocessing function `preprocess(text)`:
# ```python
# def preprocess(text):
#     result=[]
#     for token in gensim.utils.simple_preprocess(text):
# ```
# The `preprocess` function takes a `text` input and performs text preprocessing on it. It initializes an empty list `result` to store the processed tokens.
#
# 4. Tokenization:
# ```python
#     for token in gensim.utils.simple_preprocess(text):
# ```
# The `gensim.utils.simple_preprocess` function is used for tokenizing the input text. Tokenization is the process of breaking down the text into smaller units called tokens (words or subwords). Here, it will break the `text` into individual tokens.
#
# 5. Check for Stopwords and Minimum Length:
# ```python
#         if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
# ```
# The code checks if the current `token` is not a stopword (common words like "and," "the," "is," etc., that are often removed during text processing as they do not carry significant meaning). It also checks if the length of the `token` is greater than 3. This condition ensures that only tokens with more than 3 characters are considered for further processing.
#
# 6. Lemmatize and Stem the Token:
# ```python
#             result.append(lemmatize_stemming(token))
# ```
# If the `token` passes the conditions in the previous step, it is then passed to the `lemmatize_stemming` function, which lemmatizes and stems the token. The processed token is then appended to the `result` list.
#
# 7. Return the Result:
# ```python
#     return result
# ```
# Finally, after processing all tokens in the input `text`, the function returns the `result` list containing the preprocessed tokens.
#
# In summary, the `preprocess` function takes a text as input and performs the following steps:
# - Tokenizes the text.
# - Removes stopwords and filters tokens with a length less than or equal to 3.
# - Lemmatizes and stems the tokens that pass the filtering criteria.
# - Returns the list of preprocessed tokens.
#
# One important thing to note is that the code snippet is missing the definition of the `stemmer` variable, which should be initialized before using the `lemmatize_stemming` function. The stemmer could be an instance of a stemming algorithm like the Porter Stemmer or Snowball Stemmer from the NLTK library.

# %% [markdown]
# The provided code contains two functions related to text preprocessing: `lemmatize_stemming` and `preprocess`. These functions are used to process text data, typically for natural language processing (NLP) tasks. Let's break down the technical and theoretical concepts involved in the code:
#
# 1. **Text Preprocessing**:
#    Text preprocessing is an essential step in NLP tasks, where raw text data is transformed into a more manageable and standardized format. It involves various operations to clean, normalize, and reduce the dimensionality of text data. Preprocessing helps in improving the quality of text analysis and reducing noise in the data.
#
# 2. **Tokenization**:
#    Tokenization is the process of breaking down a text into smaller units called tokens. Tokens can be words, phrases, or sentences. In this code, `gensim.utils.simple_preprocess` is used for tokenization, which splits the text into lowercase tokens and removes punctuations.
#
# 3. **Lemmatization**:
#    Lemmatization is the process of reducing words to their base or root form, known as the lemma. It helps in grouping inflected or derived forms of a word together. In the code, the `WordNetLemmatizer` from the NLTK library is used to lemmatize the tokens with the part-of-speech (POS) tag 'v', indicating verbs.
#
# 4. **Stemming**:
#    Stemming is the process of removing suffixes or prefixes from words to obtain their root form, known as the stem. Unlike lemmatization, stemming may not always result in a valid word, but it can be computationally faster. In the code, the `stemmer` (stemming function) is used to obtain the stem of the lemmatized tokens.
#
# 5. **Stop Words**:
#    Stop words are common words (e.g., "and," "the," "is") that are often removed from text during preprocessing as they don't carry significant meaning and are present in most texts. In the code, `gensim.parsing.preprocessing.STOPWORDS` is used to filter out these stop words from the tokens.
#
# Now, let's discuss the flow of the functions:
#
# - The `lemmatize_stemming` function takes a single word (text) as input and performs lemmatization followed by stemming using the `WordNetLemmatizer` and the `stemmer`, respectively. It returns the stemmed lemma of the input word.
#
# - The `preprocess` function takes a text as input and processes it through the following steps:
#   1. Tokenization: It uses `gensim.utils.simple_preprocess` to split the text into lowercase tokens without punctuations.
#   2. Stopword Removal: It filters out tokens that appear in the `gensim.parsing.preprocessing.STOPWORDS` set, which contains common stop words.
#   3. Lemmatization and Stemming: It applies the `lemmatize_stemming` function to each remaining token, obtaining the stemmed lemmatized tokens.
#   4. The function returns a list of processed tokens, representing the preprocessed version of the input text.
#
# Overall, the code aims to preprocess text data for further NLP tasks by tokenizing, removing stop words, lemmatizing, and stemming the words in the text. These steps help in reducing the dimensionality of the text data and extracting essential information for downstream NLP tasks like text classification, topic modeling, and sentiment analysis.

# %%
'''
Preview a document after preprocessing
'''
document_num = 50
doc_sample = 'This disk has failed many times. I would like to get it replaced.'

print("Original document: ")
words = []
for word in doc_sample.split(' '):
    words.append(word)
print(words)
print("\n\nTokenized and lemmatized document: ")
print(preprocess(doc_sample))

output:-

Original document:
['This', 'disk', 'has', 'failed', 'many', 'times.', 'I', 'would', 'like', 'to', 'get', 'it', 'replaced.']


Tokenized and lemmatized document:
['disk', 'fail', 'time', 'like', 'replac']

# %% [markdown]
# Hello! I'll be happy to explain the given code step by step. Let's break it down into smaller pieces and go through each part in detail:
#
# 1. First, we have some initial setup:
# ```python
# document_num = 50
# doc_sample = 'This disk has failed many times. I would like to get it replaced.'
# ```
# Here, `document_num` is a variable set to the value 50, which is not used in the code snippet you provided. The `doc_sample` variable contains the text of the document that we want to preprocess.
#
# 2. Next, we print the original document:
# ```python
# print("Original document: ")
# ```
# This line simply prints the text "Original document: " to the console, indicating that the following lines will display the original document text.
#
# 3. Tokenization of the original document:
# ```python
# words = []
# for word in doc_sample.split(' '):
#     words.append(word)
# ```
# In this part, we tokenize the `doc_sample` string by splitting it into individual words using the space character (' ') as the delimiter. The `split(' ')` method splits the string into a list of words based on the spaces between them. We then iterate through each word and append it to the `words` list. As a result, the `words` list will contain all the words in the original document.
#
# 4. Print the tokenized document:
# ```python
# print(words)
# ```
# This line prints the tokenized document, i.e., all the words extracted from the original document, as a list.
#
# 5. Preprocess the document using a custom function:
# ```python
# print("\n\nTokenized and lemmatized document: ")
# print(preprocess(doc_sample))
# ```
# Here, we call the `preprocess` function passing `doc_sample` as an argument. This function is expected to tokenize and lemmatize the input text. However, the `preprocess` function is not explicitly defined in the code snippet you provided. It seems that the function is missing from this code, and that's why this part would raise a NameError since `preprocess` is not recognized.
#
# 6. The output:
# ```
# Original document:
# ['This', 'disk', 'has', 'failed', 'many', 'times.', 'I', 'would', 'like', 'to', 'get', 'it', 'replaced.']
#
# Tokenized and lemmatized document:
# ['disk', 'fail', 'time', 'like', 'replac']
# ```
#
# The output shown above is what you would get if the `preprocess` function was correctly defined and implemented. The tokenized document contains all the individual words from the original document, and the lemmatized document contains the lemmatized forms of some of those words (assuming that the `preprocess` function takes care of lemmatization).
#
# It's important to note that without the definition of the `preprocess` function, we cannot explain the exact details of the lemmatization process that led to the lemmatized output.
#
# Now, let's talk about some technical and theoretical concepts mentioned in the code:
#
# 1. Tokenization:
# Tokenization is the process of breaking a text into smaller units, such as words or sentences. In this code, the `doc_sample.split(' ')` method is used to tokenize the `doc_sample` into individual words by splitting it on spaces.
#
# 2. Lemmatization:
# Lemmatization is the process of reducing words to their base or root form, called the lemma. For example, the lemma of the word "running" is "run," and the lemma of "mice" is "mouse." Lemmatization helps to standardize words, making it easier to analyze and compare texts. The code output shows the lemmatized version of some words from the original document.
#
# 3. Functions:
# Functions are blocks of code that can be called and executed multiple times with different inputs. In this code, the `preprocess` function is used for tokenization and lemmatization, but its implementation is missing.
#
# 4. Lists:
# Lists are a type of data structure in Python that can store multiple items in an ordered sequence. In the code, the `words` list is used to store the tokenized words from the original document.
#
# 5. Loops:
# Loops are used to repeat a block of code multiple times. In the code, the `for` loop is used to iterate through each word in the tokenized document and append them to the `words` list.
#
# Unfortunately, without the `preprocess` function's definition, we can't provide a detailed explanation of the lemmatization process. However, the missing function should be responsible for tokenizing the input text, performing lemmatization, and returning the lemmatized version.
#
# If you have the implementation of the `preprocess` function or any specific questions, feel free to share them, and I'll be glad to provide further assistance!

# %%
processed_docs = []

for doc in newsgroups_train.data:
    processed_docs.append(preprocess(doc))


'''
Preview 'processed_docs'
'''
print(processed_docs[:2])

# %% [markdown]
# Of course! Let's break down the given code step by step and explain each line in detail:
#
# Step 1: Initialize an empty list to store processed documents.
# ```python
# processed_docs = []
# ```
# In this line, we create an empty list called `processed_docs`. This list will be used to store the processed versions of the documents after they undergo some text preprocessing.
#
# Step 2: Loop through the documents in the `newsgroups_train.data` dataset and preprocess each document.
# ```python
# for doc in newsgroups_train.data:
#     processed_docs.append(preprocess(doc))
# ```
# In this loop, we iterate through each document in the `newsgroups_train.data` dataset. For each document, we call the `preprocess` function (not shown in this code snippet) to perform some text preprocessing. The preprocessed document is then appended to the `processed_docs` list.
#
# Step 3: Print a preview of the processed documents.
# ```python
# print(processed_docs[:2])
# ```
# This line prints the first two elements of the `processed_docs` list, giving us a preview of the preprocessed documents.
#
# The code you provided utilizes the concept of loops, lists, and functions:
#
# 1. Loops:
# Loops, specifically the `for` loop, allow us to iterate through elements in a collection (in this case, documents in `newsgroups_train.data`). It helps us process each document one by one without having to write repetitive code.
#
# 2. Lists:
# Lists are data structures that can store multiple items in an ordered sequence. In this code, `processed_docs` is a list that stores the processed versions of the documents.
#
# 3. Functions:
# The code references a `preprocess` function, which is not shown in the provided code snippet. Functions are blocks of reusable code that can take inputs (arguments) and perform specific tasks. In this case, the `preprocess` function takes a document as input, processes it, and returns the processed version.
#
# Explanation of `preprocess` function:
# Since the `preprocess` function is not included in the provided code, we can't explain its internal details. However, based on the context, the `preprocess` function is likely designed to perform some text preprocessing tasks like tokenization, removing stopwords, lemmatization, or stemming. These preprocessing steps are typically applied to clean and transform raw text data into a format suitable for further analysis or natural language processing tasks.
#
# The result of this code would be a list of processed documents (`processed_docs`) containing the preprocessed versions of the documents from the `newsgroups_train.data` dataset.
#
# If you have the implementation of the `preprocess` function or any other specific questions, feel free to share them, and I'll be glad to provide further assistance!

# %% [markdown]
# # **Step 3: Bag of words on the dataset**
#
# Now let's create a dictionary from 'processed_docs' containing the number of times a word appears in the training set. To do that, let's pass processed_docs to gensim.corpora.Dictionary() and call it 'dictionary'.
#
# Prior to topic modelling, we convert the tokenized and lemmatized text to a bag of words — which you can think of as a dictionary where the key is the word and value is the number of times that word occurs in the entire corpus.
#
# We can further filter words that occur very few times or occur very frequently.
#
# Now for each pre-processed document we use the dictionary object just created to convert that document into a bag of words. i.e for each document we create a dictionary reporting how many words and how many times those words appear.

# %%
'''
Create a dictionary from 'processed_docs' containing the number of times a word appears
in the training set using gensim.corpora.Dictionary and call it 'dictionary'
'''
dictionary = gensim.corpora.Dictionary(processed_docs)


'''
Checking dictionary created
'''
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 10:
        break

output:-
0 addit
1 bodi
2 bricklin
3 bring
4 bumper
5 call

# %% [markdown]
# Of course! Let's go through the code step by step, explaining each line in detail:
#
# Step 1: Create a dictionary from 'processed_docs' using gensim.corpora.Dictionary.
# ```python
# dictionary = gensim.corpora.Dictionary(processed_docs)
# ```
# In this line, we are using the `gensim.corpora.Dictionary` class to create a dictionary from the `processed_docs` list. The `gensim` library is a popular library for topic modeling and document similarity analysis, and the `Dictionary` class from gensim is used to represent the mapping between words and their integer ids in a corpus.
#
# Step 2: Checking the dictionary created.
# ```python
# count = 0
# for k, v in dictionary.iteritems():
#     print(k, v)
#     count += 1
#     if count > 10:
#         break
# ```
# In this part, we are iterating through the dictionary created in the previous step using a `for` loop. For each key-value pair in the dictionary, the loop prints the key (word) and the value (integer id) using `print(k, v)`. The loop is controlled by the `count` variable to print only the first 11 key-value pairs. After printing the first 11 pairs, the loop breaks using the `break` statement.
#
# Concepts and explanations:
#
# 1. Gensim:
# Gensim is an open-source Python library that specializes in topic modeling and natural language processing tasks. It provides tools for working with large text collections and transforming them into numerical representations that can be used in machine learning models.
#
# 2. Dictionary:
# In the context of gensim, the `Dictionary` class is used to create a mapping between words and their integer ids. It is typically used to build a dictionary of words from a corpus (a collection of texts). The dictionary serves as a lookup table that allows us to map words to unique integer ids, which is a common representation in natural language processing tasks.
#
# 3. Dictionary creation:
# The line `dictionary = gensim.corpora.Dictionary(processed_docs)` creates a dictionary by taking `processed_docs` as input. The `processed_docs` list likely contains preprocessed text documents (tokenized, lemmatized, etc.), and the `Dictionary` class will build a mapping of words to unique integer ids based on the words present in the documents.
#
# 4. Dictionary iteration:
# The `for` loop with `for k, v in dictionary.iteritems():` is used to iterate through the key-value pairs in the dictionary. In each iteration, the variable `k` represents the word, and `v` represents its corresponding integer id.
#
# 5. Counting and breaking the loop:
# The `count` variable is used to keep track of the number of iterations (key-value pairs printed). The loop will stop after printing the first 11 pairs using the `if count > 10: break` statement. This is done to provide a preview of the dictionary's contents without overwhelming the output.
#
# In summary, this code creates a dictionary called `dictionary` using the gensim library, which maps words to unique integer ids based on the words present in the `processed_docs` list. The subsequent loop provides a preview of the first 11 key-value pairs in the dictionary, showing some words and their corresponding integer ids.
#
# If you have any more questions or need further clarification, feel free to ask!

# %% [markdown]
# # **Gensim filter_extremes**
# filter_extremes(no_below=5, no_above=0.5, keep_n=100000)
#
# Filter out tokens that appear in
#
# less than no_below documents (absolute number) or
# more than no_above documents (fraction of total corpus size, not absolute number).
# after (1) and (2), keep only the first keep_n most frequent tokens (or keep all if None).

# %%
'''
OPTIONAL STEP
Remove very rare and very common words:

- words appearing less than 15 times
- words appearing in more than 10% of all documents
'''
dictionary.filter_extremes(no_below=15, no_above=0.1, keep_n= 100000)

# %% [markdown]
# Of course! Let's break down the code step by step and explain each line in detail:
#
# Step 1: Remove very rare and very common words from the dictionary.
#
# ```python
# dictionary.filter_extremes(no_below=15, no_above=0.1, keep_n=100000)
# ```
#
# In this step, we are applying optional filtering to the `dictionary` object created in the previous code snippet. The purpose is to remove words that are too rare or too common in the corpus to avoid noise or less informative terms.
#
# Concepts and explanations:
#
# 1. Filtering extremes:
# The `filter_extremes` method is a feature of the gensim `Dictionary` class. It allows us to filter out words that are considered extreme in terms of their occurrence frequency.
#
# 2. Parameters:
# The `filter_extremes` method takes three parameters:
#    - `no_below`: An integer representing the minimum number of times a word must appear in the corpus (all documents combined) to be kept in the dictionary. In this case, words appearing less than 15 times will be removed.
#    - `no_above`: A float representing the maximum proportion of documents (expressed as a fraction between 0 and 1) in which a word is allowed to appear to be kept in the dictionary. In this case, words appearing in more than 10% (0.1) of all documents will be removed.
#    - `keep_n`: An integer representing the maximum number of words to keep in the dictionary after filtering. In this case, at most 100,000 words will be retained in the dictionary, based on their occurrence and frequency.
#
# 3. Frequency-based filtering:
# The filtering process is based on the occurrence frequency of words in the corpus. Words that are very rare (appear less than 15 times) or very common (appear in more than 10% of all documents) are considered extreme and are removed from the dictionary.
#
# 4. Purpose:
# The purpose of filtering extremes is to improve the quality of the dictionary and remove noisy or less informative terms. Very rare words might not contribute much to the overall understanding of the corpus, while very common words (like stop words) may not carry much specific meaning in the context of the documents.
#
# 5. Note on the order of operations:
# The filtering is applied to the `dictionary` object created earlier, so it affects the dictionary and not the original documents (`processed_docs`). The filtering is performed in-place, meaning the `dictionary` will be modified directly.
#
# In summary, this optional step removes very rare (less than 15 occurrences) and very common (in more than 10% of all documents) words from the `dictionary` object using the `filter_extremes` method. The purpose is to create a more informative and focused dictionary for further analysis or modeling tasks.
#
# If you have any more questions or need further clarification, feel free to ask!

# %% [markdown]
# # **Gensim doc2bow**
# ### **doc2bow(document)**
#
# Convert document (a list of words) into the bag-of-words format = list of (token_id, token_count) 2-tuples. Each word is assumed to be a tokenized and normalized string (either unicode or utf8-encoded). No further preprocessing is done on the words in document; apply tokenization, stemming etc. before calling this method.

# %%
'''
Create the Bag-of-words model for each document i.e for each document we create a dictionary reporting how many
words and how many times those words appear. Save this to 'bow_corpus'
'''
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]


'''
Preview BOW for our sample preprocessed document
'''
document_num = 20
bow_doc_x = bow_corpus[document_num]

for i in range(len(bow_doc_x)):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_x[i][0],
                                                     dictionary[bow_doc_x[i][0]],
                                                     bow_doc_x[i][1]))

output:-

Word 18 ("rest") appears 1 time.
Word 166 ("clear") appears 1 time.

# %% [markdown]
# Hello! I'd be glad to explain the code to you in detail. Let's break it down step by step:
#
# Step 1: Create the Bag-of-Words (BOW) model for each document.
# ---------------------------------------------------------
#
# ```python
# # Create the Bag-of-words model for each document i.e., for each document, we create a dictionary reporting how many
# # words and how many times those words appear. Save this to 'bow_corpus'
#
# bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
# ```
#
# Explanation:
# - In this code block, we are using a list comprehension to create a Bag-of-Words (BOW) model for each document in the `processed_docs`.
# - `processed_docs` is assumed to be a list of preprocessed documents where each document is represented as a list of words.
# - `dictionary` is a pre-existing dictionary that maps words to unique IDs. It serves as a vocabulary for our BOW model.
# - The function `doc2bow()` is applied to each document in `processed_docs`. This function takes a document as input and converts it into a sparse vector representation, where each element of the vector corresponds to a unique word ID, and its value represents the number of occurrences of that word in the document.
# - The result is a list of sparse vectors, where each vector represents a BOW representation of a document. We store this list in the variable `bow_corpus`.
#
# Step 2: Preview the Bag-of-Words representation for a sample document
# -------------------------------------------------------------------
#
# ```python
# # Preview BOW for our sample preprocessed document
#
# document_num = 20
# bow_doc_x = bow_corpus[document_num]
#
# for i in range(len(bow_doc_x)):
#     print("Word {} (\"{}\") appears {} time.".format(bow_doc_x[i][0],
#                                                      dictionary[bow_doc_x[i][0]],
#                                                      bow_doc_x[i][1]))
# ```
#
# Explanation:
# - In this code block, we are previewing the Bag-of-Words representation for a specific document, indicated by the `document_num` variable.
# - We access the BOW representation of the specified document by retrieving it from the `bow_corpus` list using its index `document_num`. The resulting BOW representation is stored in the variable `bow_doc_x`.
# - The BOW representation `bow_doc_x` is a sparse vector, where each element is a tuple `(word_id, word_frequency)`.
# - We use a loop to iterate through each element of the sparse vector.
# - Inside the loop, we extract the `word_id`, which is the unique ID of the word, and the `word_frequency`, which represents how many times the word appears in the document.
# - Using the `word_id`, we look up the corresponding word from the `dictionary`.
# - Finally, we print the word, its frequency in the document, and its human-readable representation.
#
# In summary, this code first creates a Bag-of-Words model for each document in the `processed_docs` list, where each document is represented by a sparse vector containing word IDs and their respective frequencies. Then, it previews the BOW representation for a specific document by printing the word and its frequency in that document.
#
# Technical Concepts:
# -------------------
#
# 1. Bag-of-Words (BOW) Model: The BOW model is a common approach in Natural Language Processing (NLP) for text representation. It represents a text document as a "bag" (unordered set) of words, disregarding grammar and word order but keeping track of word frequencies. The BOW model is often used as a feature representation for machine learning algorithms.
#
# 2. Dictionary: In the context of this code, the `dictionary` is a mapping from words to unique IDs. It serves as a vocabulary for the BOW model, where each word in the corpus is associated with a specific ID. The `dictionary.doc2bow()` function converts a document (list of words) into a BOW representation using this dictionary.
#
# 3. Sparse Vector: The BOW representation of a document is often a sparse vector. A sparse vector is a vector in which most of the elements have zero values. In the BOW model, the vector's non-zero elements represent the word frequencies, while the zero elements indicate that the corresponding word does not appear in the document.
#
# 4. Looping: The `for` loop is used to iterate through each element of the sparse vector `bow_doc_x` to access the word ID and its frequency. This allows us to print the word and its frequency for the specified document.
#
# I hope this explanation helps you understand the code and the technical concepts involved! If you have any more questions or need further clarification, feel free to ask. Happy learning!

# %% [markdown]
# # **3. Running LDA**
# This is actually quite simple as we can use the gensim LDA model. We need to specify how many topics are there in the data set. Lets say we start with 8 unique topics. Num of passes is the number of training passes over the document.
#
# We are going for 10 topics in the document corpus.
#
# We will be running LDA using all CPU cores to parallelize and speed up model training.
#
# # **Some of the parameters we will be tweaking are:**
#
# num_topics is the number of requested latent topics to be extracted from the training corpus.
# id2word is a mapping from word ids (integers) to words (strings). It is used to determine the vocabulary size, as well as for debugging and topic printing.
# workers is the number of extra processes to use for parallelization. Uses all available cores by default.
# alpha and eta are hyperparameters that affect sparsity of the document-topic (theta) and topic-word (lambda) distributions. We will let these be the default values for now(default value is 1/num_topics)
# Alpha is the per document topic distribution.
# High alpha: Every document has a mixture of all topics(documents appear similar to each other).
#
# # **Low alpha: Every document has a mixture of very few topics**
#
# Eta is the per topic word distribution.
# High eta: Each topic has a mixture of most words(topics appear similar to each other).
#
# # **Low eta: Each topic has a mixture of few words.**
#
# passes is the number of training passes through the corpus. For example, if the training corpus has 50,000 documents, chunksize is 10,000, passes is 2, then online training is done in 10 updates:

# %%
# LDA mono-core -- fallback code in case LdaMulticore throws an error on your machine
# lda_model = gensim.models.LdaModel(bow_corpus,
#                                    num_topics = 10,
#                                    id2word = dictionary,
#                                    passes = 50)

# LDA multicore
'''
Train your lda model using gensim.models.LdaMulticore and save it to 'lda_model'
'''
# TODO
lda_model =  gensim.models.LdaMulticore(bow_corpus,
                                   num_topics = 8,
                                   id2word = dictionary,
                                   passes = 10,
                                   workers = 2)

# %% [markdown]
# Sure! Let's break down the given code into small pieces and explain each line step by step:
#
# Step 1: Import the necessary library
# ------------------------------------
#
# ```python
# import gensim
# ```
#
# Explanation:
# - The code begins by importing the `gensim` library, which is a popular Python library for topic modeling, including the Latent Dirichlet Allocation (LDA) algorithm.
#
# Step 2: Define the LDA model using LdaMulticore
# ----------------------------------------------
#
# ```python
# lda_model =  gensim.models.LdaMulticore(bow_corpus,
#                                        num_topics=8,
#                                        id2word=dictionary,
#                                        passes=10,
#                                        workers=2)
# ```
#
# Explanation:
# - In this part, we are training the LDA model using the `LdaMulticore` class from the `gensim.models` module.
# - `LdaMulticore` is an optimized version of LDA that utilizes multiple CPU cores to speed up the training process.
#
# Parameters:
# - `bow_corpus`: This is the Bag-of-Words (BOW) corpus that we created earlier, containing the BOW representation of each document in the dataset.
# - `num_topics`: This parameter specifies the number of topics we want the LDA model to discover. In this case, the model will try to find 8 topics in the corpus.
# - `id2word`: This is the dictionary that maps word IDs to words. It is used to convert the BOW representation back to human-readable topics.
# - `passes`: The number of passes or iterations the LDA algorithm makes over the corpus during training. A higher value generally helps to improve the quality of the topics.
# - `workers`: The number of CPU cores to use for parallelizing and speeding up the training process. In this case, we are using 2 cores.
#
# After running this code, the variable `lda_model` will contain the trained LDA model that can be used to explore and interpret the discovered topics in the corpus.
#
# Technical Concepts:
# -------------------
#
# 1. Latent Dirichlet Allocation (LDA): LDA is a probabilistic topic modeling technique used to discover hidden topics in a collection of documents. It assumes that each document is a mixture of various topics, and each topic is a probability distribution over words.
#
# 2. LdaMulticore: `LdaMulticore` is a variation of the LDA algorithm provided by the Gensim library. It is designed to leverage multiple CPU cores, which can significantly speed up the training process, especially for large datasets.
#
# 3. num_topics: The `num_topics` parameter specifies the number of topics that the LDA model should identify in the corpus. Determining the optimal number of topics is a challenging task and often requires experimentation and evaluation.
#
# 4. passes: The `passes` parameter determines how many times the LDA algorithm goes through the entire corpus during training. Each pass updates the topic assignments for words in documents and the topic distributions for documents. Increasing the number of passes can improve the quality of the topics but may also increase the training time.
#
# 5. workers: The `workers` parameter controls how many CPU cores are used to parallelize the training process. By setting it to a value greater than 1, the training can be done concurrently on multiple cores, leading to faster training.
#
# In summary, the code uses the `LdaMulticore` class from Gensim to train an LDA model on the Bag-of-Words representation of a corpus. The trained model is stored in the variable `lda_model`, and it can be used to explore and analyze the topics present in the dataset.
#
# If you have any more questions or need further clarification, feel free to ask! Happy learning!

# %%
For each topic, we will explore the words occuring in that topic and its relative weight
'''
for idx, topic in lda_model.print_topics(-1):
    print("Topic: {} \nWords: {}".format(idx, topic ))
    print("\n")

output:-
Topic: 0
Words: 0.012*"armenian" + 0.011*"game" + 0.010*"team" + 0.007*"turkish" + 0.006*"play" +
0.006*"player" + 0.005*"season" + 0.004*"leagu" + 0.004*"basebal" + 0.004*"leav"


Topic: 1
Words: 0.017*"drive" + 0.006*"control" + 0.005*"hard" + 0.005*"disk" + 0.004*"bike" +
 0.004*"firearm" + 0.004*"caus" + 0.004*"effect" + 0.003*"car" + 0.003*"weapon"

# %% [markdown]
# Of course! Let's break down the given code into small pieces and explain each line step by step:
#
# Step 1: Loop through topics and print them
# ------------------------------------------
#
# ```python
# for idx, topic in lda_model.print_topics(-1):
#     print("Topic: {} \nWords: {}".format(idx, topic))
#     print("\n")
# ```
#
# Explanation:
# - In this code, we are using a loop to iterate through all the topics generated by the LDA model (`lda_model`).
# - The `print_topics()` method of the LDA model is used to retrieve the topics along with the top words contributing to each topic.
# - The method takes a few parameters:
#   - `-1`: The `num_words` parameter set to -1 means that all the words contributing to each topic will be printed.
#   - `idx`: This variable will hold the index of the current topic being processed.
#   - `topic`: This variable will hold the string representation of the topic with its top contributing words.
#
# Step 2: Print the topic index and the top words
# ----------------------------------------------
#
# ```python
# print("Topic: {} \nWords: {}".format(idx, topic))
# ```
#
# Explanation:
# - Inside the loop, we are printing the current topic's index (`idx`) and the top words contributing to that topic (`topic`).
# - `idx` represents the index of the topic, starting from 0 for the first topic, 1 for the second topic, and so on.
# - `topic` contains a formatted string that shows the top words contributing to the current topic.
#
# Step 3: Add a newline after each topic
# -------------------------------------
#
# ```python
# print("\n")
# ```
#
# Explanation:
# - After printing the top words for a particular topic, we add an extra newline to separate the output of different topics for better readability.
#
# Technical Concepts:
# -------------------
#
# 1. Looping: The `for` loop is used to iterate through each topic generated by the LDA model. It goes through each topic one by one and allows us to process them sequentially.
#
# 2. Topic Modeling: Topic modeling is a technique used to discover latent topics in a collection of documents. In this case, we are using the LDA model to identify and represent topics as probability distributions over words.
#
# 3. print_topics(): The `print_topics()` method is a utility function provided by the Gensim library for LDA models. It returns a list of (topic_index, topic_string) pairs, where each `topic_string` contains the top contributing words and their corresponding probabilities for a specific topic.
#
# In summary, the code iterates through the topics generated by the LDA model and prints the topic index along with the top words contributing to each topic. The output shows the distribution of words for each topic, helping us understand the themes present in the corpus.
#
# If you have any further questions or need more explanation, feel free to ask! Happy learning!

# %% [markdown]
# Classification of the topics
# Using the words in each topic and their corresponding weights, what categories were you able to infer?
#
# Topic 0: Politics
#
# Topic 1: Gun Violence
#
# Topic 2: Graphic Cards
#
# Topic 3: Space
#
# Topic 4: Encryption
#
# Topic 5: Sports
#
# Topic 6: Technology
#
# Topic 7: Religion

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Observations:**
#
# The model did impressively well in extracting the unique topics in the data set which we can confirm given we know the target names
# The model runs very quickly. I could extract topics from data set in minutes
# It does assume that there are distinct topics in the data set. So if the data set is a bunch of random tweets than the model results may not be as interpretable.

# %% [markdown]
# # **What is Topic Modeling ?**
#
#
# In natural language understanding (NLU) tasks, there is a hierarchy of lenses through which we can extract meaning — from words to sentences to paragraphs to documents. At the document level, one of the most useful ways to understand text is by analyzing its topics. The process of learning, recognizing, and extracting these topics across a collection of documents is called topic modeling.
#
# Topic modelling refers to the task of identifying topics that best describes a set of documents. These topics will only emerge during the topic modelling process (therefore called latent). And one popular topic modeling technique is known as Latent Dirichlet Allocation (LDA).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **All topic models are based on the same basic assumption:**
#
# ## each document consists of a mixture of topics, and
# ## each topic consists of a collection of words.
#
# In other words, topic models are built around the idea that the semantics of our document are actually being governed by some hidden, or “latent,” variables that we are not observing. As a result, the goal of topic modeling is to uncover these latent variables — topics — that shape the meaning of our document and corpus.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Certainly! Let's go through the concepts mentioned in the code step by step and explain their importance:
#
# 1. **Importing Libraries:**
#    The first part of the code imports several Python libraries, which are essential for various data analysis and visualization tasks. These libraries include:
#    - `numpy` (imported as `np`): NumPy is a library for numerical computing in Python. It provides support for large, multi-dimensional arrays and matrices, as well as various mathematical functions to operate on these arrays efficiently.
#    - `pandas` (imported as `pd`): Pandas is a powerful library for data manipulation and analysis. It introduces two new data structures: Series (1D labeled array) and DataFrame (2D labeled array) that allow you to handle data in a structured way.
#    - `IPython.display`: This library includes functions to help with displaying content within IPython environments, like Jupyter notebooks.
#    - `tqdm`: TQDM stands for "taqaddum" in Arabic, which means "progress" or "advance." It's a library for creating progress bars for loops, making it easier to track the progress of time-consuming tasks.
#    - `collections`: This module provides various specialized container datatypes, beyond the built-in data types like lists and dictionaries. In this code, it is used to create a `Counter`, which helps count the occurrences of elements in a collection.
#    - `ast`: The `ast` module is used to work with abstract syntax trees (AST) in Python. It allows you to parse Python code into a tree-like structure and manipulate it programmatically.
#
# 2. **Data Visualization Libraries:**
#    - `matplotlib.pyplot` (imported as `plt`): Matplotlib is a widely-used data visualization library in Python. The `pyplot` module provides a simple interface for creating various types of plots, such as line plots, bar plots, histograms, etc.
#    - `matplotlib.mlab`: This module is an older interface to Matplotlib's functions. However, its use is not recommended anymore, and most plotting functions are now accessed directly through `matplotlib.pyplot`.
#    - `seaborn` (imported as `sb`): Seaborn is a high-level data visualization library built on top of Matplotlib. It provides a more attractive and informative visual representation of data, with simplified commands.
#
# 3. **Text Analysis Libraries:**
#    - `sklearn.feature_extraction.text.CountVectorizer`: This class from scikit-learn (imported as `CountVectorizer`) is used to convert a collection of text documents into a matrix of token counts. It is a common technique for text analysis and text-based machine learning tasks.
#    - `textblob.TextBlob`: TextBlob is a library for processing textual data. It provides a simple API to access common natural language processing (NLP) tasks, such as part-of-speech tagging, noun phrase extraction, sentiment analysis, etc.
#    - `scipy.stats`: This module from SciPy provides various statistical functions and tests.
#
# 4. **Machine Learning Models:**
#    - `sklearn.decomposition.TruncatedSVD`: Truncated Singular Value Decomposition (SVD) is a dimensionality reduction technique used in machine learning. It is mainly applied to sparse data to reduce the number of features while preserving the most important information.
#    - `sklearn.decomposition.LatentDirichletAllocation`: Latent Dirichlet Allocation (LDA) is a probabilistic topic modeling technique used to discover hidden topics within a collection of documents. It is commonly used for text analysis and clustering.
#    - `sklearn.manifold.TSNE`: t-distributed Stochastic Neighbor Embedding (t-SNE) is a dimensionality reduction technique particularly useful for visualizing high-dimensional data. It projects data points into a lower-dimensional space while preserving local structure and relationships.
#
# 5. **`output_notebook()`:**
#    This function seems to be from Bokeh, a Python interactive visualization library. `output_notebook()` is used to configure Bokeh to render its output directly within a Jupyter notebook, allowing for interactive and dynamic visualizations.
#
# 6. **`%matplotlib inline`:**
#    This is a Jupyter Notebook magic command that configures Matplotlib to display plots directly in the notebook output. It ensures that any plot generated by `matplotlib.pyplot` will be shown inline in the notebook, instead of opening in a separate window.
#
# Importing these libraries and configuring the output for visualization are essential steps to set up the environment for data analysis, text processing, and visualizations. Each library serves a specific purpose and collectively enables you to perform data exploration, understand patterns, and gain insights from the data in a more visual and interactive way.

# %%
from google.colab import drive
drive.mount('/content/drive')
Mounted at /content/drive
datafile = '/content/drive/MyDrive/AlmaBetter/Cohort Aravali/Module 4/Week 3/Day 6/abcnews-date-text.csv'
raw_data = pd.read_csv(datafile, parse_dates=[0], infer_datetime_format=True)

reindexed_data = raw_data['headline_text']
reindexed_data.index = raw_data['publish_date']

raw_data.head()
publish_date	headline_text
0	2003-02-19	aba decides against community broadcasting lic...
1	2003-02-19	act fire witnesses must be aware of defamation

# %% [markdown]
# Sure! Let's break down the given code into small pieces and explain each line step by step:
#
# Step 1: Import the required libraries
# -------------------------------------
#
# ```python
# from google.colab import drive
# ```
#
# Explanation:
# - In this line, we are importing the `drive` module from the `google.colab` package. This module allows us to connect and mount Google Drive to our Colab notebook.
#
# Step 2: Mount Google Drive
# --------------------------
#
# ```python
# drive.mount('/content/drive')
# ```
#
# Explanation:
# - This line mounts Google Drive to the Colab notebook. It prompts you to provide an authentication code and once the code is entered, the Drive is successfully mounted.
# - After mounting, you can access your Google Drive files within the Colab environment under the `/content/drive` directory.
#
# Step 3: Define the data file path
# --------------------------------
#
# ```python
# datafile = '/content/drive/MyDrive/AlmaBetter/Cohort Aravali/Module 4/Week 3/Day 6/abcnews-date-text.csv'
# ```
#
# Explanation:
# - In this line, we are defining the file path of the CSV file that contains the data we want to work with.
# - The `datafile` variable holds the full path to the CSV file in the mounted Google Drive.
#
# Step 4: Read the CSV data into a DataFrame
# ------------------------------------------
#
# ```python
# raw_data = pd.read_csv(datafile, parse_dates=[0], infer_datetime_format=True)
# ```
#
# Explanation:
# - In this line, we are using Pandas (`pd`) to read the CSV data into a DataFrame.
# - `pd.read_csv()` is the Pandas function used to read CSV files.
# - The `parse_dates` parameter is set to `[0]`, indicating that the first column of the CSV file contains dates that should be parsed as datetime objects.
# - The `infer_datetime_format` parameter is set to `True`, allowing Pandas to automatically infer the format of the datetime data.
#
# Step 5: Reindex the DataFrame using dates
# -----------------------------------------
#
# ```python
# reindexed_data = raw_data['headline_text']
# reindexed_data.index = raw_data['publish_date']
# ```
#
# Explanation:
# - In these lines, we are reindexing the DataFrame `raw_data` using the 'publish_date' column as the new index.
# - We create a new Series `reindexed_data` that contains only the 'headline_text' column from the original DataFrame `raw_data`.
# - Then, we set the index of `reindexed_data` to the 'publish_date' column, effectively reindexing the DataFrame using dates.
#
# Step 6: Display the first few rows of the DataFrame
# ---------------------------------------------------
#
# ```python
# raw_data.head()
# ```
#
# Explanation:
# - This line simply displays the first few rows of the DataFrame `raw_data` to inspect the data and ensure it was loaded correctly.
#
# Technical Concepts:
# -------------------
#
# 1. Google Drive Mounting: Google Colab allows users to mount their Google Drive to the notebook environment. This is helpful for accessing files stored in Google Drive and persisting changes across sessions.
#
# 2. DataFrame: In Python, a DataFrame is a two-dimensional, size-mutable, and heterogeneous data structure provided by the Pandas library. It is similar to a spreadsheet or SQL table, and it allows us to store and manipulate tabular data.
#
# 3. Reindexing: In the context of this code, reindexing means changing the index of the DataFrame to a new set of labels (in this case, dates) so that the data is aligned with the new index.
#
# 4. CSV (Comma-Separated Values): CSV is a simple file format commonly used to store tabular data, where each line in the file represents a row, and values within a row are separated by commas.
#
# In summary, the code mounts Google Drive, reads a CSV file into a DataFrame, reindexes the DataFrame using dates, and then displays the first few rows of the DataFrame to verify the data's successful loading.
#
# If you have any further questions or need more explanation, feel free to ask! Happy learning!

# %% [markdown]
# **First we develop a list of the top words used across all one million headlines, giving us a glimpse into the core vocabulary of the source data. Stop words are omitted here to avoid any trivial conjunctions, prepositions, etc**.

# %%
# Define helper functions
def get_top_n_words(n_top_words, count_vectorizer, text_data):
    '''
    returns a tuple of the top n words in a sample and their
    accompanying counts, given a CountVectorizer object and text sample
    '''
    vectorized_headlines = count_vectorizer.fit_transform(text_data.values)
    vectorized_total = np.sum(vectorized_headlines, axis=0)
    word_indices = np.flip(np.argsort(vectorized_total)[0,:], 1)
    word_values = np.flip(np.sort(vectorized_total)[0,:],1)

    word_vectors = np.zeros((n_top_words, vectorized_headlines.shape[1]))
    for i in range(n_top_words):
        word_vectors[i,word_indices[0,i]] = 1

    words = [word[0].encode('ascii').decode('utf-8') for
             word in count_vectorizer.inverse_transform(word_vectors)]

    return (words, word_values[0,:n_top_words].tolist()[0])

# %% [markdown]
# Certainly! Let's break down the given code into small pieces and explain each function and its components step by step:
#
# Step 1: Define the helper function `get_top_n_words`
# --------------------------------------------------
#
# ```python
# def get_top_n_words(n_top_words, count_vectorizer, text_data):
#     '''
#     returns a tuple of the top n words in a sample and their
#     accompanying counts, given a CountVectorizer object and text sample
#     '''
# ```
#
# Explanation:
# - In this step, we define the helper function `get_top_n_words`, which is used to find the top n words and their counts in a given text sample using a CountVectorizer object.
# - The function takes three parameters:
#   - `n_top_words`: The number of top words to be retrieved.
#   - `count_vectorizer`: A CountVectorizer object, which is used to convert text data into a numerical format (vectorized representation).
#   - `text_data`: A Pandas Series or DataFrame containing the text samples that we want to analyze.
#
# Step 2: Vectorize the text data
# -------------------------------
#
# ```python
# vectorized_headlines = count_vectorizer.fit_transform(text_data.values)
# ```
#
# Explanation:
# - In this step, we use the provided `count_vectorizer` to convert the text data into a vectorized representation.
# - The `fit_transform()` method of the CountVectorizer class is applied to the `text_data.values`. It learns the vocabulary from the text data and transforms the text samples into numerical feature vectors.
#
# Step 3: Sum the vectorized headlines to get word frequencies
# -----------------------------------------------------------
#
# ```python
# vectorized_total = np.sum(vectorized_headlines, axis=0)
# ```
#
# Explanation:
# - In this step, we calculate the total frequency of each word across all the headlines in the `text_data`.
# - The `np.sum()` function is used to sum the vectorized headlines along `axis=0`, which aggregates the word frequencies.
#
# Step 4: Sort the words based on their frequencies
# -------------------------------------------------
#
# ```python
# word_indices = np.flip(np.argsort(vectorized_total)[0, :], 1)
# word_values = np.flip(np.sort(vectorized_total)[0, :], 1)
# ```
#
# Explanation:
# - In this step, we sort the words based on their frequencies in descending order.
# - The `np.argsort()` function is used to get the indices that would sort the `vectorized_total` array in ascending order. The `np.flip()` function is then applied to reverse the order, effectively sorting in descending order.
# - `word_indices` contains the indices of the words, and `word_values` contains the corresponding word frequencies.
#
# Step 5: Create word vectors for the top n words
# ----------------------------------------------
#
# ```python
# word_vectors = np.zeros((n_top_words, vectorized_headlines.shape[1]))
# for i in range(n_top_words):
#     word_vectors[i, word_indices[0, i]] = 1
# ```
#
# Explanation:
# - In this step, we create word vectors for the top n words, where n is specified by the `n_top_words` parameter.
# - `word_vectors` is initialized as a matrix of zeros with shape `(n_top_words, vocabulary_size)` (the number of unique words in the text data).
# - The loop iterates through the top n words, and for each word, it sets the corresponding element in `word_vectors` to 1. This represents the presence of that word in the top n words.
#
# Step 6: Retrieve the top n words and their counts
# -------------------------------------------------
#
# ```python
# words = [word[0].encode('ascii').decode('utf-8') for
#          word in count_vectorizer.inverse_transform(word_vectors)]
#
# return (words, word_values[0, :n_top_words].tolist()[0])
# ```
#
# Explanation:
# - In this step, we use the `count_vectorizer` to convert the `word_vectors` back into word representations.
# - `count_vectorizer.inverse_transform()` is applied to `word_vectors`, which returns a list of lists containing the words for each word vector. The outer list is converted to a Python list comprehension.
# - We also retrieve the corresponding word frequencies for the top n words using `word_values`.
#
# Step 7: Theory Concepts
# -----------------------
#
# 1. CountVectorizer: `CountVectorizer` is a text preprocessing tool from the scikit-learn library. It is used to convert a collection of text documents into a matrix of token counts (word frequencies). It is a crucial step in preparing text data for machine learning models.
#
# 2. Vectorization: Vectorization refers to the process of converting text data into a numerical format that can be used as input for machine learning models. In this code, the text data is vectorized using the `CountVectorizer`.
#
# 3. Word Frequencies: In NLP, word frequencies refer to the number of times each word appears in a given corpus or document. By counting word frequencies, we can gain insights into the most common words in the text.
#
# In summary, the provided helper function `get_top_n_words` takes a CountVectorizer object and text data, vectorizes the text data, calculates word frequencies, retrieves the top n words based on their frequencies, and returns the top n words along with their corresponding counts.
#
# If you have any more questions or need further clarification, feel free to ask! Happy learning!

# %%
count_vectorizer = CountVectorizer(stop_words='english')
words, word_values = get_top_n_words(n_top_words=15,
                                     count_vectorizer=count_vectorizer,
                                     text_data=reindexed_data)

fig, ax = plt.subplots(figsize=(16,8))
ax.bar(range(len(words)), word_values)
ax.set_xticks(range(len(words)))
ax.set_xticklabels(words, rotation='vertical')
ax.set_title('Top words in headlines dataset (excluding stop words)')
ax.set_xlabel('Word')
ax.set_ylabel('Number of occurences')
plt.show()

# %% [markdown]
# Certainly! Let's break down the given code into small pieces and explain each step:
#
# Step 1: Create a CountVectorizer object with stop words
# ------------------------------------------------------
#
# ```python
# count_vectorizer = CountVectorizer(stop_words='english')
# ```
#
# Explanation:
# - In this step, we create a `CountVectorizer` object from the scikit-learn library.
# - The `stop_words` parameter is set to `'english'`, which means the CountVectorizer will automatically remove common English stop words (e.g., "the," "is," "and," etc.) during the text preprocessing step.
#
# Step 2: Get the top n words and their counts using the helper function
# ---------------------------------------------------------------------
#
# ```python
# words, word_values = get_top_n_words(n_top_words=15,
#                                      count_vectorizer=count_vectorizer,
#                                      text_data=reindexed_data)
# ```
#
# Explanation:
# - In this step, we use the `get_top_n_words` helper function to get the top n words and their corresponding counts from the `reindexed_data`.
# - The `n_top_words` parameter is set to 15, indicating that we want to retrieve the top 15 words.
# - We pass the `count_vectorizer` object we created in Step 1 and the `reindexed_data` as the text data to analyze.
#
# Step 3: Create a bar plot to visualize the top words
# ---------------------------------------------------
#
# ```python
# fig, ax = plt.subplots(figsize=(16, 8))
# ax.bar(range(len(words)), word_values)
# ax.set_xticks(range(len(words)))
# ax.set_xticklabels(words, rotation='vertical')
# ax.set_title('Top words in headlines dataset (excluding stop words)')
# ax.set_xlabel('Word')
# ax.set_ylabel('Number of occurrences')
# plt.show()
# ```
#
# Explanation:
# - In this step, we create a bar plot to visualize the top words and their occurrences.
# - `plt.subplots()` is used to create a new figure and axes. We specify the `figsize` parameter to set the size of the plot.
# - `ax.bar()` is used to create the bar plot. The x-values are represented by the indices of the `words` list, and the y-values are represented by the `word_values` list.
# - `ax.set_xticks()` and `ax.set_xticklabels()` are used to set the x-axis tick positions and their labels, respectively.
# - We set the plot title, x-label, and y-label using `ax.set_title()`, `ax.set_xlabel()`, and `ax.set_ylabel()` functions.
# - Finally, we use `plt.show()` to display the plot.
#
# Technical Concepts:
# -------------------
#
# 1. CountVectorizer: As discussed earlier, `CountVectorizer` is a text preprocessing tool from scikit-learn that converts text data into a matrix of token counts (word frequencies).
#
# 2. Stop Words: Stop words are common words (e.g., "the," "is," "and") that are often removed during text processing as they do not carry significant meaning and are unlikely to contribute to the analysis.
#
# 3. Bar Plot: A bar plot is a graphical representation of data using rectangular bars with lengths proportional to the values they represent. It is commonly used to visualize and compare data, such as word frequencies in this case.
#
# In summary, the code creates a `CountVectorizer` object, uses the helper function to find the top 15 words and their counts in the `reindexed_data`, and then visualizes the top words using a bar plot.
#
# If you have any more questions or need further clarification, feel free to ask! Happy learning!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Topic Modelling**
# **We now apply a clustering algorithm to the headlines corpus in order to study the topic focus of ABC News, as well as how it has evolved through time. To do so, we first experiment with a small subsample of the dataset in order to determine which of the two potential clustering algorithms is most appropriate – once this has been ascertained, we can then scale up to a larger portion of the available data.**
#
#
# # **Preprocessing**
#
# The only preprocessing step required in our case is feature construction, where we take the sample of text headlines and represent them in some tractable feature space. In practice, this simply means converting each string to a numerical vector. This can be done using the CountVectorizer object from SKLearn, which yields an
#  document-term matrix where
#  is the number of distinct words across the
#  headlines in our sample (less stop words and with a limit of max_features).

# %%
small_count_vectorizer = CountVectorizer(stop_words='english', max_features=4000)
small_text_sample = reindexed_data.sample(n=10000, random_state=0).values

print('Headline before vectorization: {}'.format(small_text_sample[123]))

small_document_term_matrix = small_count_vectorizer.fit_transform(small_text_sample)

print('Headline after vectorization: \n{}'.format(small_document_term_matrix[123]))

output:-

Headline before vectorization: man jailed for theft of police files
Headline after vectorization:
  (0, 2196)	1
  (0, 2662)	1

# %% [markdown]
# Thus we have our (very high-rank and sparse) training data, small_document_term_matrix, and can now actually implement a clustering algorithm. Our choice will be Latent Dirichlet Allocation. IT will take our document-term matrix as input and yield an n*N topic matrix as output, where N is the number of topic categories (which we supply as a parameter

# %% [markdown]
# # **Latent Dirichlet Allocation**
#
# LDA is a generative probabilistic process, designed with the specific goal of uncovering latent topic structure in text corpora.

# %%
# Parameters tuning using Grid Search
from sklearn.model_selection import GridSearchCV
grid_params = {'n_components' : list(range(5,10))}

# LDA model
lda = LatentDirichletAllocation()
lda_model = GridSearchCV(lda,param_grid=grid_params)
lda_model.fit(small_document_term_matrix)

# Best LDA model
best_lda_model = lda_model.best_estimator_

print("Best LDA model's params" , lda_model.best_params_)
print("Best log likelihood Score for the LDA model",lda_model.best_score_)
print("LDA model Perplexity on train data", best_lda_model.perplexity(small_document_term_matrix))


output:-

Best LDA model's params {'n_components': 5}
Best log likelihood Score for the LDA model -82895.33081684374
LDA model Perplexity on train data 3890.5324761734973

# %% [markdown]
# Certainly! Let's break down the given code into small pieces and explain each step:
#
# Step 1: Import the necessary libraries
# -------------------------------------
#
# ```python
# from sklearn.model_selection import GridSearchCV
# ```
#
# Explanation:
# - In this step, we import the `GridSearchCV` class from the scikit-learn library.
# - `GridSearchCV` is a module for hyperparameter tuning that exhaustively searches over a specified parameter grid and finds the best combination of hyperparameters.
#
# Step 2: Define the grid of parameters to search over
# ---------------------------------------------------
#
# ```python
# grid_params = {'n_components': list(range(5, 10))}
# ```
#
# Explanation:
# - In this step, we define a dictionary `grid_params` that specifies the grid of hyperparameters to search over during the tuning process.
# - In this case, we are tuning the hyperparameter `n_components` for the Latent Dirichlet Allocation (LDA) model, and we are considering values from 5 to 9 (inclusive).
#
# Step 3: Create and fit the GridSearchCV object
# ---------------------------------------------
#
# ```python
# lda = LatentDirichletAllocation()
# lda_model = GridSearchCV(lda, param_grid=grid_params)
# lda_model.fit(small_document_term_matrix)
# ```
#
# Explanation:
# - In this step, we create an instance of the Latent Dirichlet Allocation (LDA) model with default hyperparameters using `LatentDirichletAllocation()`.
# - We then create a `GridSearchCV` object `lda_model` with the `lda` model and the defined parameter grid `grid_params`.
# - The `fit()` method of `GridSearchCV` is then used to perform the grid search and find the best hyperparameters that maximize the model's log likelihood on the training data (`small_document_term_matrix`).
#
# Step 4: Get the best LDA model and print its performance
# --------------------------------------------------------
#
# ```python
# best_lda_model = lda_model.best_estimator_
#
# print("Best LDA model's params", lda_model.best_params_)
# print("Best log likelihood Score for the LDA model", lda_model.best_score_)
# print("LDA model Perplexity on train data", best_lda_model.perplexity(small_document_term_matrix))
# ```
#
# Explanation:
# - In this step, we retrieve the best LDA model from the grid search results using `lda_model.best_estimator_`.
# - We then print out the best hyperparameters found by the grid search (`lda_model.best_params_`), the corresponding log likelihood score (`lda_model.best_score_`), and the perplexity of the best LDA model on the training data (`best_lda_model.perplexity(small_document_term_matrix)`).
# - Perplexity is a measure of how well the LDA model predicts unseen data. Lower perplexity values indicate better model performance.
#
# Technical Concepts:
# -------------------
#
# 1. Grid Search: Grid search is a hyperparameter tuning technique that performs an exhaustive search over a predefined grid of hyperparameter values. It trains and evaluates models for all possible combinations of hyperparameters to find the best combination that yields the highest performance on the validation data.
#
# 2. Hyperparameters: Hyperparameters are parameters of a machine learning model that are not learned from the data but are set before the learning process. Examples of hyperparameters for the LDA model include the number of topics (`n_components`) and the learning rate.
#
# 3. Log Likelihood: The log likelihood is a measure used in probabilistic models like LDA to evaluate the likelihood of the observed data under the learned model. Higher log likelihood values indicate that the model is a better fit for the data.
#
# 4. Perplexity: Perplexity is another measure used in probabilistic models, including LDA, to evaluate how well the model predicts unseen data. Lower perplexity values indicate that the model can better generalize to new data.
#
# In summary, the code performs hyperparameter tuning for the LDA model using grid search. It finds the best hyperparameters that maximize the log likelihood on the training data and prints the results, including the best hyperparameters and model performance metrics.
#
# If you have any more questions or need further clarification, feel free to ask! Happy learning!

# %% [markdown]
# Once again, we take the  **arg max**
#  of each entry in the topic matrix to obtain the predicted topic category for each headline. These topic categories can then be characterised by their most frequent words.

# %%
# !pip install pyLDAvis
import pyLDAvis.sklearn

pyLDAvis.enable_notebook()
lda_panel = pyLDAvis.sklearn.prepare(best_lda_model, small_document_term_matrix,small_count_vectorizer,mds='tsne')
lda_panel

# %% [markdown]
# Of course! Let's break down the given code into small pieces and explain each step:
#
# Step 1: Install the `pyLDAvis` library
# -------------------------------------
#
# ```python
# !pip install pyLDAvis
# ```
#
# Explanation:
# - In this step, we are using the `pip` package manager to install the `pyLDAvis` library.
# - `pyLDAvis` is a Python library that provides interactive visualizations for topic models, including Latent Dirichlet Allocation (LDA).
#
# Step 2: Import the necessary module from `pyLDAvis`
# -------------------------------------------------
#
# ```python
# import pyLDAvis.sklearn
# ```
#
# Explanation:
# - In this step, we are importing the `pyLDAvis.sklearn` module from the `pyLDAvis` library.
# - This module contains functions to visualize topic models created using scikit-learn's LDA implementation.
#
# Step 3: Enable notebook display for `pyLDAvis`
# ---------------------------------------------
#
# ```python
# pyLDAvis.enable_notebook()
# ```
#
# Explanation:
# - In this step, we are enabling the notebook display mode for `pyLDAvis`.
# - This line allows us to display the interactive LDA visualization directly within the Jupyter notebook.
#
# Step 4: Prepare the LDA visualization
# -------------------------------------
#
# ```python
# lda_panel = pyLDAvis.sklearn.prepare(best_lda_model, small_document_term_matrix, small_count_vectorizer, mds='tsne')
# ```
#
# Explanation:
# - In this step, we prepare the data for the LDA visualization using `pyLDAvis`.
# - `pyLDAvis.sklearn.prepare()` is a function that prepares the data required for the interactive visualization.
# - The parameters are as follows:
#   - `best_lda_model`: The best LDA model obtained from hyperparameter tuning in the previous code (GridSearchCV).
#   - `small_document_term_matrix`: The document-term matrix (vectorized representation) of the text data used for training the LDA model.
#   - `small_count_vectorizer`: The CountVectorizer object used to vectorize the text data.
#   - `mds`: The multidimensional scaling (MDS) method used for visualizing the topics. In this case, 'tsne' is used for t-distributed stochastic neighbor embedding.
#
# Step 5: Display the LDA visualization
# -------------------------------------
#
# ```python
# lda_panel
# ```
#
# Explanation:
# - In this step, we simply display the `lda_panel` variable, which contains the interactive LDA visualization.
# - The visualization shows the topics and their word distributions, providing an intuitive way to explore and analyze the topics discovered by the LDA model.
#
# Technical Concepts:
# -------------------
#
# 1. pyLDAvis: `pyLDAvis` is a Python library that provides interactive visualizations for topic models. It helps to analyze and interpret the results of topic modeling algorithms like Latent Dirichlet Allocation (LDA).
#
# 2. Latent Dirichlet Allocation (LDA): LDA is a probabilistic topic modeling technique used to discover hidden topics in a collection of documents. It assumes that each document is a mixture of various topics, and each topic is a probability distribution over words.
#
# 3. Multidimensional Scaling (MDS): MDS is a dimensionality reduction technique used for visualizing high-dimensional data in lower dimensions. It aims to preserve the pairwise distances between data points as much as possible.
#
# 4. t-distributed Stochastic Neighbor Embedding (t-SNE): t-SNE is a specific MDS method that is commonly used for visualizing high-dimensional data, especially in the context of machine learning. It is particularly effective at preserving local structure and revealing clusters in the data.
#
# In summary, the code installs the `pyLDAvis` library, imports the necessary module, enables notebook display for `pyLDAvis`, prepares the LDA visualization data, and displays the interactive LDA visualization within the Jupyter notebook.
#
# If you have any more questions or need further clarification, feel free to ask! Happy learning!

# %% [markdown]
# # **How LDA works?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# From a dirichlet distribution Dir(alpha)
# , we draw a random sample representing the topic distribution, or topic mixture, of a particular document. This topic distribution is theta(0)
# . From  theta (0), we select a particular topic Z.based on the distribution.
#
#
#
# Next, from another dirichlet distribution Dir(B)
# , we select a random sample representing the word distribution of the topic Z
# . This word distribution is Y
# . From Y
# , we choose the word W
# .
#
#
# The normal distribution is a probability distribution over all the real numbers. It is described by a mean and a variance. The mean is the expected value of this distribution, and the variance tells us how much we can expect samples to deviate from the mean. If the variance is very high, then you’re going to see values that are both much smaller than the mean and much larger than the mean. If the variance is small, then the samples will be very close to the mean. If the variance goes close to zero, all samples will be almost exactly at the mean.
# Similarly, the dirichlet distribution is a probability distribution as well - but it is not sampling from the space of real numbers. Instead it is sampling over a probability simplex.
#
# And what is a probability simplex? It’s a bunch of numbers that add up to 1. For example:
# (0.6, 0.4)
#
# (0.1, 0.1, 0.8)
#
# (0.05, 0.2, 0.15, 0.1, 0.3, 0.2)
#
# These numbers represent probabilities over K distinct categories. In the above examples, K is 2, 3, and 6 respectively.
